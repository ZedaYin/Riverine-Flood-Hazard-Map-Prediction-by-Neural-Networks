# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.interpolate import griddata
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import datetime
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, TensorDataset, DataLoader

from einops import rearrange

#PyTorch random number generator
torch.manual_seed(3407)
torch.cuda.manual_seed(3407)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
print(device)
# Out:
# cuda

# %%
bc_fine = np.zeros(((45, 168, 4)))

for i in range (45):
    df1 = pd.read_csv('C:/Users/59713/BC2MAP/inputs/case_{}.csv'.format(i+1))
    data1 = df1.values
    bc_fine[i, :, :] = data1

# %%
D_3d_fine = np.zeros(((45, 576, 384)))

for i in range (45):
    df2 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_{}.csv'.format(i))
    data2 = df2.values
    D_3d_fine[i, :, :] = np.reshape(data2[:, 5], (576, 384))

# %%
E_3d_fine = np.zeros((576, 384))
X_3d_fine = np.zeros((576, 384))
Y_3d_fine = np.zeros((576, 384))
S_3d_fine = np.zeros((576, 384))
map4all = np.zeros((576, 384))

df3 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_45.csv')
data3 = df3.values
X_3d_fine[:, :] = np.reshape(data3[:, 0], (576, 384))
Y_3d_fine[:, :] = np.reshape(data3[:, 1], (576, 384))
E_3d_fine[:, :] = np.reshape(data3[:, 3], (576, 384))
map4all[:, :] = np.reshape(data3[:, 5], (576, 384))

# %%
dzdx = np.zeros((576, 384))
dzdy = np.zeros((576, 384))

# calculate internal cell slope
for i in range (1, S_3d_fine.shape[0]-1):
    for j in range (1, S_3d_fine.shape[1]-1):
        dzdx[i, j] = ((E_3d_fine[i+1, j-1]+2*E_3d_fine[i+1, j]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i-1, j]+2*E_3d_fine[i-1, j+1]))/(8*(X_3d_fine[i+1, j]-X_3d_fine[i-1, j]))
        dzdy[i, j] = ((E_3d_fine[i-1, j+1]+2*E_3d_fine[i, j+1]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i, j-1]+2*E_3d_fine[i+1, j-1]))/(8*(Y_3d_fine[i, j+1]-Y_3d_fine[i, j-1]))
        S_3d_fine[i, j] = np.arctan(np.sqrt((dzdx[i, j])**2+(dzdy[i, j])**2))
        
# take care of the most oustside layer
S_3d_fine[0, :] = S_3d_fine[1, :]
S_3d_fine[-1, :] = S_3d_fine[-2, :]
S_3d_fine[:, 0] = S_3d_fine[:, 1]
S_3d_fine[:, -1] = S_3d_fine[:, -2]

# %% [markdown]
# ### make a 3D info

# %%
all_data_X = bc_fine
all_data_Y = D_3d_fine

# %%
print(all_data_X.shape, all_data_Y.shape)
# Out:
# (45, 168, 4) (45, 576, 384)

# %%
# split into train and test
train_X, test_X = all_data_X[:-5, :], all_data_X[-5:, :]
train_y, test_y = all_data_Y[:-5, :, :], all_data_Y[-5:, :, :]

# %%
batch_size = 1

train_features = torch.Tensor(train_X).to(device)
train_targets = torch.Tensor(train_y).to(device)
test_features = torch.Tensor(test_X).to(device)
test_targets = torch.Tensor(test_y).to(device)

train = TensorDataset(train_features, train_targets)
test = TensorDataset(test_features, test_targets)

train_loader = DataLoader(train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader_one = DataLoader(test, batch_size=1, shuffle=False, drop_last=True)

# %%
sup_feat = np.zeros(((batch_size, 3, 576, 384)))

# first channel is mapforall
sup_feat[:, 0, :, :] = map4all
# second channel is elevation
sup_feat[:, 1, :, :] = E_3d_fine
# third channel is slope
sup_feat[:, 2, :, :] = S_3d_fine
# fourth channel left for bc info after SA

# %%
class Self_Attention(nn.Module):
    def __init__(self):
        super(Self_Attention, self).__init__()
        
        self.embed_dim = 864
        self.num_heads = 1
        self.head_dim = self.embed_dim // self.num_heads
        
        self.value = nn.Linear(self.embed_dim, self.embed_dim)
        self.key = nn.Linear(self.embed_dim, self.embed_dim)
        self.query = nn.Linear(self.embed_dim, self.embed_dim)
                    
    def forward(self, x):
        queries = self.query(x)
        keys = self.key(x)
        values = self.value(x)
        
        batch_size, seq_len, embed_dim = x.size()
        # Reshape query, key, and value to split into multiple heads
        queries = queries.view(batch_size, seq_len, self.num_heads, self.head_dim)
        keys = keys.view(batch_size, seq_len, self.num_heads, self.head_dim)
        values = values.view(batch_size, seq_len, self.num_heads, self.head_dim)
        
        # Transpose to prepare for scaled dot-product attention
        queries = queries.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        keys = keys.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        values = values.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        
        # Apply softmax to get attention probabilities
        attention_scores = torch.matmul(queries, keys.transpose(-2, -1)) / (self.head_dim**0.5)
        attention_probs = F.softmax(attention_scores, dim=-1)
        
        # Compute the weighted sum of values
        x = torch.matmul(attention_probs, values)
        
        # Reshape and concatenate heads
        x = x.transpose(1, 2)
        
        out = x.reshape(x.size(0), seq_len, embed_dim)
        
        return out

# %%
class BC2Map(nn.Module):
    def __init__(self, input_size, output_size, background_map, batch_size):
        super(BC2Map, self).__init__()
        
        self.background_map = torch.Tensor(background_map).to(device)
        
        self.input_size = input_size
        self.hidden_dim = output_size
        batch_size = batch_size
                
        self.fc1 = nn.Linear(input_size*3, self.hidden_dim)
        self.fc2 = nn.Linear(input_size, self.hidden_dim)
        
        self.self_attention = Self_Attention().to(device)
        
        self.L1 = nn.Linear(864, 4096)
        self.L2 = nn.Linear(4096, 864)
        
        self.pos_embedding = nn.Parameter(data=torch.randn(1, 2, 576, 384)).to(device)
        
        ##-----------end of embedding ---------##
        ##-----------start of Unet ---------##
        
        self.conv1 = nn.Conv2d(in_channels=5, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv7 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv9 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1)
        self.conv10 = nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1)
        
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        
        self.conv_transpose0 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2, padding=0)
        self.conv_transpose1 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2, padding=0)
        self.conv_transpose2 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2, padding=0)
        self.conv_transpose3 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2, padding=0)
        self.conv_transpose4 = nn.ConvTranspose2d(in_channels=64, out_channels=1, kernel_size=3, stride=1, padding=1)
        
    def forward(self, x):
        # change dimension, maybe it's better to use embedding
        x = x.transpose(1, 2)
        x1 = x[:, :3, :].reshape(x.size(0), 1, -1)
        x1 = self.relu(self.fc1(x1))
        x2 = x[:, 3:, :]
        x2 = self.relu(self.fc2(x2))
        
        x = torch.cat((x1, x2), dim=1)
        x = rearrange(x, 'b c (h w) -> b c h w', h=576)
        
        # add positional embeddings
        x = x + self.pos_embedding
        
        x = rearrange(x, 'b c (h1 h) (w1 w) -> b (c h1 w1) (h w)', h1=16, w1=16)
        
        # Self-Attention #1
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #2
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #3
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #4
        x = self.self_attention(x)
        
        # Concat the full feature map
        x = rearrange(x, 'b (c h1 w1) (h w) -> b c (h1 h) (w1 w)', h1=16, w1=16, c=2, h=36, w=24)
        x = torch.cat((x, self.background_map), dim=1)
        
        # initial conv: 1->64
        x = self.relu(self.conv1(x))
        
        # 1st resblock: 64->64
        identity = x
        x = self.conv2(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = x + identity
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 2nd resblock: 64->128
        identity2 = x
        x = self.conv3(x)
        x = self.relu(x)
        x = self.conv4(x)
        identity2 = self.conv3(identity2)
        x = x + identity2
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 3rd resblock: 128->256
        identity3 = x
        x = self.conv5(x)
        x = self.relu(x)
        x = self.conv6(x)
        identity3 = self.conv5(identity3)
        x = x + identity3
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 4th resblock: 256->512
        identity4 = x
        x = self.conv7(x)
        x = self.relu(x)
        x = self.conv8(x)
        identity4 = self.conv7(identity4)
        x = x + identity4
        x = self.relu(x)
        
        # transpose1: 512->256
        x = self.relu(self.conv_transpose1(x))
        identity8 = x
        x = self.conv6(x)
        x = self.relu(x)
        x = self.conv6(x)
        x = x + identity8
        x = self.relu(x)
        
        # transpose2: 256->128
        x = self.relu(self.conv_transpose2(x))
        identity9 = x
        x = self.conv4(x)
        x = self.relu(x)
        x = self.conv4(x)
        x = x + identity9
        
        # transpose3: 128->64
        x = self.relu(self.conv_transpose3(x))
        identity10 = x
        x = self.conv2(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = x + identity10
        x = self.relu(x)
        
        # transpose4: 64->1
        x = self.relu(self.conv_transpose4(x))
        
        out = x.reshape(x.size(0), -1)
        
        return out

# %%
class Optimization:
    def __init__(self, model, optimizer):
        self.model = model
        self.loss_fn = nn.MSELoss(reduction="mean")
        self.optimizer = optimizer
        self.train_losses = []
        self.val_losses = []
    
    def train_step(self, x, y):
        # Sets model to train mode
        self.model.train()

        # Makes predictions
        yhat = self.model(x)

        # Computes loss
        loss = self.loss_fn(y, yhat)

        # Computes gradients
        loss.backward()

        # Updates parameters and zeroes gradients
        self.optimizer.step()
        self.optimizer.zero_grad()

        # Returns the loss
        return loss.item()

    def train(self, train_loader, val_loader, batch_size=4, n_epochs=50):
        model_path = f'models/{self.model}_{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'

        for epoch in range(1, n_epochs + 1):
            batch_losses = []
            for x_batch, y_batch in train_loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.view([batch_size, 576*384]).to(device)
                loss = self.train_step(x_batch, y_batch)
                batch_losses.append(loss)
            training_loss = np.mean(batch_losses)
            self.train_losses.append(training_loss)

            with torch.no_grad():
                batch_val_losses = []
                for x_val, y_val in val_loader:
                    x_val = x_val.to(device)
                    y_val = y_val.view([batch_size, 576*384]).to(device)
                    self.model.eval()
                    yhat = self.model(x_val).to(device)
                    val_loss = self.loss_fn(y_val, yhat).item()
                    batch_val_losses.append(val_loss)
                validation_loss = np.mean(batch_val_losses)
                self.val_losses.append(validation_loss)

            if (epoch % 5 == 0):
                print(
                    f"[{epoch}/{n_epochs}] Training loss: {training_loss:.6f}\t Validation loss: {validation_loss:.6f}"
                )
            
            if (validation_loss <= 0.004):
                break

#         torch.save(self.model.state_dict(), model_path)

    def evaluate(self, test_loader, batch_size=1):
        with torch.no_grad():
            predictions = []
            values = []
            for x_test, y_test in test_loader:
                x_test = x_test.to(device)
                y_test = y_test.view([batch_size, 576*384]).to(device)
                self.model.eval()
                yhat = self.model(x_test)
                predictions.append(yhat.cpu().detach().numpy())
                values.append(y_test.cpu().detach().numpy())

        return predictions, values

    def plot_losses(self):
        plt.plot(self.train_losses, label="Training loss")
        plt.plot(self.val_losses, label="Validation loss")
        plt.legend()
        plt.title("Losses")
        plt.show()
        plt.close()

# %%
input_size = 672//4
output_size = 576 * 384

batch_size = batch_size
n_epochs = 5000
learning_rate = 1e-4
weight_decay = learning_rate/n_epochs

model = BC2Map(input_size, output_size, background_map=sup_feat, batch_size=batch_size).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

opt = Optimization(model=model, optimizer=optimizer)
opt.train(train_loader, test_loader, batch_size=batch_size, n_epochs=n_epochs)
opt.plot_losses()
# Out:
# [5/5000] Training loss: 0.486588	 Validation loss: 0.564249
# [10/5000] Training loss: 0.246497	 Validation loss: 0.230903
# [15/5000] Training loss: 0.110781	 Validation loss: 0.168492
# [20/5000] Training loss: 0.135221	 Validation loss: 0.137337
# [25/5000] Training loss: 0.121728	 Validation loss: 0.127532
# [30/5000] Training loss: 0.076573	 Validation loss: 0.125198
# [35/5000] Training loss: 0.065675	 Validation loss: 0.104969
# [40/5000] Training loss: 0.094157	 Validation loss: 0.114245
# [45/5000] Training loss: 0.114411	 Validation loss: 0.165228
# [50/5000] Training loss: 0.080402	 Validation loss: 0.104493
# [55/5000] Training loss: 0.052598	 Validation loss: 0.099124
# [60/5000] Training loss: 0.064408	 Validation loss: 0.090924
# [65/5000] Training loss: 0.069221	 Validation loss: 0.096459
# [70/5000] Training loss: 0.052520	 Validation loss: 0.100326
# [75/5000] Training loss: 0.074886	 Validation loss: 0.099627
# [80/5000] Training loss: 0.049375	 Validation loss: 0.084111
# [85/5000] Training loss: 0.055411	 Validation loss: 0.092748
# [90/5000] Training loss: 0.048738	 Validation loss: 0.082065
# [95/5000] Training loss: 0.047168	 Validation loss: 0.088574
# [100/5000] Training loss: 0.044864	 Validation loss: 0.081319
# [105/5000] Training loss: 0.042786	 Validation loss: 0.080810
# [110/5000] Training loss: 0.066983	 Validation loss: 0.135274
# [115/5000] Training loss: 0.074684	 Validation loss: 0.213438
# [120/5000] Training loss: 0.078896	 Validation loss: 0.100011
# [125/5000] Training loss: 0.049389	 Validation loss: 0.082396
# [130/5000] Training loss: 0.051697	 Validation loss: 0.079289
# [135/5000] Training loss: 0.042233	 Validation loss: 0.082159
# [140/5000] Training loss: 0.040654	 Validation loss: 0.072498
# [145/5000] Training loss: 0.047612	 Validation loss: 0.073810
# [150/5000] Training loss: 0.040875	 Validation loss: 0.068791
# [155/5000] Training loss: 0.039285	 Validation loss: 0.077033
# [160/5000] Training loss: 0.062823	 Validation loss: 0.092491
# [165/5000] Training loss: 0.053594	 Validation loss: 0.103091
# [170/5000] Training loss: 0.041297	 Validation loss: 0.068324
# [175/5000] Training loss: 0.036948	 Validation loss: 0.065542
# [180/5000] Training loss: 0.037302	 Validation loss: 0.073382
# [185/5000] Training loss: 0.036065	 Validation loss: 0.062411
# [190/5000] Training loss: 0.036079	 Validation loss: 0.062199
# [195/5000] Training loss: 0.042848	 Validation loss: 0.065586
# [200/5000] Training loss: 0.079453	 Validation loss: 0.084487
# [205/5000] Training loss: 0.035218	 Validation loss: 0.059027
# [210/5000] Training loss: 0.035025	 Validation loss: 0.071457
# [215/5000] Training loss: 0.031766	 Validation loss: 0.054210
# [220/5000] Training loss: 0.030129	 Validation loss: 0.050748
# [225/5000] Training loss: 0.035624	 Validation loss: 0.060351
# [230/5000] Training loss: 0.030900	 Validation loss: 0.053295
# [235/5000] Training loss: 0.025596	 Validation loss: 0.041872
# [240/5000] Training loss: 0.049354	 Validation loss: 0.062220
# [245/5000] Training loss: 0.047595	 Validation loss: 0.093890
# [250/5000] Training loss: 0.029770	 Validation loss: 0.051915
# [255/5000] Training loss: 0.036979	 Validation loss: 0.055971
# [260/5000] Training loss: 0.033116	 Validation loss: 0.054473
# [265/5000] Training loss: 0.027584	 Validation loss: 0.050294
# [270/5000] Training loss: 0.033017	 Validation loss: 0.054986
# [275/5000] Training loss: 0.032000	 Validation loss: 0.052624
# [280/5000] Training loss: 0.032000	 Validation loss: 0.053071
# [285/5000] Training loss: 0.022249	 Validation loss: 0.045392
# [290/5000] Training loss: 0.021647	 Validation loss: 0.044696
# [295/5000] Training loss: 0.057476	 Validation loss: 0.083091
# [300/5000] Training loss: 0.027315	 Validation loss: 0.036609
# [305/5000] Training loss: 0.033989	 Validation loss: 0.056240
# [310/5000] Training loss: 0.021015	 Validation loss: 0.034095
# [315/5000] Training loss: 0.018611	 Validation loss: 0.037470
# [320/5000] Training loss: 0.017127	 Validation loss: 0.040543
# [325/5000] Training loss: 0.045870	 Validation loss: 0.058026
# [330/5000] Training loss: 0.019896	 Validation loss: 0.034991
# [335/5000] Training loss: 0.022668	 Validation loss: 0.040375
# [340/5000] Training loss: 0.014268	 Validation loss: 0.029297
# [345/5000] Training loss: 0.014837	 Validation loss: 0.029048
# [350/5000] Training loss: 0.014521	 Validation loss: 0.028262
# [355/5000] Training loss: 0.015314	 Validation loss: 0.027616
# [360/5000] Training loss: 0.020751	 Validation loss: 0.035152
# [365/5000] Training loss: 0.018514	 Validation loss: 0.031737
# [370/5000] Training loss: 0.025154	 Validation loss: 0.050610
# [375/5000] Training loss: 0.013944	 Validation loss: 0.023744
# [380/5000] Training loss: 0.029173	 Validation loss: 0.054071
# [385/5000] Training loss: 0.018967	 Validation loss: 0.034028
# [390/5000] Training loss: 0.029201	 Validation loss: 0.024637
# [395/5000] Training loss: 0.010947	 Validation loss: 0.023038
# [400/5000] Training loss: 0.011346	 Validation loss: 0.023570
# [405/5000] Training loss: 0.019460	 Validation loss: 0.027569
# [410/5000] Training loss: 0.011782	 Validation loss: 0.026861
# [415/5000] Training loss: 0.014088	 Validation loss: 0.021252
# [420/5000] Training loss: 0.009831	 Validation loss: 0.022375
# [425/5000] Training loss: 0.009574	 Validation loss: 0.028039
# [430/5000] Training loss: 0.008763	 Validation loss: 0.023384
# [435/5000] Training loss: 0.008601	 Validation loss: 0.020476
# [440/5000] Training loss: 0.017782	 Validation loss: 0.040900
# [445/5000] Training loss: 0.009195	 Validation loss: 0.021597
# [450/5000] Training loss: 0.012091	 Validation loss: 0.040322
# [455/5000] Training loss: 0.011746	 Validation loss: 0.022654
# [460/5000] Training loss: 0.010203	 Validation loss: 0.020200
# [465/5000] Training loss: 0.014976	 Validation loss: 0.021683
# [470/5000] Training loss: 0.012836	 Validation loss: 0.023704
# [475/5000] Training loss: 0.007126	 Validation loss: 0.018921
# [480/5000] Training loss: 0.008414	 Validation loss: 0.022587
# [485/5000] Training loss: 0.009024	 Validation loss: 0.021266
# [490/5000] Training loss: 0.007685	 Validation loss: 0.021228
# [495/5000] Training loss: 0.008798	 Validation loss: 0.035979
# [500/5000] Training loss: 0.010478	 Validation loss: 0.026866
# [505/5000] Training loss: 0.018178	 Validation loss: 0.020264
# [510/5000] Training loss: 0.007954	 Validation loss: 0.017978
# [515/5000] Training loss: 0.009301	 Validation loss: 0.018599
# [520/5000] Training loss: 0.006961	 Validation loss: 0.016813
# [525/5000] Training loss: 0.006486	 Validation loss: 0.023312
# [530/5000] Training loss: 0.007451	 Validation loss: 0.032869
# [535/5000] Training loss: 0.006208	 Validation loss: 0.020269
# [540/5000] Training loss: 0.007889	 Validation loss: 0.017922
# [545/5000] Training loss: 0.009207	 Validation loss: 0.027016
# [550/5000] Training loss: 0.262938	 Validation loss: 0.191045
# [555/5000] Training loss: 0.040030	 Validation loss: 0.051225
# [560/5000] Training loss: 0.045725	 Validation loss: 0.063767
# [565/5000] Training loss: 0.010210	 Validation loss: 0.030866
# [570/5000] Training loss: 0.009028	 Validation loss: 0.018125
# [575/5000] Training loss: 0.005591	 Validation loss: 0.022805
# [580/5000] Training loss: 0.005191	 Validation loss: 0.018177
# [585/5000] Training loss: 0.011030	 Validation loss: 0.023512
# [590/5000] Training loss: 0.004956	 Validation loss: 0.020540
# [595/5000] Training loss: 0.005070	 Validation loss: 0.017315
# [600/5000] Training loss: 0.024883	 Validation loss: 0.035701
# [605/5000] Training loss: 0.004922	 Validation loss: 0.018882
# [610/5000] Training loss: 0.004682	 Validation loss: 0.018517
# [615/5000] Training loss: 0.004474	 Validation loss: 0.019122
# [620/5000] Training loss: 0.006467	 Validation loss: 0.025653
# [625/5000] Training loss: 0.005760	 Validation loss: 0.019250
# [630/5000] Training loss: 0.005478	 Validation loss: 0.017598
# [635/5000] Training loss: 0.025434	 Validation loss: 0.062751
# [640/5000] Training loss: 0.010334	 Validation loss: 0.019322
# [645/5000] Training loss: 0.417477	 Validation loss: 0.187945
# [650/5000] Training loss: 0.023873	 Validation loss: 0.045810
# [655/5000] Training loss: 0.013816	 Validation loss: 0.025609
# [660/5000] Training loss: 0.009163	 Validation loss: 0.017967
# [665/5000] Training loss: 0.006725	 Validation loss: 0.023483
# [670/5000] Training loss: 0.005551	 Validation loss: 0.018654
# [675/5000] Training loss: 0.011349	 Validation loss: 0.017667
# [680/5000] Training loss: 0.005856	 Validation loss: 0.017214
# [685/5000] Training loss: 0.004372	 Validation loss: 0.018901
# [690/5000] Training loss: 0.004194	 Validation loss: 0.021368
# [695/5000] Training loss: 0.004171	 Validation loss: 0.015286
# [700/5000] Training loss: 0.009198	 Validation loss: 0.028320
# [705/5000] Training loss: 0.004995	 Validation loss: 0.015824
# [710/5000] Training loss: 0.004685	 Validation loss: 0.017966
# [715/5000] Training loss: 0.008538	 Validation loss: 0.022382
# [720/5000] Training loss: 0.012762	 Validation loss: 0.014274
# [725/5000] Training loss: 0.004068	 Validation loss: 0.020777
# [730/5000] Training loss: 0.003864	 Validation loss: 0.016025
# [735/5000] Training loss: 0.004069	 Validation loss: 0.015730
# [740/5000] Training loss: 0.006270	 Validation loss: 0.023459
# [745/5000] Training loss: 0.004611	 Validation loss: 0.013533
# [750/5000] Training loss: 0.005547	 Validation loss: 0.017724
# [755/5000] Training loss: 0.004043	 Validation loss: 0.013625
# [760/5000] Training loss: 0.004780	 Validation loss: 0.022223
# [765/5000] Training loss: 0.011453	 Validation loss: 0.016663
# [770/5000] Training loss: 0.033785	 Validation loss: 0.022001
# [775/5000] Training loss: 0.004152	 Validation loss: 0.014739
# [780/5000] Training loss: 0.019172	 Validation loss: 0.017747
# [785/5000] Training loss: 0.003379	 Validation loss: 0.012851
# [790/5000] Training loss: 0.033250	 Validation loss: 0.020115
# [795/5000] Training loss: 0.008970	 Validation loss: 0.017778
# [800/5000] Training loss: 0.006629	 Validation loss: 0.015968
# [805/5000] Training loss: 0.004799	 Validation loss: 0.014266
# [810/5000] Training loss: 0.014729	 Validation loss: 0.041708
# [815/5000] Training loss: 0.010415	 Validation loss: 0.012510
# [820/5000] Training loss: 0.004364	 Validation loss: 0.017890
# [825/5000] Training loss: 0.003326	 Validation loss: 0.014973
# [830/5000] Training loss: 0.003424	 Validation loss: 0.012242
# [835/5000] Training loss: 0.002995	 Validation loss: 0.012409
# [840/5000] Training loss: 0.006806	 Validation loss: 0.014809
# [845/5000] Training loss: 0.002896	 Validation loss: 0.013607
# [850/5000] Training loss: 0.002433	 Validation loss: 0.011790
# [855/5000] Training loss: 0.002500	 Validation loss: 0.014886
# [860/5000] Training loss: 0.002386	 Validation loss: 0.013756
# [865/5000] Training loss: 0.002720	 Validation loss: 0.012633
# [870/5000] Training loss: 0.011063	 Validation loss: 0.014187
# [875/5000] Training loss: 0.004469	 Validation loss: 0.017222
# [880/5000] Training loss: 0.004544	 Validation loss: 0.011522
# [885/5000] Training loss: 0.047125	 Validation loss: 0.187121
# [890/5000] Training loss: 0.009629	 Validation loss: 0.013090
# [895/5000] Training loss: 0.004652	 Validation loss: 0.011676
# [900/5000] Training loss: 0.029459	 Validation loss: 0.028526
# [905/5000] Training loss: 0.012056	 Validation loss: 0.021856
# [910/5000] Training loss: 0.009434	 Validation loss: 0.017322
# [915/5000] Training loss: 0.006359	 Validation loss: 0.016234
# [920/5000] Training loss: 0.004140	 Validation loss: 0.017344
# [925/5000] Training loss: 0.002700	 Validation loss: 0.011116
# [930/5000] Training loss: 0.002376	 Validation loss: 0.014942
# [935/5000] Training loss: 0.004316	 Validation loss: 0.020992
# [940/5000] Training loss: 0.005181	 Validation loss: 0.014610
# [945/5000] Training loss: 0.005731	 Validation loss: 0.022220
# [950/5000] Training loss: 0.003007	 Validation loss: 0.013001
# [955/5000] Training loss: 0.002585	 Validation loss: 0.011342
# [960/5000] Training loss: 0.004541	 Validation loss: 0.016829
# [965/5000] Training loss: 0.005402	 Validation loss: 0.021357
# [970/5000] Training loss: 0.007120	 Validation loss: 0.015724
# [975/5000] Training loss: 0.001701	 Validation loss: 0.009844
# [980/5000] Training loss: 0.001588	 Validation loss: 0.011468
# [985/5000] Training loss: 0.001277	 Validation loss: 0.010498
# [990/5000] Training loss: 0.006082	 Validation loss: 0.010952
# [995/5000] Training loss: 0.002833	 Validation loss: 0.011134
# [1000/5000] Training loss: 0.005771	 Validation loss: 0.010231
# [1005/5000] Training loss: 0.002921	 Validation loss: 0.022118
# [1010/5000] Training loss: 0.004518	 Validation loss: 0.010445
# [1015/5000] Training loss: 0.001518	 Validation loss: 0.010794
# [1020/5000] Training loss: 0.001501	 Validation loss: 0.011515
# [1025/5000] Training loss: 0.002463	 Validation loss: 0.016511
# [1030/5000] Training loss: 0.002943	 Validation loss: 0.010371
# [1035/5000] Training loss: 0.003807	 Validation loss: 0.013991
# [1040/5000] Training loss: 0.006571	 Validation loss: 0.009583
# [1045/5000] Training loss: 0.008025	 Validation loss: 0.009704
# [1050/5000] Training loss: 0.001973	 Validation loss: 0.009262
# [1055/5000] Training loss: 0.001367	 Validation loss: 0.008376
# [1060/5000] Training loss: 0.001463	 Validation loss: 0.011437
# [1065/5000] Training loss: 0.002697	 Validation loss: 0.009834
# [1070/5000] Training loss: 0.002510	 Validation loss: 0.009913
# [1075/5000] Training loss: 0.004412	 Validation loss: 0.010455
# [1080/5000] Training loss: 0.001672	 Validation loss: 0.010972
# [1085/5000] Training loss: 0.002173	 Validation loss: 0.008465
# [1090/5000] Training loss: 0.003405	 Validation loss: 0.033650
# [1095/5000] Training loss: 0.001148	 Validation loss: 0.009979
# [1100/5000] Training loss: 0.001414	 Validation loss: 0.008941
# [1105/5000] Training loss: 0.001387	 Validation loss: 0.009527
# [1110/5000] Training loss: 0.003235	 Validation loss: 0.012143
# [1115/5000] Training loss: 0.003296	 Validation loss: 0.016478
# [1120/5000] Training loss: 0.001838	 Validation loss: 0.011250
# [1125/5000] Training loss: 0.001385	 Validation loss: 0.008900
# [1130/5000] Training loss: 0.001463	 Validation loss: 0.011003
# [1135/5000] Training loss: 0.002937	 Validation loss: 0.010197
# [1140/5000] Training loss: 0.004179	 Validation loss: 0.040560
# [1145/5000] Training loss: 0.001960	 Validation loss: 0.010848
# [1150/5000] Training loss: 0.001283	 Validation loss: 0.011490
# [1155/5000] Training loss: 0.001429	 Validation loss: 0.012399
# [1160/5000] Training loss: 0.002152	 Validation loss: 0.012893
# [1165/5000] Training loss: 0.003320	 Validation loss: 0.011152
# [1170/5000] Training loss: 0.001670	 Validation loss: 0.009887
# [1175/5000] Training loss: 0.002428	 Validation loss: 0.012383
# [1180/5000] Training loss: 0.001105	 Validation loss: 0.010811
# [1185/5000] Training loss: 0.001010	 Validation loss: 0.010769
# [1190/5000] Training loss: 0.003336	 Validation loss: 0.009833
# [1195/5000] Training loss: 0.002164	 Validation loss: 0.009235
# [1200/5000] Training loss: 0.001141	 Validation loss: 0.011220
# [1205/5000] Training loss: 0.001942	 Validation loss: 0.011877
# [1210/5000] Training loss: 0.005502	 Validation loss: 0.012840
# [1215/5000] Training loss: 0.024930	 Validation loss: 0.052836
# [1220/5000] Training loss: 0.001860	 Validation loss: 0.010424
# [1225/5000] Training loss: 0.001314	 Validation loss: 0.010574
# [1230/5000] Training loss: 0.000881	 Validation loss: 0.009077
# [1235/5000] Training loss: 0.000748	 Validation loss: 0.010077
# [1240/5000] Training loss: 0.000860	 Validation loss: 0.009627
# [1245/5000] Training loss: 0.000704	 Validation loss: 0.009128
# [1250/5000] Training loss: 0.001353	 Validation loss: 0.010566
# [1255/5000] Training loss: 0.001999	 Validation loss: 0.012649
# [1260/5000] Training loss: 0.001234	 Validation loss: 0.013004
# [1265/5000] Training loss: 0.002120	 Validation loss: 0.013611
# [1270/5000] Training loss: 0.002181	 Validation loss: 0.012638
# [1275/5000] Training loss: 0.001479	 Validation loss: 0.010024
# [1280/5000] Training loss: 0.001377	 Validation loss: 0.010226
# [1285/5000] Training loss: 0.001171	 Validation loss: 0.008495
# [1290/5000] Training loss: 0.001689	 Validation loss: 0.011087
# [1295/5000] Training loss: 0.003228	 Validation loss: 0.010993
# [1300/5000] Training loss: 0.001968	 Validation loss: 0.010684
# [1305/5000] Training loss: 0.001317	 Validation loss: 0.012998
# [1310/5000] Training loss: 0.001464	 Validation loss: 0.010576
# [1315/5000] Training loss: 0.002220	 Validation loss: 0.011605
# [1320/5000] Training loss: 0.001079	 Validation loss: 0.009412
# [1325/5000] Training loss: 0.001565	 Validation loss: 0.011668
# [1330/5000] Training loss: 0.001595	 Validation loss: 0.010761
# [1335/5000] Training loss: 0.002636	 Validation loss: 0.017440
# [1340/5000] Training loss: 0.003505	 Validation loss: 0.014168
# [1345/5000] Training loss: 0.001822	 Validation loss: 0.010623
# [1350/5000] Training loss: 0.002100	 Validation loss: 0.011093
# [1355/5000] Training loss: 0.002316	 Validation loss: 0.011427
# [1360/5000] Training loss: 0.004732	 Validation loss: 0.011239
# [1365/5000] Training loss: 0.014540	 Validation loss: 0.019323
# [1370/5000] Training loss: 0.001107	 Validation loss: 0.009259
# [1375/5000] Training loss: 0.000774	 Validation loss: 0.010544
# [1380/5000] Training loss: 0.000714	 Validation loss: 0.009485
# [1385/5000] Training loss: 0.000688	 Validation loss: 0.010720
# [1390/5000] Training loss: 0.000607	 Validation loss: 0.009892
# [1395/5000] Training loss: 0.000586	 Validation loss: 0.009728
# [1400/5000] Training loss: 0.000902	 Validation loss: 0.009580
# [1405/5000] Training loss: 0.000651	 Validation loss: 0.010329
# [1410/5000] Training loss: 0.000638	 Validation loss: 0.009845
# [1415/5000] Training loss: 0.012095	 Validation loss: 0.080624
# [1420/5000] Training loss: 0.010654	 Validation loss: 0.030456
# [1425/5000] Training loss: 0.006968	 Validation loss: 0.013773
# [1430/5000] Training loss: 0.002293	 Validation loss: 0.008756
# [1435/5000] Training loss: 0.008315	 Validation loss: 0.013651
# [1440/5000] Training loss: 0.003067	 Validation loss: 0.009852
# [1445/5000] Training loss: 0.004605	 Validation loss: 0.025648
# [1450/5000] Training loss: 0.001700	 Validation loss: 0.009050
# [1455/5000] Training loss: 0.002414	 Validation loss: 0.010741
# [1460/5000] Training loss: 0.002240	 Validation loss: 0.012636
# [1465/5000] Training loss: 0.001777	 Validation loss: 0.008565
# [1470/5000] Training loss: 0.005883	 Validation loss: 0.014560
# [1475/5000] Training loss: 0.000886	 Validation loss: 0.011516
# [1480/5000] Training loss: 0.001107	 Validation loss: 0.008766
# [1485/5000] Training loss: 0.001246	 Validation loss: 0.010444
# [1490/5000] Training loss: 0.000861	 Validation loss: 0.015247
# [1495/5000] Training loss: 0.006880	 Validation loss: 0.011862
# [1500/5000] Training loss: 0.004035	 Validation loss: 0.008607
# [1505/5000] Training loss: 0.001289	 Validation loss: 0.009353
# [1510/5000] Training loss: 0.001283	 Validation loss: 0.010026
# [1515/5000] Training loss: 0.000675	 Validation loss: 0.008731
# [1520/5000] Training loss: 0.000545	 Validation loss: 0.008925
# [1525/5000] Training loss: 0.001498	 Validation loss: 0.008281
# [1530/5000] Training loss: 0.000998	 Validation loss: 0.007686
# [1535/5000] Training loss: 0.000962	 Validation loss: 0.009104
# [1540/5000] Training loss: 0.005464	 Validation loss: 0.009403
# [1545/5000] Training loss: 0.001087	 Validation loss: 0.010210
# [1550/5000] Training loss: 0.005390	 Validation loss: 0.020497
# [1555/5000] Training loss: 0.001127	 Validation loss: 0.020823
# [1560/5000] Training loss: 0.000735	 Validation loss: 0.009432
# [1565/5000] Training loss: 0.000823	 Validation loss: 0.009949
# [1570/5000] Training loss: 0.000725	 Validation loss: 0.010209
# [1575/5000] Training loss: 0.000592	 Validation loss: 0.009802
# [1580/5000] Training loss: 0.000558	 Validation loss: 0.010058
# [1585/5000] Training loss: 0.000820	 Validation loss: 0.010764
# [1590/5000] Training loss: 0.000802	 Validation loss: 0.011411
# [1595/5000] Training loss: 0.001637	 Validation loss: 0.009324
# [1600/5000] Training loss: 0.000887	 Validation loss: 0.011729
# [1605/5000] Training loss: 0.002412	 Validation loss: 0.016068
# [1610/5000] Training loss: 0.000816	 Validation loss: 0.008902
# [1615/5000] Training loss: 0.000628	 Validation loss: 0.010164
# [1620/5000] Training loss: 0.001060	 Validation loss: 0.009167
# [1625/5000] Training loss: 0.002511	 Validation loss: 0.019948
# [1630/5000] Training loss: 0.001677	 Validation loss: 0.009717
# [1635/5000] Training loss: 0.002064	 Validation loss: 0.010738
# [1640/5000] Training loss: 0.000951	 Validation loss: 0.010173
# [1645/5000] Training loss: 0.000649	 Validation loss: 0.008865
# [1650/5000] Training loss: 0.001028	 Validation loss: 0.010695
# [1655/5000] Training loss: 0.010082	 Validation loss: 0.026432
# [1660/5000] Training loss: 0.001577	 Validation loss: 0.018947
# [1665/5000] Training loss: 0.001307	 Validation loss: 0.008586
# [1670/5000] Training loss: 0.000701	 Validation loss: 0.009101
# [1675/5000] Training loss: 0.001318	 Validation loss: 0.008034
# [1680/5000] Training loss: 0.000416	 Validation loss: 0.008826
# [1685/5000] Training loss: 0.000402	 Validation loss: 0.008855
# [1690/5000] Training loss: 0.000400	 Validation loss: 0.009004
# [1695/5000] Training loss: 0.000396	 Validation loss: 0.009158
# [1700/5000] Training loss: 0.000472	 Validation loss: 0.008528
# [1705/5000] Training loss: 0.000825	 Validation loss: 0.008785
# [1710/5000] Training loss: 0.004110	 Validation loss: 0.009869
# [1715/5000] Training loss: 0.002065	 Validation loss: 0.007705
# [1720/5000] Training loss: 0.002153	 Validation loss: 0.009805
# [1725/5000] Training loss: 0.020793	 Validation loss: 0.019586
# [1730/5000] Training loss: 0.001827	 Validation loss: 0.011039
# [1735/5000] Training loss: 0.001063	 Validation loss: 0.012073
# [1740/5000] Training loss: 0.001004	 Validation loss: 0.008200
# [1745/5000] Training loss: 0.001294	 Validation loss: 0.010608
# [1750/5000] Training loss: 0.000794	 Validation loss: 0.008910
# [1755/5000] Training loss: 0.000668	 Validation loss: 0.009250
# [1760/5000] Training loss: 0.000732	 Validation loss: 0.008677
# [1765/5000] Training loss: 0.005656	 Validation loss: 0.011781
# [1770/5000] Training loss: 0.001450	 Validation loss: 0.009299
# [1775/5000] Training loss: 0.000515	 Validation loss: 0.008543
# [1780/5000] Training loss: 0.000437	 Validation loss: 0.009375
# [1785/5000] Training loss: 0.000412	 Validation loss: 0.008908
# [1790/5000] Training loss: 0.000342	 Validation loss: 0.009313
# [1795/5000] Training loss: 0.000492	 Validation loss: 0.009177
# [1800/5000] Training loss: 0.022100	 Validation loss: 0.013577
# [1805/5000] Training loss: 0.002354	 Validation loss: 0.012975
# [1810/5000] Training loss: 0.001552	 Validation loss: 0.008819
# [1815/5000] Training loss: 0.001440	 Validation loss: 0.012420
# [1820/5000] Training loss: 0.001599	 Validation loss: 0.008398
# [1825/5000] Training loss: 0.000748	 Validation loss: 0.008321
# [1830/5000] Training loss: 0.000823	 Validation loss: 0.009818
# [1835/5000] Training loss: 0.000729	 Validation loss: 0.008846
# [1840/5000] Training loss: 0.005474	 Validation loss: 0.011874
# [1845/5000] Training loss: 0.003020	 Validation loss: 0.012247
# [1850/5000] Training loss: 0.000439	 Validation loss: 0.011307
# [1855/5000] Training loss: 0.000303	 Validation loss: 0.009051
# [1860/5000] Training loss: 0.000693	 Validation loss: 0.008718
# [1865/5000] Training loss: 0.000495	 Validation loss: 0.010218
# [1870/5000] Training loss: 0.000304	 Validation loss: 0.009090
# [1875/5000] Training loss: 0.000324	 Validation loss: 0.010267
# [1880/5000] Training loss: 0.000241	 Validation loss: 0.010069
# [1885/5000] Training loss: 0.000460	 Validation loss: 0.011327
# [1890/5000] Training loss: 0.000353	 Validation loss: 0.010540
# [1895/5000] Training loss: 0.005664	 Validation loss: 0.010952
# [1900/5000] Training loss: 0.000598	 Validation loss: 0.007558
# [1905/5000] Training loss: 0.000824	 Validation loss: 0.011276
# [1910/5000] Training loss: 0.000684	 Validation loss: 0.008944
# [1915/5000] Training loss: 0.001072	 Validation loss: 0.008413
# [1920/5000] Training loss: 0.002875	 Validation loss: 0.008190
# [1925/5000] Training loss: 0.002374	 Validation loss: 0.010243
# [1930/5000] Training loss: 0.000703	 Validation loss: 0.008061
# [1935/5000] Training loss: 0.001524	 Validation loss: 0.012500
# [1940/5000] Training loss: 0.001444	 Validation loss: 0.007926
# [1945/5000] Training loss: 0.000341	 Validation loss: 0.008465
# [1950/5000] Training loss: 0.000489	 Validation loss: 0.009789
# [1955/5000] Training loss: 0.000276	 Validation loss: 0.008414
# [1960/5000] Training loss: 0.002122	 Validation loss: 0.008528
# [1965/5000] Training loss: 0.008982	 Validation loss: 0.012829
# [1970/5000] Training loss: 0.000722	 Validation loss: 0.008909
# [1975/5000] Training loss: 0.000338	 Validation loss: 0.008830
# [1980/5000] Training loss: 0.000251	 Validation loss: 0.009866
# [1985/5000] Training loss: 0.000293	 Validation loss: 0.008562
# [1990/5000] Training loss: 0.000241	 Validation loss: 0.009542
# [1995/5000] Training loss: 0.000390	 Validation loss: 0.008304
# [2000/5000] Training loss: 0.000307	 Validation loss: 0.009743
# [2005/5000] Training loss: 0.002934	 Validation loss: 0.008544
# [2010/5000] Training loss: 0.003178	 Validation loss: 0.010859
# [2015/5000] Training loss: 0.002240	 Validation loss: 0.012089
# [2020/5000] Training loss: 0.001052	 Validation loss: 0.008207
# [2025/5000] Training loss: 0.001278	 Validation loss: 0.007093
# [2030/5000] Training loss: 0.000380	 Validation loss: 0.008483
# [2035/5000] Training loss: 0.000847	 Validation loss: 0.009173
# [2040/5000] Training loss: 0.001152	 Validation loss: 0.008725
# [2045/5000] Training loss: 0.000291	 Validation loss: 0.008638
# [2050/5000] Training loss: 0.000225	 Validation loss: 0.009056
# [2055/5000] Training loss: 0.000222	 Validation loss: 0.008152
# [2060/5000] Training loss: 0.001109	 Validation loss: 0.008628
# [2065/5000] Training loss: 0.002880	 Validation loss: 0.012894
# [2070/5000] Training loss: 0.000736	 Validation loss: 0.008784
# [2075/5000] Training loss: 0.000479	 Validation loss: 0.008863
# [2080/5000] Training loss: 0.000607	 Validation loss: 0.008102
# [2085/5000] Training loss: 0.000218	 Validation loss: 0.008812
# [2090/5000] Training loss: 0.000605	 Validation loss: 0.008637
# [2095/5000] Training loss: 0.001620	 Validation loss: 0.012816
# [2100/5000] Training loss: 0.003440	 Validation loss: 0.008465
# [2105/5000] Training loss: 0.000928	 Validation loss: 0.008931
# [2110/5000] Training loss: 0.001727	 Validation loss: 0.010244
# [2115/5000] Training loss: 0.003761	 Validation loss: 0.009574
# [2120/5000] Training loss: 0.000857	 Validation loss: 0.008520
# [2125/5000] Training loss: 0.000513	 Validation loss: 0.010011
# [2130/5000] Training loss: 0.000234	 Validation loss: 0.008425
# [2135/5000] Training loss: 0.000233	 Validation loss: 0.008853
# [2140/5000] Training loss: 0.000222	 Validation loss: 0.008572
# [2145/5000] Training loss: 0.009858	 Validation loss: 0.039165
# [2150/5000] Training loss: 0.001378	 Validation loss: 0.009275
# [2155/5000] Training loss: 0.001264	 Validation loss: 0.010546
# [2160/5000] Training loss: 0.000583	 Validation loss: 0.007872
# [2165/5000] Training loss: 0.000296	 Validation loss: 0.007307
# [2170/5000] Training loss: 0.000250	 Validation loss: 0.007731
# [2175/5000] Training loss: 0.000248	 Validation loss: 0.007089
# [2180/5000] Training loss: 0.002998	 Validation loss: 0.015844
# [2185/5000] Training loss: 0.000567	 Validation loss: 0.008390
# [2190/5000] Training loss: 0.000429	 Validation loss: 0.009668
# [2195/5000] Training loss: 0.001965	 Validation loss: 0.010308
# [2200/5000] Training loss: 0.000532	 Validation loss: 0.009552
# [2205/5000] Training loss: 0.000273	 Validation loss: 0.009825
# [2210/5000] Training loss: 0.000241	 Validation loss: 0.007724
# [2215/5000] Training loss: 0.000233	 Validation loss: 0.008102
# [2220/5000] Training loss: 0.000544	 Validation loss: 0.008699
# [2225/5000] Training loss: 0.000687	 Validation loss: 0.011020
# [2230/5000] Training loss: 0.002292	 Validation loss: 0.010064
# [2235/5000] Training loss: 0.021245	 Validation loss: 0.010524
# [2240/5000] Training loss: 0.012746	 Validation loss: 0.033592
# [2245/5000] Training loss: 0.019665	 Validation loss: 0.012660
# [2250/5000] Training loss: 0.008205	 Validation loss: 0.017720
# [2255/5000] Training loss: 0.002656	 Validation loss: 0.010591
# [2260/5000] Training loss: 0.014125	 Validation loss: 0.059673
# [2265/5000] Training loss: 0.015917	 Validation loss: 0.029434
# [2270/5000] Training loss: 0.008438	 Validation loss: 0.012129
# [2275/5000] Training loss: 0.005848	 Validation loss: 0.008323
# [2280/5000] Training loss: 0.000637	 Validation loss: 0.008133
# [2285/5000] Training loss: 0.003465	 Validation loss: 0.021708
# [2290/5000] Training loss: 0.008744	 Validation loss: 0.004869
# [2295/5000] Training loss: 0.005349	 Validation loss: 0.008955
# [2300/5000] Training loss: 0.002857	 Validation loss: 0.009079
# [2305/5000] Training loss: 0.001319	 Validation loss: 0.010155
# [2310/5000] Training loss: 0.001716	 Validation loss: 0.011014
# [2315/5000] Training loss: 0.000922	 Validation loss: 0.009743
# [2320/5000] Training loss: 0.000893	 Validation loss: 0.008698
# [2325/5000] Training loss: 0.001348	 Validation loss: 0.010397
# [2330/5000] Training loss: 0.000931	 Validation loss: 0.011148
# [2335/5000] Training loss: 0.000447	 Validation loss: 0.009092
# [2340/5000] Training loss: 0.001409	 Validation loss: 0.008064
# [2345/5000] Training loss: 0.001373	 Validation loss: 0.006266
# [2350/5000] Training loss: 0.001303	 Validation loss: 0.008835
# [2355/5000] Training loss: 0.001614	 Validation loss: 0.008282
# [2360/5000] Training loss: 0.012504	 Validation loss: 0.012098
# [2365/5000] Training loss: 0.003651	 Validation loss: 0.019045
# [2370/5000] Training loss: 0.001049	 Validation loss: 0.017066
# [2375/5000] Training loss: 0.001273	 Validation loss: 0.010617
# [2380/5000] Training loss: 0.002885	 Validation loss: 0.022047
# [2385/5000] Training loss: 0.001996	 Validation loss: 0.016820
# [2390/5000] Training loss: 0.001567	 Validation loss: 0.014436
# [2395/5000] Training loss: 0.000914	 Validation loss: 0.013886
# [2400/5000] Training loss: 0.000913	 Validation loss: 0.010674
# [2405/5000] Training loss: 0.002209	 Validation loss: 0.009895
# [2410/5000] Training loss: 0.000767	 Validation loss: 0.009785
# [2415/5000] Training loss: 0.001310	 Validation loss: 0.014068
# [2420/5000] Training loss: 0.005213	 Validation loss: 0.015325
# [2425/5000] Training loss: 0.000864	 Validation loss: 0.012355
# [2430/5000] Training loss: 0.001163	 Validation loss: 0.013268
# [2435/5000] Training loss: 0.001283	 Validation loss: 0.012260
# [2440/5000] Training loss: 0.001334	 Validation loss: 0.010020
# [2445/5000] Training loss: 0.001299	 Validation loss: 0.011844
# [2450/5000] Training loss: 0.003147	 Validation loss: 0.016092
# [2455/5000] Training loss: 0.004310	 Validation loss: 0.048295
# [2460/5000] Training loss: 0.002970	 Validation loss: 0.019514
# [2465/5000] Training loss: 0.002576	 Validation loss: 0.006894
# [2470/5000] Training loss: 0.000972	 Validation loss: 0.007074
# [2475/5000] Training loss: 0.000587	 Validation loss: 0.006549
# [2480/5000] Training loss: 0.003948	 Validation loss: 0.016956
# [2485/5000] Training loss: 0.000563	 Validation loss: 0.006512
# [2490/5000] Training loss: 0.000464	 Validation loss: 0.007723
# [2495/5000] Training loss: 0.000293	 Validation loss: 0.007288
# [2500/5000] Training loss: 0.000947	 Validation loss: 0.008576
# [2505/5000] Training loss: 0.000175	 Validation loss: 0.007706
# [2510/5000] Training loss: 0.002161	 Validation loss: 0.013429
# [2515/5000] Training loss: 0.002014	 Validation loss: 0.007495
# [2520/5000] Training loss: 0.000239	 Validation loss: 0.008094
# [2525/5000] Training loss: 0.000990	 Validation loss: 0.006578
# [2530/5000] Training loss: 0.000956	 Validation loss: 0.007600
# [2535/5000] Training loss: 0.004333	 Validation loss: 0.014237
# [2540/5000] Training loss: 0.009366	 Validation loss: 0.021873
# [2545/5000] Training loss: 0.001998	 Validation loss: 0.009717
# [2550/5000] Training loss: 0.005378	 Validation loss: 0.006465
# [2555/5000] Training loss: 0.003590	 Validation loss: 0.008885
# [2560/5000] Training loss: 0.002872	 Validation loss: 0.011913
# [2565/5000] Training loss: 0.001517	 Validation loss: 0.010063
# [2570/5000] Training loss: 0.000948	 Validation loss: 0.008432
# [2575/5000] Training loss: 0.000298	 Validation loss: 0.008184
# [2580/5000] Training loss: 0.000225	 Validation loss: 0.009540
# [2585/5000] Training loss: 0.000306	 Validation loss: 0.009225
# [2590/5000] Training loss: 0.000360	 Validation loss: 0.008608
# [2595/5000] Training loss: 0.000456	 Validation loss: 0.010405
# [2600/5000] Training loss: 0.001039	 Validation loss: 0.009262
# [2605/5000] Training loss: 0.000295	 Validation loss: 0.009674
# [2610/5000] Training loss: 0.000275	 Validation loss: 0.007994
# [2615/5000] Training loss: 0.000901	 Validation loss: 0.010144
# [2620/5000] Training loss: 0.002594	 Validation loss: 0.019454
# [2625/5000] Training loss: 0.000572	 Validation loss: 0.012350
# [2630/5000] Training loss: 0.000471	 Validation loss: 0.010474
# [2635/5000] Training loss: 0.001436	 Validation loss: 0.013787
# [2640/5000] Training loss: 0.000425	 Validation loss: 0.010523
# [2645/5000] Training loss: 0.000297	 Validation loss: 0.008992
# [2650/5000] Training loss: 0.000449	 Validation loss: 0.008512
# [2655/5000] Training loss: 0.001227	 Validation loss: 0.014270
# [2660/5000] Training loss: 0.000272	 Validation loss: 0.008836
# [2665/5000] Training loss: 0.000261	 Validation loss: 0.009154
# [2670/5000] Training loss: 0.000221	 Validation loss: 0.009054
# [2675/5000] Training loss: 0.004835	 Validation loss: 0.008906
# [2680/5000] Training loss: 0.000810	 Validation loss: 0.010120
# [2685/5000] Training loss: 0.000941	 Validation loss: 0.011778
# [2690/5000] Training loss: 0.000641	 Validation loss: 0.009099
# [2695/5000] Training loss: 0.000188	 Validation loss: 0.009942
# [2700/5000] Training loss: 0.000112	 Validation loss: 0.008914
# [2705/5000] Training loss: 0.000156	 Validation loss: 0.009784
# [2710/5000] Training loss: 0.000149	 Validation loss: 0.007762
# [2715/5000] Training loss: 0.001881	 Validation loss: 0.011512
# [2720/5000] Training loss: 0.001289	 Validation loss: 0.009081
# [2725/5000] Training loss: 0.000577	 Validation loss: 0.009349
# [2730/5000] Training loss: 0.001043	 Validation loss: 0.009624
# [2735/5000] Training loss: 0.000359	 Validation loss: 0.012642
# [2740/5000] Training loss: 0.002419	 Validation loss: 0.007435
# [2745/5000] Training loss: 0.001116	 Validation loss: 0.010258
# [2750/5000] Training loss: 0.000694	 Validation loss: 0.007586
# [2755/5000] Training loss: 0.000689	 Validation loss: 0.011431
# [2760/5000] Training loss: 0.000517	 Validation loss: 0.008624
# [2765/5000] Training loss: 0.000605	 Validation loss: 0.009192
# [2770/5000] Training loss: 0.001385	 Validation loss: 0.007574
# [2775/5000] Training loss: 0.010513	 Validation loss: 0.012128
# [2780/5000] Training loss: 0.000443	 Validation loss: 0.008045
# [2785/5000] Training loss: 0.001305	 Validation loss: 0.009862
# [2790/5000] Training loss: 0.003146	 Validation loss: 0.008322
# [2795/5000] Training loss: 0.008288	 Validation loss: 0.011970
# [2800/5000] Training loss: 0.000734	 Validation loss: 0.008967
# [2805/5000] Training loss: 0.000509	 Validation loss: 0.007511
# [2810/5000] Training loss: 0.001471	 Validation loss: 0.007732
# [2815/5000] Training loss: 0.002303	 Validation loss: 0.012315
# [2820/5000] Training loss: 0.004304	 Validation loss: 0.013949
# [2825/5000] Training loss: 0.000514	 Validation loss: 0.008960
# [2830/5000] Training loss: 0.000488	 Validation loss: 0.008795
# [2835/5000] Training loss: 0.000249	 Validation loss: 0.009123
# [2840/5000] Training loss: 0.000230	 Validation loss: 0.008282
# [2845/5000] Training loss: 0.000204	 Validation loss: 0.010127
# [2850/5000] Training loss: 0.000497	 Validation loss: 0.009470
# [2855/5000] Training loss: 0.000623	 Validation loss: 0.010586
# [2860/5000] Training loss: 0.000133	 Validation loss: 0.009536
# [2865/5000] Training loss: 0.000190	 Validation loss: 0.009742
# [2870/5000] Training loss: 0.000203	 Validation loss: 0.008921
# [2875/5000] Training loss: 0.000222	 Validation loss: 0.009368
# [2880/5000] Training loss: 0.002249	 Validation loss: 0.008915
# [2885/5000] Training loss: 0.000329	 Validation loss: 0.008938
# [2890/5000] Training loss: 0.001021	 Validation loss: 0.008542
# [2895/5000] Training loss: 0.000290	 Validation loss: 0.008690
# [2900/5000] Training loss: 0.001180	 Validation loss: 0.010149
# [2905/5000] Training loss: 0.001296	 Validation loss: 0.007837
# [2910/5000] Training loss: 0.000579	 Validation loss: 0.009692
# [2915/5000] Training loss: 0.000126	 Validation loss: 0.008659
# [2920/5000] Training loss: 0.000317	 Validation loss: 0.008673
# [2925/5000] Training loss: 0.000182	 Validation loss: 0.008507
# [2930/5000] Training loss: 0.000334	 Validation loss: 0.008485
# [2935/5000] Training loss: 0.000730	 Validation loss: 0.010350
# [2940/5000] Training loss: 0.000247	 Validation loss: 0.009287
# [2945/5000] Training loss: 0.000182	 Validation loss: 0.008399
# [2950/5000] Training loss: 0.000324	 Validation loss: 0.010727
# [2955/5000] Training loss: 0.000766	 Validation loss: 0.009076
# [2960/5000] Training loss: 0.000445	 Validation loss: 0.008896
# [2965/5000] Training loss: 0.008309	 Validation loss: 0.014312
# [2970/5000] Training loss: 0.000899	 Validation loss: 0.008722
# [2975/5000] Training loss: 0.014209	 Validation loss: 0.015264
# [2980/5000] Training loss: 0.000519	 Validation loss: 0.009632
# [2985/5000] Training loss: 0.000227	 Validation loss: 0.009805
# [2990/5000] Training loss: 0.000551	 Validation loss: 0.008489
# [2995/5000] Training loss: 0.000232	 Validation loss: 0.009264
# [3000/5000] Training loss: 0.000234	 Validation loss: 0.009170
# [3005/5000] Training loss: 0.000113	 Validation loss: 0.008572
# [3010/5000] Training loss: 0.000149	 Validation loss: 0.008562
# [3015/5000] Training loss: 0.000160	 Validation loss: 0.009049
# [3020/5000] Training loss: 0.003284	 Validation loss: 0.009674
# [3025/5000] Training loss: 0.001809	 Validation loss: 0.008064
# [3030/5000] Training loss: 0.000245	 Validation loss: 0.008576
# [3035/5000] Training loss: 0.000128	 Validation loss: 0.009407
# [3040/5000] Training loss: 0.000345	 Validation loss: 0.009049
# [3045/5000] Training loss: 0.000398	 Validation loss: 0.008915
# [3050/5000] Training loss: 0.000254	 Validation loss: 0.008404
# [3055/5000] Training loss: 0.000119	 Validation loss: 0.008505
# [3060/5000] Training loss: 0.000400	 Validation loss: 0.011823
# [3065/5000] Training loss: 0.001304	 Validation loss: 0.008481
# [3070/5000] Training loss: 0.000195	 Validation loss: 0.007945
# [3075/5000] Training loss: 0.001736	 Validation loss: 0.008052
# [3080/5000] Training loss: 0.000271	 Validation loss: 0.008398
# [3085/5000] Training loss: 0.003151	 Validation loss: 0.010633
# [3090/5000] Training loss: 0.002536	 Validation loss: 0.010023
# [3095/5000] Training loss: 0.001332	 Validation loss: 0.008255
# [3100/5000] Training loss: 0.000170	 Validation loss: 0.008215
# [3105/5000] Training loss: 0.000508	 Validation loss: 0.007269
# [3110/5000] Training loss: 0.000160	 Validation loss: 0.007560
# [3115/5000] Training loss: 0.000447	 Validation loss: 0.009607
# [3120/5000] Training loss: 0.000831	 Validation loss: 0.009410
# [3125/5000] Training loss: 0.000175	 Validation loss: 0.009333
# [3130/5000] Training loss: 0.000103	 Validation loss: 0.008581
# [3135/5000] Training loss: 0.000133	 Validation loss: 0.007902
# [3140/5000] Training loss: 0.000277	 Validation loss: 0.008715
# [3145/5000] Training loss: 0.000238	 Validation loss: 0.008946
# [3150/5000] Training loss: 0.001891	 Validation loss: 0.010003
# [3155/5000] Training loss: 0.010775	 Validation loss: 0.017479
# [3160/5000] Training loss: 0.000597	 Validation loss: 0.008172
# [3165/5000] Training loss: 0.000199	 Validation loss: 0.008488
# [3170/5000] Training loss: 0.000128	 Validation loss: 0.008709
# [3175/5000] Training loss: 0.014372	 Validation loss: 0.030087
# [3180/5000] Training loss: 0.000807	 Validation loss: 0.010486
# [3185/5000] Training loss: 0.000209	 Validation loss: 0.007544
# [3190/5000] Training loss: 0.000146	 Validation loss: 0.008397
# [3195/5000] Training loss: 0.000097	 Validation loss: 0.007882
# [3200/5000] Training loss: 0.000135	 Validation loss: 0.008681
# [3205/5000] Training loss: 0.000093	 Validation loss: 0.008420
# [3210/5000] Training loss: 0.000108	 Validation loss: 0.007971
# [3215/5000] Training loss: 0.000075	 Validation loss: 0.008416
# [3220/5000] Training loss: 0.000077	 Validation loss: 0.008117
# [3225/5000] Training loss: 0.002303	 Validation loss: 0.007756
# [3230/5000] Training loss: 0.002982	 Validation loss: 0.008494
# [3235/5000] Training loss: 0.000302	 Validation loss: 0.007747
# [3240/5000] Training loss: 0.000144	 Validation loss: 0.007691
# [3245/5000] Training loss: 0.000168	 Validation loss: 0.008259
# [3250/5000] Training loss: 0.001002	 Validation loss: 0.009899
# [3255/5000] Training loss: 0.031269	 Validation loss: 0.139443
# [3260/5000] Training loss: 0.027283	 Validation loss: 0.012528
# [3265/5000] Training loss: 0.004343	 Validation loss: 0.017783
# [3270/5000] Training loss: 0.010051	 Validation loss: 0.013574
# [3275/5000] Training loss: 0.003018	 Validation loss: 0.012216
# [3280/5000] Training loss: 0.001521	 Validation loss: 0.011308
# [3285/5000] Training loss: 0.001178	 Validation loss: 0.010573
# [3290/5000] Training loss: 0.000905	 Validation loss: 0.009917
# [3295/5000] Training loss: 0.000759	 Validation loss: 0.009983
# [3300/5000] Training loss: 0.000596	 Validation loss: 0.009270
# [3305/5000] Training loss: 0.000528	 Validation loss: 0.009210
# [3310/5000] Training loss: 0.000441	 Validation loss: 0.009723
# [3315/5000] Training loss: 0.000689	 Validation loss: 0.010640
# [3320/5000] Training loss: 0.000478	 Validation loss: 0.010991
# [3325/5000] Training loss: 0.000504	 Validation loss: 0.009806
# [3330/5000] Training loss: 0.000371	 Validation loss: 0.010078
# [3335/5000] Training loss: 0.000347	 Validation loss: 0.010040
# [3340/5000] Training loss: 0.000337	 Validation loss: 0.009336
# [3345/5000] Training loss: 0.000825	 Validation loss: 0.008760
# [3350/5000] Training loss: 0.000621	 Validation loss: 0.010073
# [3355/5000] Training loss: 0.000295	 Validation loss: 0.009213
# [3360/5000] Training loss: 0.000218	 Validation loss: 0.009175
# [3365/5000] Training loss: 0.002361	 Validation loss: 0.007293
# [3370/5000] Training loss: 0.000364	 Validation loss: 0.008816
# [3375/5000] Training loss: 0.000196	 Validation loss: 0.008965
# [3380/5000] Training loss: 0.000242	 Validation loss: 0.009958
# [3385/5000] Training loss: 0.001392	 Validation loss: 0.009763
# [3390/5000] Training loss: 0.002541	 Validation loss: 0.011273
# [3395/5000] Training loss: 0.001327	 Validation loss: 0.008108
# [3400/5000] Training loss: 0.004030	 Validation loss: 0.007795
# [3405/5000] Training loss: 0.000600	 Validation loss: 0.006999
# [3410/5000] Training loss: 0.000293	 Validation loss: 0.007972
# [3415/5000] Training loss: 0.000212	 Validation loss: 0.007360
# [3420/5000] Training loss: 0.000495	 Validation loss: 0.006813
# [3425/5000] Training loss: 0.001841	 Validation loss: 0.007844
# [3430/5000] Training loss: 0.001040	 Validation loss: 0.006540
# [3435/5000] Training loss: 0.000279	 Validation loss: 0.007004
# [3440/5000] Training loss: 0.000228	 Validation loss: 0.007102
# [3445/5000] Training loss: 0.000529	 Validation loss: 0.006413
# [3450/5000] Training loss: 0.000491	 Validation loss: 0.007558
# [3455/5000] Training loss: 0.000642	 Validation loss: 0.007330
# [3460/5000] Training loss: 0.001179	 Validation loss: 0.011922
# [3465/5000] Training loss: 0.000348	 Validation loss: 0.007062
# [3470/5000] Training loss: 0.000339	 Validation loss: 0.006572
# [3475/5000] Training loss: 0.000236	 Validation loss: 0.007285
# [3480/5000] Training loss: 0.000275	 Validation loss: 0.007938
# [3485/5000] Training loss: 0.000462	 Validation loss: 0.007827
# [3490/5000] Training loss: 0.000154	 Validation loss: 0.007554
# [3495/5000] Training loss: 0.000155	 Validation loss: 0.007352
# [3500/5000] Training loss: 0.000135	 Validation loss: 0.007283
# [3505/5000] Training loss: 0.000247	 Validation loss: 0.008085
# [3510/5000] Training loss: 0.000419	 Validation loss: 0.007167
# [3515/5000] Training loss: 0.000341	 Validation loss: 0.007037
# [3520/5000] Training loss: 0.240060	 Validation loss: 0.040602
# [3525/5000] Training loss: 0.010240	 Validation loss: 0.015212
# [3530/5000] Training loss: 0.006672	 Validation loss: 0.011126
# [3535/5000] Training loss: 0.013224	 Validation loss: 0.010397
# [3540/5000] Training loss: 0.003082	 Validation loss: 0.011137
# [3545/5000] Training loss: 0.027067	 Validation loss: 0.031015
# [3550/5000] Training loss: 0.009292	 Validation loss: 0.017375
# [3555/5000] Training loss: 0.007135	 Validation loss: 0.010313
# [3560/5000] Training loss: 0.002405	 Validation loss: 0.010225
# [3565/5000] Training loss: 0.002363	 Validation loss: 0.012841
# [3570/5000] Training loss: 0.002734	 Validation loss: 0.008137
# [3575/5000] Training loss: 0.001769	 Validation loss: 0.015366
# [3580/5000] Training loss: 0.002775	 Validation loss: 0.012618
# [3585/5000] Training loss: 0.001923	 Validation loss: 0.012859
# [3590/5000] Training loss: 0.011264	 Validation loss: 0.039620
# [3595/5000] Training loss: 0.035845	 Validation loss: 0.059059
# [3600/5000] Training loss: 0.017049	 Validation loss: 0.033445
# [3605/5000] Training loss: 0.014548	 Validation loss: 0.026262
# [3610/5000] Training loss: 0.011264	 Validation loss: 0.028185
# [3615/5000] Training loss: 0.012724	 Validation loss: 0.019265
# [3620/5000] Training loss: 0.008782	 Validation loss: 0.028525
# [3625/5000] Training loss: 0.007359	 Validation loss: 0.026939
# [3630/5000] Training loss: 0.004507	 Validation loss: 0.021149
# [3635/5000] Training loss: 0.004144	 Validation loss: 0.019978
# [3640/5000] Training loss: 0.003206	 Validation loss: 0.021154
# [3645/5000] Training loss: 0.002632	 Validation loss: 0.024196
# [3650/5000] Training loss: 0.002572	 Validation loss: 0.021615
# [3655/5000] Training loss: 0.002273	 Validation loss: 0.022953
# [3660/5000] Training loss: 0.002900	 Validation loss: 0.018693
# [3665/5000] Training loss: 0.003001	 Validation loss: 0.018928
# [3670/5000] Training loss: 0.002804	 Validation loss: 0.022071
# [3675/5000] Training loss: 0.002428	 Validation loss: 0.020506
# [3680/5000] Training loss: 0.003950	 Validation loss: 0.019843
# [3685/5000] Training loss: 0.002606	 Validation loss: 0.020586
# [3690/5000] Training loss: 0.001731	 Validation loss: 0.019318
# [3695/5000] Training loss: 0.005566	 Validation loss: 0.019936
# [3700/5000] Training loss: 0.017037	 Validation loss: 0.027741
# [3705/5000] Training loss: 0.006007	 Validation loss: 0.017199
# [3710/5000] Training loss: 0.002372	 Validation loss: 0.016777
# [3715/5000] Training loss: 0.002194	 Validation loss: 0.017810
# [3720/5000] Training loss: 0.002015	 Validation loss: 0.010232
# [3725/5000] Training loss: 0.001187	 Validation loss: 0.013497
# [3730/5000] Training loss: 0.001652	 Validation loss: 0.008773
# [3735/5000] Training loss: 0.002463	 Validation loss: 0.012836
# [3740/5000] Training loss: 0.001036	 Validation loss: 0.015686
# [3745/5000] Training loss: 0.001477	 Validation loss: 0.011682
# [3750/5000] Training loss: 0.001559	 Validation loss: 0.018785
# [3755/5000] Training loss: 0.000943	 Validation loss: 0.016086
# [3760/5000] Training loss: 0.001897	 Validation loss: 0.017317
# [3765/5000] Training loss: 0.001316	 Validation loss: 0.011858
# [3770/5000] Training loss: 0.001625	 Validation loss: 0.017189
# [3775/5000] Training loss: 0.000762	 Validation loss: 0.013125
# [3780/5000] Training loss: 0.000629	 Validation loss: 0.011042
# [3785/5000] Training loss: 0.001044	 Validation loss: 0.009267
# [3790/5000] Training loss: 0.002787	 Validation loss: 0.009085
# [3795/5000] Training loss: 0.001154	 Validation loss: 0.016113
# [3800/5000] Training loss: 0.000977	 Validation loss: 0.015506
# [3805/5000] Training loss: 0.003568	 Validation loss: 0.025239
# [3810/5000] Training loss: 0.002268	 Validation loss: 0.009907
# [3815/5000] Training loss: 0.002227	 Validation loss: 0.006934
# [3820/5000] Training loss: 0.009118	 Validation loss: 0.010760
# [3825/5000] Training loss: 0.000980	 Validation loss: 0.007100
# [3830/5000] Training loss: 0.000923	 Validation loss: 0.007646
# [3835/5000] Training loss: 0.000507	 Validation loss: 0.008023
# [3840/5000] Training loss: 0.000822	 Validation loss: 0.007212
# [3845/5000] Training loss: 0.020188	 Validation loss: 0.010085
# [3850/5000] Training loss: 0.001311	 Validation loss: 0.008781
# [3855/5000] Training loss: 0.001116	 Validation loss: 0.007559
# [3860/5000] Training loss: 0.009889	 Validation loss: 0.030029
# [3865/5000] Training loss: 0.000907	 Validation loss: 0.008558
# [3870/5000] Training loss: 0.000604	 Validation loss: 0.007963
# [3875/5000] Training loss: 0.000582	 Validation loss: 0.008333
# [3880/5000] Training loss: 0.001714	 Validation loss: 0.007068
# [3885/5000] Training loss: 0.009274	 Validation loss: 0.032177
# [3890/5000] Training loss: 0.001396	 Validation loss: 0.013921
# [3895/5000] Training loss: 0.001067	 Validation loss: 0.014770
# [3900/5000] Training loss: 0.001363	 Validation loss: 0.007839
# [3905/5000] Training loss: 0.001239	 Validation loss: 0.006746
# [3910/5000] Training loss: 0.001866	 Validation loss: 0.007439
# [3915/5000] Training loss: 0.000550	 Validation loss: 0.012170
# [3920/5000] Training loss: 0.001363	 Validation loss: 0.010862
# [3925/5000] Training loss: 0.001303	 Validation loss: 0.008684
# [3930/5000] Training loss: 0.000569	 Validation loss: 0.011178
# [3935/5000] Training loss: 0.000477	 Validation loss: 0.011962
# [3940/5000] Training loss: 0.007683	 Validation loss: 0.010051
# [3945/5000] Training loss: 0.010485	 Validation loss: 0.012114
# [3950/5000] Training loss: 0.003532	 Validation loss: 0.020584
# [3955/5000] Training loss: 0.003515	 Validation loss: 0.009950
# [3960/5000] Training loss: 0.004771	 Validation loss: 0.010993
# [3965/5000] Training loss: 0.002131	 Validation loss: 0.012796
# [3970/5000] Training loss: 0.001717	 Validation loss: 0.011075
# [3975/5000] Training loss: 0.001289	 Validation loss: 0.008207
# [3980/5000] Training loss: 0.001445	 Validation loss: 0.008477
# [3985/5000] Training loss: 0.001197	 Validation loss: 0.010908
# [3990/5000] Training loss: 0.001471	 Validation loss: 0.017124
# [3995/5000] Training loss: 0.000668	 Validation loss: 0.010758
# [4000/5000] Training loss: 0.001519	 Validation loss: 0.027219
# [4005/5000] Training loss: 0.001267	 Validation loss: 0.011033
# [4010/5000] Training loss: 0.000689	 Validation loss: 0.011250
# [4015/5000] Training loss: 0.000688	 Validation loss: 0.007939
# [4020/5000] Training loss: 0.000422	 Validation loss: 0.007349
# [4025/5000] Training loss: 0.001441	 Validation loss: 0.012101
# [4030/5000] Training loss: 0.001324	 Validation loss: 0.009010
# [4035/5000] Training loss: 0.017686	 Validation loss: 0.009972
# [4040/5000] Training loss: 0.013695	 Validation loss: 0.031317
# [4045/5000] Training loss: 0.001452	 Validation loss: 0.010302
# [4050/5000] Training loss: 0.007880	 Validation loss: 0.010345
# [4055/5000] Training loss: 0.000649	 Validation loss: 0.009229
# [4060/5000] Training loss: 0.001340	 Validation loss: 0.007057
# [4065/5000] Training loss: 0.001556	 Validation loss: 0.006449
# [4070/5000] Training loss: 0.000467	 Validation loss: 0.010492
# [4075/5000] Training loss: 0.000399	 Validation loss: 0.009378
# [4080/5000] Training loss: 0.000244	 Validation loss: 0.007061
# [4085/5000] Training loss: 0.000158	 Validation loss: 0.007213
# [4090/5000] Training loss: 0.000138	 Validation loss: 0.007429
# [4095/5000] Training loss: 0.000339	 Validation loss: 0.006857
# [4100/5000] Training loss: 0.004512	 Validation loss: 0.028701
# [4105/5000] Training loss: 0.001939	 Validation loss: 0.010440
# [4110/5000] Training loss: 0.001343	 Validation loss: 0.007918
# [4115/5000] Training loss: 0.001869	 Validation loss: 0.009392
# [4120/5000] Training loss: 0.000276	 Validation loss: 0.008173
# [4125/5000] Training loss: 0.000369	 Validation loss: 0.011088
# [4130/5000] Training loss: 0.000906	 Validation loss: 0.007762
# [4135/5000] Training loss: 0.000577	 Validation loss: 0.007955
# [4140/5000] Training loss: 0.000247	 Validation loss: 0.009590
# [4145/5000] Training loss: 0.004423	 Validation loss: 0.013240
# [4150/5000] Training loss: 0.008342	 Validation loss: 0.012382
# [4155/5000] Training loss: 0.000520	 Validation loss: 0.009530
# [4160/5000] Training loss: 0.001689	 Validation loss: 0.007998
# [4165/5000] Training loss: 0.008358	 Validation loss: 0.154603
# [4170/5000] Training loss: 0.006805	 Validation loss: 0.012118
# [4175/5000] Training loss: 0.007293	 Validation loss: 0.016750
# [4180/5000] Training loss: 0.002074	 Validation loss: 0.007456
# [4185/5000] Training loss: 0.000602	 Validation loss: 0.007911
# [4190/5000] Training loss: 0.000353	 Validation loss: 0.008629
# [4195/5000] Training loss: 0.000147	 Validation loss: 0.008318
# [4200/5000] Training loss: 0.000168	 Validation loss: 0.008330
# [4205/5000] Training loss: 0.000850	 Validation loss: 0.007258
# [4210/5000] Training loss: 0.000361	 Validation loss: 0.007638
# [4215/5000] Training loss: 0.000276	 Validation loss: 0.008642
# [4220/5000] Training loss: 0.001930	 Validation loss: 0.001940

# %%
predictions, values = opt.evaluate(test_loader_one, batch_size=1)

preds = np.array(predictions)
vals = np.array(values)

preds = np.reshape(preds, (5, 576, 384))
vals = np.reshape(vals, (5, 576, 384))

print(preds.shape, vals.shape)
# Out:
# (5, 576, 384) (5, 576, 384)

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[0, :, :].transpose() - vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[1, :, :].transpose() - vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[2, :, :].transpose() - vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[3, :, :].transpose() - vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[4, :, :].transpose() - vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
torch.save(model.state_dict(), 'Saved models/0SA4+Unet512')

# %%
savfig_p = np.reshape(preds, (5, 576*384))
savfig_t = np.reshape(vals, (5, 576*384))

savfig_p = pd.DataFrame(savfig_p)
savfig_t = pd.DataFrame(savfig_t)

savfig_p.to_csv('CSVs/0SA4+Unet512.csv', index=False)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def calculate_metrics(df1, df2):
    return {'mae' : mean_absolute_error(df1, df2),
            'rmse' : mean_squared_error(df1, df2) ** 0.5,
            'r2' : r2_score(df1, df2)}

# %%
result_metrics = calculate_metrics(savfig_t, savfig_p)
result_metrics
# Out:
# {'mae': 0.008371211, 'rmse': 0.04404702337087113, 'r2': -1.9553288543371379}
