# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.interpolate import griddata
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import datetime
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, TensorDataset, DataLoader

#PyTorch random number generator
torch.manual_seed(3407)
torch.cuda.manual_seed(3407)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
print(device)
# Out:
# cuda

# %%
bc_fine = np.zeros(((45, 168, 4)))

for i in range (45):
    df1 = pd.read_csv('C:/Users/59713/BC2MAP/inputs/case_{}.csv'.format(i+1))
    data1 = df1.values
    bc_fine[i, :, :] = data1

# %%
D_3d_fine = np.zeros(((45, 576, 384)))

for i in range (45):
    df2 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_{}.csv'.format(i))
    data2 = df2.values
    D_3d_fine[i, :, :] = np.reshape(data2[:, 5], (576, 384))

# %%
E_3d_fine = np.zeros((576, 384))
X_3d_fine = np.zeros((576, 384))
Y_3d_fine = np.zeros((576, 384))
S_3d_fine = np.zeros((576, 384))
map4all = np.zeros((576, 384))

df3 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_45.csv')
data3 = df3.values
X_3d_fine[:, :] = np.reshape(data3[:, 0], (576, 384))
Y_3d_fine[:, :] = np.reshape(data3[:, 1], (576, 384))
E_3d_fine[:, :] = np.reshape(data3[:, 3], (576, 384))
map4all[:, :] = np.reshape(data3[:, 5], (576, 384))

# %%
dzdx = np.zeros((576, 384))
dzdy = np.zeros((576, 384))

# calculate internal cell slope
for i in range (1, S_3d_fine.shape[0]-1):
    for j in range (1, S_3d_fine.shape[1]-1):
        dzdx[i, j] = ((E_3d_fine[i+1, j-1]+2*E_3d_fine[i+1, j]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i-1, j]+2*E_3d_fine[i-1, j+1]))/(8*(X_3d_fine[i+1, j]-X_3d_fine[i-1, j]))
        dzdy[i, j] = ((E_3d_fine[i-1, j+1]+2*E_3d_fine[i, j+1]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i, j-1]+2*E_3d_fine[i+1, j-1]))/(8*(Y_3d_fine[i, j+1]-Y_3d_fine[i, j-1]))
        S_3d_fine[i, j] = np.arctan(np.sqrt((dzdx[i, j])**2+(dzdy[i, j])**2))
        
# take care of the most oustside layer
S_3d_fine[0, :] = S_3d_fine[1, :]
S_3d_fine[-1, :] = S_3d_fine[-2, :]
S_3d_fine[:, 0] = S_3d_fine[:, 1]
S_3d_fine[:, -1] = S_3d_fine[:, -2]

# %% [markdown]
# ### make a 3D info

# %%
all_data_X = bc_fine
all_data_Y = D_3d_fine

# %%
print(all_data_X.shape, all_data_Y.shape)
# Out:
# (45, 168, 4) (45, 576, 384)

# %%
# split into train and test
train_X, test_X = all_data_X[:-5, :], all_data_X[-5:, :]
train_y, test_y = all_data_Y[:-5, :, :], all_data_Y[-5:, :, :]

# %%
batch_size = 1

train_features = torch.Tensor(train_X).to(device)
train_targets = torch.Tensor(train_y).to(device)
test_features = torch.Tensor(test_X).to(device)
test_targets = torch.Tensor(test_y).to(device)

train = TensorDataset(train_features, train_targets)
test = TensorDataset(test_features, test_targets)

train_loader = DataLoader(train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader_one = DataLoader(test, batch_size=1, shuffle=False, drop_last=True)

# %%
sup_feat = np.zeros(((batch_size, 3, 576, 384)))

# first channel is mapforall
sup_feat[:, 0, :, :] = map4all
# second channel is elevation
sup_feat[:, 1, :, :] = E_3d_fine
# third channel is slope
sup_feat[:, 2, :, :] = S_3d_fine
# fourth channel left for bc info after SA

# %%
class Self_Attention(nn.Module):
    def __init__(self):
        super(Self_Attention, self).__init__()
        
        self.embed_dim = 576*384//64
        self.num_heads = 1
        self.head_dim = self.embed_dim // self.num_heads
        
        self.value = nn.Linear(self.embed_dim, self.embed_dim)
        self.key = nn.Linear(self.embed_dim, self.embed_dim)
        self.query = nn.Linear(self.embed_dim, self.embed_dim)
                    
    def forward(self, x):
        queries = self.query(x)
        keys = self.key(x)
        values = self.value(x)
        
        batch_size, seq_len, embed_dim = x.size()
        # Reshape query, key, and value to split into multiple heads
        queries = queries.view(batch_size, seq_len, self.num_heads, self.head_dim)
        keys = keys.view(batch_size, seq_len, self.num_heads, self.head_dim)
        values = values.view(batch_size, seq_len, self.num_heads, self.head_dim)
        
        # Transpose to prepare for scaled dot-product attention
        queries = queries.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        keys = keys.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        values = values.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        
        # Apply softmax to get attention probabilities
        attention_scores = torch.matmul(queries, keys.transpose(-2, -1)) / (self.head_dim**0.5)
        attention_probs = F.softmax(attention_scores, dim=-1)
        
        # Compute the weighted sum of values
        x = torch.matmul(attention_probs, values)
        
        # Reshape and concatenate heads
        x = x.transpose(1, 2)
        
        out = x.reshape(x.size(0), seq_len, embed_dim)
        
        return out

# %%
class BC2Map(nn.Module):
    def __init__(self, input_size, output_size, background_map, batch_size):
        super(BC2Map, self).__init__()
        
        self.background_map = torch.Tensor(background_map).to(device)
        
        self.input_size = input_size
        self.hidden_dim = output_size
        batch_size = batch_size
                
        self.fc1 = nn.Linear(input_size*3, self.hidden_dim)
        self.fc2 = nn.Linear(input_size, self.hidden_dim)
        
        ##-----------end of embedding ---------##
        ##-----------start of Unet ---------##
        
        self.conv1 = nn.Conv2d(in_channels=5, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv7 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv9 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1)
        self.conv10 = nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1)
        
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        
        self.conv_transpose0 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2, padding=0)
        self.conv_transpose1 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2, padding=0)
        self.conv_transpose2 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2, padding=0)
        self.conv_transpose3 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2, padding=0)
        self.conv_transpose4 = nn.ConvTranspose2d(in_channels=64, out_channels=1, kernel_size=3, stride=1, padding=1)
        
    def forward(self, x):
        # change dimension, maybe it's better to use embedding
        x = x.transpose(1, 2)
        x1 = x[:, :3, :].reshape(x.size(0), 1, -1)
        x1 = self.relu(self.fc1(x1))
        x2 = x[:, 3:, :]
        x2 = self.relu(self.fc2(x2))
        
        x = torch.cat((x1, x2), dim=1)
        x = x.view(x.size(0), x.size(1), 576, 384)
        
        # Concat the full feature map
        x = torch.cat((x, self.background_map), dim=1)
        
        # initial conv: 1->64
        x = self.relu(self.conv1(x))
        
        # 1st resblock: 64->64
        identity = x
        x = self.conv2(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = x + identity
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 2nd resblock: 64->128
        identity2 = x
        x = self.conv3(x)
        x = self.relu(x)
        x = self.conv4(x)
        identity2 = self.conv3(identity2)
        x = x + identity2
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 3rd resblock: 128->256
        identity3 = x
        x = self.conv5(x)
        x = self.relu(x)
        x = self.conv6(x)
        identity3 = self.conv5(identity3)
        x = x + identity3
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 4th resblock: 256->512
        identity4 = x
        x = self.conv7(x)
        x = self.relu(x)
        x = self.conv8(x)
        identity4 = self.conv7(identity4)
        x = x + identity4
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 5th resblock: 512->1024
        identity5 = x
        x = self.conv9(x)
        x = self.relu(x)
        x = self.conv10(x)
        identity5 = self.conv9(identity5)
        x = x + identity5
        x = self.relu(x)
        
        # transpose0: 1024->512
        x = self.relu(self.conv_transpose0(x))
        identity6 = x
        x = self.conv8(x)
        x = self.relu(x)
        x = self.conv8(x)
        x = x + identity6
        
        # transpose1: 512->256
        x = self.relu(self.conv_transpose1(x))
        identity7 = x
        x = self.conv6(x)
        x = self.relu(x)
        x = self.conv6(x)
        x = x + identity7
        
        # transpose2: 256->128
        x = self.relu(self.conv_transpose2(x))
        identity8 = x
        x = self.conv4(x)
        x = self.relu(x)
        x = self.conv4(x)
        x = x + identity8
        
        # transpose3: 128->64
        x = self.relu(self.conv_transpose3(x))
        identity9 = x
        x = self.conv2(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = x + identity9
        
        # transpose4: 64->1
        x = self.relu(self.conv_transpose4(x))
        
        out = x.reshape(x.size(0), -1)
        
        return out

# %%
class Optimization:
    def __init__(self, model, optimizer):
        self.model = model
        self.loss_fn = nn.MSELoss(reduction="mean")
        self.optimizer = optimizer
        self.train_losses = []
        self.val_losses = []
    
    def train_step(self, x, y):
        # Sets model to train mode
        self.model.train()

        # Makes predictions
        yhat = self.model(x)

        # Computes loss
        loss = self.loss_fn(y, yhat)

        # Computes gradients
        loss.backward()

        # Updates parameters and zeroes gradients
        self.optimizer.step()
        self.optimizer.zero_grad()

        # Returns the loss
        return loss.item()

    def train(self, train_loader, val_loader, batch_size=4, n_epochs=50):
        model_path = f'models/{self.model}_{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'

        for epoch in range(1, n_epochs + 1):
            batch_losses = []
            for x_batch, y_batch in train_loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.view([batch_size, 576*384]).to(device)
                loss = self.train_step(x_batch, y_batch)
                batch_losses.append(loss)
            training_loss = np.mean(batch_losses)
            self.train_losses.append(training_loss)

            with torch.no_grad():
                batch_val_losses = []
                for x_val, y_val in val_loader:
                    x_val = x_val.to(device)
                    y_val = y_val.view([batch_size, 576*384]).to(device)
                    self.model.eval()
                    yhat = self.model(x_val).to(device)
                    val_loss = self.loss_fn(y_val, yhat).item()
                    batch_val_losses.append(val_loss)
                validation_loss = np.mean(batch_val_losses)
                self.val_losses.append(validation_loss)

            if (epoch % 5 == 0):
                print(
                    f"[{epoch}/{n_epochs}] Training loss: {training_loss:.6f}\t Validation loss: {validation_loss:.6f}"
                )

#         torch.save(self.model.state_dict(), model_path)

    def evaluate(self, test_loader, batch_size=1):
        with torch.no_grad():
            predictions = []
            values = []
            for x_test, y_test in test_loader:
                x_test = x_test.to(device)
                y_test = y_test.view([batch_size, 576*384]).to(device)
                self.model.eval()
                yhat = self.model(x_test)
                predictions.append(yhat.cpu().detach().numpy())
                values.append(y_test.cpu().detach().numpy())

        return predictions, values

    def plot_losses(self):
        plt.plot(self.train_losses, label="Training loss")
        plt.plot(self.val_losses, label="Validation loss")
        plt.legend()
        plt.title("Losses")
        plt.show()
        plt.close()

# %%
input_size = 672//4
output_size = 576 * 384

batch_size = batch_size
n_epochs = 3000
learning_rate = 1e-4
weight_decay = learning_rate/n_epochs

model = BC2Map(input_size, output_size, background_map=sup_feat, batch_size=batch_size).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

opt = Optimization(model=model, optimizer=optimizer)
opt.train(train_loader, test_loader, batch_size=batch_size, n_epochs=n_epochs)
opt.plot_losses()
# Out:
# [5/3000] Training loss: 6.189553	 Validation loss: 6.806521
# [10/3000] Training loss: 3.058589	 Validation loss: 2.632078
# [15/3000] Training loss: 0.560217	 Validation loss: 0.576899
# [20/3000] Training loss: 0.223435	 Validation loss: 0.338185
# [25/3000] Training loss: 0.191585	 Validation loss: 0.321244
# [30/3000] Training loss: 0.183120	 Validation loss: 0.310099
# [35/3000] Training loss: 0.184920	 Validation loss: 0.314527
# [40/3000] Training loss: 0.190472	 Validation loss: 0.332668
# [45/3000] Training loss: 0.205005	 Validation loss: 0.306604
# [50/3000] Training loss: 0.216566	 Validation loss: 0.310226
# [55/3000] Training loss: 0.177295	 Validation loss: 0.283997
# [60/3000] Training loss: 0.172593	 Validation loss: 0.320827
# [65/3000] Training loss: 0.174869	 Validation loss: 0.290992
# [70/3000] Training loss: 0.381376	 Validation loss: 0.720926
# [75/3000] Training loss: 0.692944	 Validation loss: 0.302044
# [80/3000] Training loss: 0.082303	 Validation loss: 0.144738
# [85/3000] Training loss: 0.073479	 Validation loss: 0.142785
# [90/3000] Training loss: 0.072227	 Validation loss: 0.144664
# [95/3000] Training loss: 0.072063	 Validation loss: 0.142136
# [100/3000] Training loss: 0.070439	 Validation loss: 0.140317
# [105/3000] Training loss: 0.070266	 Validation loss: 0.146581
# [110/3000] Training loss: 0.124389	 Validation loss: 0.157419
# [115/3000] Training loss: 0.103832	 Validation loss: 0.199289
# [120/3000] Training loss: 0.091348	 Validation loss: 0.126341
# [125/3000] Training loss: 0.074487	 Validation loss: 0.128464
# [130/3000] Training loss: 0.066805	 Validation loss: 0.123026
# [135/3000] Training loss: 0.068358	 Validation loss: 0.125826
# [140/3000] Training loss: 0.067595	 Validation loss: 0.124391
# [145/3000] Training loss: 0.068967	 Validation loss: 0.129851
# [150/3000] Training loss: 0.092483	 Validation loss: 0.168381
# [155/3000] Training loss: 0.106836	 Validation loss: 0.208931
# [160/3000] Training loss: 0.106390	 Validation loss: 0.122522
# [165/3000] Training loss: 0.095935	 Validation loss: 0.207501
# [170/3000] Training loss: 0.074983	 Validation loss: 0.112296
# [175/3000] Training loss: 0.058389	 Validation loss: 0.102997
# [180/3000] Training loss: 0.062479	 Validation loss: 0.104307
# [185/3000] Training loss: 0.055810	 Validation loss: 0.125428
# [190/3000] Training loss: 0.167371	 Validation loss: 0.141938
# [195/3000] Training loss: 0.087653	 Validation loss: 0.126965
# [200/3000] Training loss: 0.047160	 Validation loss: 0.097538
# [205/3000] Training loss: 0.040415	 Validation loss: 0.076761
# [210/3000] Training loss: 0.039167	 Validation loss: 0.079714
# [215/3000] Training loss: 0.041934	 Validation loss: 0.075224
# [220/3000] Training loss: 0.186719	 Validation loss: 0.231654
# [225/3000] Training loss: 0.054236	 Validation loss: 0.101940
# [230/3000] Training loss: 0.038831	 Validation loss: 0.075054
# [235/3000] Training loss: 0.034767	 Validation loss: 0.081909
# [240/3000] Training loss: 0.031492	 Validation loss: 0.067530
# [245/3000] Training loss: 0.030969	 Validation loss: 0.070895
# [250/3000] Training loss: 0.030320	 Validation loss: 0.067202
# [255/3000] Training loss: 0.029969	 Validation loss: 0.067803
# [260/3000] Training loss: 0.029986	 Validation loss: 0.066075
# [265/3000] Training loss: 0.035074	 Validation loss: 0.069973
# [270/3000] Training loss: 0.039373	 Validation loss: 0.093651
# [275/3000] Training loss: 0.040569	 Validation loss: 0.098832
# [280/3000] Training loss: 0.032283	 Validation loss: 0.061044
# [285/3000] Training loss: 0.033480	 Validation loss: 0.066695
# [290/3000] Training loss: 0.034428	 Validation loss: 0.062998
# [295/3000] Training loss: 0.029194	 Validation loss: 0.064514
# [300/3000] Training loss: 0.075261	 Validation loss: 0.102817
# [305/3000] Training loss: 0.060693	 Validation loss: 0.066800
# [310/3000] Training loss: 0.034207	 Validation loss: 0.060500
# [315/3000] Training loss: 0.025313	 Validation loss: 0.049509
# [320/3000] Training loss: 0.025026	 Validation loss: 0.063698
# [325/3000] Training loss: 0.022844	 Validation loss: 0.050368
# [330/3000] Training loss: 0.023298	 Validation loss: 0.051392
# [335/3000] Training loss: 0.024319	 Validation loss: 0.052175
# [340/3000] Training loss: 0.033578	 Validation loss: 0.057956
# [345/3000] Training loss: 0.030377	 Validation loss: 0.088986
# [350/3000] Training loss: 0.031100	 Validation loss: 0.075088
# [355/3000] Training loss: 0.026091	 Validation loss: 0.048549
# [360/3000] Training loss: 0.058811	 Validation loss: 0.046798
# [365/3000] Training loss: 0.026950	 Validation loss: 0.070578
# [370/3000] Training loss: 0.023582	 Validation loss: 0.066574
# [375/3000] Training loss: 0.019009	 Validation loss: 0.038326
# [380/3000] Training loss: 0.019073	 Validation loss: 0.037812
# [385/3000] Training loss: 0.014770	 Validation loss: 0.030764
# [390/3000] Training loss: 0.016537	 Validation loss: 0.030096
# [395/3000] Training loss: 0.026179	 Validation loss: 0.035019
# [400/3000] Training loss: 0.030077	 Validation loss: 0.112423
# [405/3000] Training loss: 0.028199	 Validation loss: 0.047266
# [410/3000] Training loss: 0.018336	 Validation loss: 0.029528
# [415/3000] Training loss: 0.008854	 Validation loss: 0.021513
# [420/3000] Training loss: 0.012784	 Validation loss: 0.023272
# [425/3000] Training loss: 0.007734	 Validation loss: 0.020647
# [430/3000] Training loss: 0.014826	 Validation loss: 0.047402
# [435/3000] Training loss: 0.018767	 Validation loss: 0.033988
# [440/3000] Training loss: 0.011781	 Validation loss: 0.028161
# [445/3000] Training loss: 0.007677	 Validation loss: 0.022710
# [450/3000] Training loss: 0.010236	 Validation loss: 0.022295
# [455/3000] Training loss: 0.006283	 Validation loss: 0.021917
# [460/3000] Training loss: 0.008534	 Validation loss: 0.017450
# [465/3000] Training loss: 0.009025	 Validation loss: 0.020570
# [470/3000] Training loss: 0.008413	 Validation loss: 0.017898
# [475/3000] Training loss: 0.008137	 Validation loss: 0.023321
# [480/3000] Training loss: 0.015742	 Validation loss: 0.027749
# [485/3000] Training loss: 0.010067	 Validation loss: 0.025345
# [490/3000] Training loss: 0.008223	 Validation loss: 0.020640
# [495/3000] Training loss: 0.008660	 Validation loss: 0.018524
# [500/3000] Training loss: 0.007277	 Validation loss: 0.024033
# [505/3000] Training loss: 0.016170	 Validation loss: 0.023016
# [510/3000] Training loss: 0.005629	 Validation loss: 0.015434
# [515/3000] Training loss: 0.006557	 Validation loss: 0.017217
# [520/3000] Training loss: 0.005984	 Validation loss: 0.018542
# [525/3000] Training loss: 0.007958	 Validation loss: 0.019521
# [530/3000] Training loss: 0.006101	 Validation loss: 0.018761
# [535/3000] Training loss: 0.013238	 Validation loss: 0.029968
# [540/3000] Training loss: 0.011979	 Validation loss: 0.016132
# [545/3000] Training loss: 0.017581	 Validation loss: 0.033759
# [550/3000] Training loss: 0.022177	 Validation loss: 0.043780
# [555/3000] Training loss: 0.013828	 Validation loss: 0.027166
# [560/3000] Training loss: 0.009778	 Validation loss: 0.025111
# [565/3000] Training loss: 0.008567	 Validation loss: 0.022130
# [570/3000] Training loss: 0.007702	 Validation loss: 0.020232
# [575/3000] Training loss: 0.008311	 Validation loss: 0.017672
# [580/3000] Training loss: 0.006211	 Validation loss: 0.014787
# [585/3000] Training loss: 0.005075	 Validation loss: 0.018596
# [590/3000] Training loss: 0.004614	 Validation loss: 0.016918
# [595/3000] Training loss: 0.004938	 Validation loss: 0.015052
# [600/3000] Training loss: 0.005121	 Validation loss: 0.015875
# [605/3000] Training loss: 0.010804	 Validation loss: 0.015363
# [610/3000] Training loss: 0.009971	 Validation loss: 0.018112
# [615/3000] Training loss: 0.006096	 Validation loss: 0.015026
# [620/3000] Training loss: 0.006775	 Validation loss: 0.016951
# [625/3000] Training loss: 0.013575	 Validation loss: 0.018129
# [630/3000] Training loss: 0.003948	 Validation loss: 0.015569
# [635/3000] Training loss: 0.007021	 Validation loss: 0.015684
# [640/3000] Training loss: 0.003508	 Validation loss: 0.013393
# [645/3000] Training loss: 0.004942	 Validation loss: 0.017298
# [650/3000] Training loss: 0.004847	 Validation loss: 0.029179
# [655/3000] Training loss: 0.007385	 Validation loss: 0.018058
# [660/3000] Training loss: 0.008090	 Validation loss: 0.016652
# [665/3000] Training loss: 0.012181	 Validation loss: 0.017417
# [670/3000] Training loss: 0.006068	 Validation loss: 0.015607
# [675/3000] Training loss: 0.003577	 Validation loss: 0.012255
# [680/3000] Training loss: 0.005518	 Validation loss: 0.021431
# [685/3000] Training loss: 0.005711	 Validation loss: 0.012918
# [690/3000] Training loss: 0.005875	 Validation loss: 0.024627
# [695/3000] Training loss: 0.008332	 Validation loss: 0.017009
# [700/3000] Training loss: 0.004028	 Validation loss: 0.013233
# [705/3000] Training loss: 0.003514	 Validation loss: 0.010977
# [710/3000] Training loss: 0.003134	 Validation loss: 0.012858
# [715/3000] Training loss: 0.004197	 Validation loss: 0.019657
# [720/3000] Training loss: 0.012387	 Validation loss: 0.046758
# [725/3000] Training loss: 0.021797	 Validation loss: 0.025878
# [730/3000] Training loss: 0.005330	 Validation loss: 0.019332
# [735/3000] Training loss: 0.003474	 Validation loss: 0.012578
# [740/3000] Training loss: 0.002694	 Validation loss: 0.011779
# [745/3000] Training loss: 0.002448	 Validation loss: 0.012190
# [750/3000] Training loss: 0.002456	 Validation loss: 0.011728
# [755/3000] Training loss: 0.007081	 Validation loss: 0.014131
# [760/3000] Training loss: 0.003202	 Validation loss: 0.011584
# [765/3000] Training loss: 0.002790	 Validation loss: 0.011619
# [770/3000] Training loss: 0.004848	 Validation loss: 0.013501
# [775/3000] Training loss: 0.005124	 Validation loss: 0.012366
# [780/3000] Training loss: 0.003269	 Validation loss: 0.013109
# [785/3000] Training loss: 0.003215	 Validation loss: 0.013441
# [790/3000] Training loss: 0.005024	 Validation loss: 0.020841
# [795/3000] Training loss: 0.004281	 Validation loss: 0.012335
# [800/3000] Training loss: 0.005256	 Validation loss: 0.021313
# [805/3000] Training loss: 0.025689	 Validation loss: 0.027034
# [810/3000] Training loss: 0.008280	 Validation loss: 0.018618
# [815/3000] Training loss: 0.003935	 Validation loss: 0.014382
# [820/3000] Training loss: 0.003378	 Validation loss: 0.010946
# [825/3000] Training loss: 0.003487	 Validation loss: 0.012306
# [830/3000] Training loss: 0.002327	 Validation loss: 0.011733
# [835/3000] Training loss: 0.002416	 Validation loss: 0.010201
# [840/3000] Training loss: 0.004104	 Validation loss: 0.012429
# [845/3000] Training loss: 0.003193	 Validation loss: 0.014319
# [850/3000] Training loss: 0.002111	 Validation loss: 0.011638
# [855/3000] Training loss: 0.005114	 Validation loss: 0.015104
# [860/3000] Training loss: 0.004623	 Validation loss: 0.016192
# [865/3000] Training loss: 0.015457	 Validation loss: 0.013414
# [870/3000] Training loss: 0.004191	 Validation loss: 0.028511
# [875/3000] Training loss: 0.002017	 Validation loss: 0.010636
# [880/3000] Training loss: 0.001936	 Validation loss: 0.012745
# [885/3000] Training loss: 0.003187	 Validation loss: 0.013488
# [890/3000] Training loss: 0.005443	 Validation loss: 0.015986
# [895/3000] Training loss: 0.002793	 Validation loss: 0.008940
# [900/3000] Training loss: 0.003107	 Validation loss: 0.009794
# [905/3000] Training loss: 0.018236	 Validation loss: 0.016948
# [910/3000] Training loss: 0.002302	 Validation loss: 0.009363
# [915/3000] Training loss: 0.001556	 Validation loss: 0.010131
# [920/3000] Training loss: 0.001705	 Validation loss: 0.009568
# [925/3000] Training loss: 0.001495	 Validation loss: 0.009874
# [930/3000] Training loss: 0.001554	 Validation loss: 0.008358
# [935/3000] Training loss: 0.001654	 Validation loss: 0.012883
# [940/3000] Training loss: 0.002696	 Validation loss: 0.011173
# [945/3000] Training loss: 0.020404	 Validation loss: 0.030786
# [950/3000] Training loss: 0.002820	 Validation loss: 0.010116
# [955/3000] Training loss: 0.001506	 Validation loss: 0.010886
# [960/3000] Training loss: 0.001245	 Validation loss: 0.009162
# [965/3000] Training loss: 0.001484	 Validation loss: 0.010053
# [970/3000] Training loss: 0.001597	 Validation loss: 0.007974
# [975/3000] Training loss: 0.001562	 Validation loss: 0.008868
# [980/3000] Training loss: 0.005100	 Validation loss: 0.013070
# [985/3000] Training loss: 0.008950	 Validation loss: 0.011144
# [990/3000] Training loss: 0.006975	 Validation loss: 0.009696
# [995/3000] Training loss: 0.001253	 Validation loss: 0.010013
# [1000/3000] Training loss: 0.001653	 Validation loss: 0.008908
# [1005/3000] Training loss: 0.001057	 Validation loss: 0.008842
# [1010/3000] Training loss: 0.001952	 Validation loss: 0.011215
# [1015/3000] Training loss: 0.002309	 Validation loss: 0.010617
# [1020/3000] Training loss: 0.001850	 Validation loss: 0.010241
# [1025/3000] Training loss: 0.003613	 Validation loss: 0.008935
# [1030/3000] Training loss: 0.002257	 Validation loss: 0.012728
# [1035/3000] Training loss: 0.003546	 Validation loss: 0.014772
# [1040/3000] Training loss: 0.002173	 Validation loss: 0.018905
# [1045/3000] Training loss: 0.005738	 Validation loss: 0.010887
# [1050/3000] Training loss: 0.009286	 Validation loss: 0.012908
# [1055/3000] Training loss: 0.002327	 Validation loss: 0.010413
# [1060/3000] Training loss: 0.001216	 Validation loss: 0.010453
# [1065/3000] Training loss: 0.001153	 Validation loss: 0.008393
# [1070/3000] Training loss: 0.001324	 Validation loss: 0.008683
# [1075/3000] Training loss: 0.000942	 Validation loss: 0.009102
# [1080/3000] Training loss: 0.000937	 Validation loss: 0.009259
# [1085/3000] Training loss: 0.001280	 Validation loss: 0.009479
# [1090/3000] Training loss: 0.002041	 Validation loss: 0.010975
# [1095/3000] Training loss: 0.001087	 Validation loss: 0.008020
# [1100/3000] Training loss: 0.001037	 Validation loss: 0.010779
# [1105/3000] Training loss: 0.002166	 Validation loss: 0.010285
# [1110/3000] Training loss: 0.009444	 Validation loss: 0.011743
# [1115/3000] Training loss: 0.002934	 Validation loss: 0.013517
# [1120/3000] Training loss: 0.001967	 Validation loss: 0.009165
# [1125/3000] Training loss: 0.001568	 Validation loss: 0.009638
# [1130/3000] Training loss: 0.002625	 Validation loss: 0.010745
# [1135/3000] Training loss: 0.006592	 Validation loss: 0.010418
# [1140/3000] Training loss: 0.004118	 Validation loss: 0.008494
# [1145/3000] Training loss: 0.001033	 Validation loss: 0.008680
# [1150/3000] Training loss: 0.001059	 Validation loss: 0.008886
# [1155/3000] Training loss: 0.001070	 Validation loss: 0.007792
# [1160/3000] Training loss: 0.003506	 Validation loss: 0.010712
# [1165/3000] Training loss: 0.001583	 Validation loss: 0.009673
# [1170/3000] Training loss: 0.002986	 Validation loss: 0.035081
# [1175/3000] Training loss: 0.002277	 Validation loss: 0.009141
# [1180/3000] Training loss: 0.002783	 Validation loss: 0.009792
# [1185/3000] Training loss: 0.001158	 Validation loss: 0.010255
# [1190/3000] Training loss: 0.002429	 Validation loss: 0.009854
# [1195/3000] Training loss: 0.002924	 Validation loss: 0.013728
# [1200/3000] Training loss: 0.003154	 Validation loss: 0.016169
# [1205/3000] Training loss: 0.001375	 Validation loss: 0.008596
# [1210/3000] Training loss: 0.001440	 Validation loss: 0.009368
# [1215/3000] Training loss: 0.001732	 Validation loss: 0.012724
# [1220/3000] Training loss: 0.001985	 Validation loss: 0.009947
# [1225/3000] Training loss: 0.003909	 Validation loss: 0.009002
# [1230/3000] Training loss: 0.000998	 Validation loss: 0.008576
# [1235/3000] Training loss: 0.004750	 Validation loss: 0.011951
# [1240/3000] Training loss: 0.001174	 Validation loss: 0.009591
# [1245/3000] Training loss: 0.000861	 Validation loss: 0.012132
# [1250/3000] Training loss: 0.002758	 Validation loss: 0.013726
# [1255/3000] Training loss: 0.003680	 Validation loss: 0.012454
# [1260/3000] Training loss: 0.001236	 Validation loss: 0.010524
# [1265/3000] Training loss: 0.001287	 Validation loss: 0.010708
# [1270/3000] Training loss: 0.000974	 Validation loss: 0.008917
# [1275/3000] Training loss: 0.001279	 Validation loss: 0.010709
# [1280/3000] Training loss: 0.002855	 Validation loss: 0.018047
# [1285/3000] Training loss: 0.002615	 Validation loss: 0.011489
# [1290/3000] Training loss: 0.001610	 Validation loss: 0.011151
# [1295/3000] Training loss: 0.000801	 Validation loss: 0.008716
# [1300/3000] Training loss: 0.000908	 Validation loss: 0.009411
# [1305/3000] Training loss: 0.001826	 Validation loss: 0.010704
# [1310/3000] Training loss: 0.000765	 Validation loss: 0.007701
# [1315/3000] Training loss: 0.001576	 Validation loss: 0.012588
# [1320/3000] Training loss: 0.001801	 Validation loss: 0.010451
# [1325/3000] Training loss: 0.002272	 Validation loss: 0.009290
# [1330/3000] Training loss: 0.001413	 Validation loss: 0.007887
# [1335/3000] Training loss: 0.001181	 Validation loss: 0.009335
# [1340/3000] Training loss: 0.001033	 Validation loss: 0.008436
# [1345/3000] Training loss: 0.001272	 Validation loss: 0.008226
# [1350/3000] Training loss: 0.003332	 Validation loss: 0.008096
# [1355/3000] Training loss: 0.002254	 Validation loss: 0.014992
# [1360/3000] Training loss: 0.002040	 Validation loss: 0.007036
# [1365/3000] Training loss: 0.000961	 Validation loss: 0.007784
# [1370/3000] Training loss: 0.001563	 Validation loss: 0.007645
# [1375/3000] Training loss: 0.001458	 Validation loss: 0.011158
# [1380/3000] Training loss: 0.000627	 Validation loss: 0.007299
# [1385/3000] Training loss: 0.001364	 Validation loss: 0.008651
# [1390/3000] Training loss: 0.001090	 Validation loss: 0.009308
# [1395/3000] Training loss: 0.001281	 Validation loss: 0.008222
# [1400/3000] Training loss: 0.000590	 Validation loss: 0.007915
# [1405/3000] Training loss: 0.001008	 Validation loss: 0.008652
# [1410/3000] Training loss: 0.002213	 Validation loss: 0.009931
# [1415/3000] Training loss: 0.002148	 Validation loss: 0.007982
# [1420/3000] Training loss: 0.005547	 Validation loss: 0.012750
# [1425/3000] Training loss: 0.001022	 Validation loss: 0.007577
# [1430/3000] Training loss: 0.001364	 Validation loss: 0.009349
# [1435/3000] Training loss: 0.003411	 Validation loss: 0.006989
# [1440/3000] Training loss: 0.001080	 Validation loss: 0.008773
# [1445/3000] Training loss: 0.001082	 Validation loss: 0.007755
# [1450/3000] Training loss: 0.001089	 Validation loss: 0.007513
# [1455/3000] Training loss: 0.001938	 Validation loss: 0.008134
# [1460/3000] Training loss: 0.000728	 Validation loss: 0.008755
# [1465/3000] Training loss: 0.001362	 Validation loss: 0.007459
# [1470/3000] Training loss: 0.001128	 Validation loss: 0.008815
# [1475/3000] Training loss: 0.002165	 Validation loss: 0.011328
# [1480/3000] Training loss: 0.000815	 Validation loss: 0.007445
# [1485/3000] Training loss: 0.002813	 Validation loss: 0.008513
# [1490/3000] Training loss: 0.000798	 Validation loss: 0.008128
# [1495/3000] Training loss: 0.000517	 Validation loss: 0.008398
# [1500/3000] Training loss: 0.000661	 Validation loss: 0.012264
# [1505/3000] Training loss: 0.003101	 Validation loss: 0.010550
# [1510/3000] Training loss: 0.001021	 Validation loss: 0.007231
# [1515/3000] Training loss: 0.001021	 Validation loss: 0.009792
# [1520/3000] Training loss: 0.000476	 Validation loss: 0.008587
# [1525/3000] Training loss: 0.001416	 Validation loss: 0.009738
# [1530/3000] Training loss: 0.001047	 Validation loss: 0.008202
# [1535/3000] Training loss: 0.000875	 Validation loss: 0.007255
# [1540/3000] Training loss: 0.001542	 Validation loss: 0.007592
# [1545/3000] Training loss: 0.001460	 Validation loss: 0.008749
# [1550/3000] Training loss: 0.005736	 Validation loss: 0.009923
# [1555/3000] Training loss: 0.001162	 Validation loss: 0.010440
# [1560/3000] Training loss: 0.000963	 Validation loss: 0.007383
# [1565/3000] Training loss: 0.001975	 Validation loss: 0.008368
# [1570/3000] Training loss: 0.000607	 Validation loss: 0.007383
# [1575/3000] Training loss: 0.001029	 Validation loss: 0.007656
# [1580/3000] Training loss: 0.001365	 Validation loss: 0.007954
# [1585/3000] Training loss: 0.001034	 Validation loss: 0.007114
# [1590/3000] Training loss: 0.009722	 Validation loss: 0.013623
# [1595/3000] Training loss: 0.001077	 Validation loss: 0.009050
# [1600/3000] Training loss: 0.000724	 Validation loss: 0.009845
# [1605/3000] Training loss: 0.000529	 Validation loss: 0.008510
# [1610/3000] Training loss: 0.000535	 Validation loss: 0.009150
# [1615/3000] Training loss: 0.000396	 Validation loss: 0.008080
# [1620/3000] Training loss: 0.000397	 Validation loss: 0.009316
# [1625/3000] Training loss: 0.000945	 Validation loss: 0.008870
# [1630/3000] Training loss: 0.001649	 Validation loss: 0.008388
# [1635/3000] Training loss: 0.001442	 Validation loss: 0.010041
# [1640/3000] Training loss: 0.000753	 Validation loss: 0.009824
# [1645/3000] Training loss: 0.001213	 Validation loss: 0.008065
# [1650/3000] Training loss: 0.001385	 Validation loss: 0.006983
# [1655/3000] Training loss: 0.001133	 Validation loss: 0.007774
# [1660/3000] Training loss: 0.000559	 Validation loss: 0.008515
# [1665/3000] Training loss: 0.000699	 Validation loss: 0.007642
# [1670/3000] Training loss: 0.000682	 Validation loss: 0.007473
# [1675/3000] Training loss: 0.001447	 Validation loss: 0.008660
# [1680/3000] Training loss: 0.000567	 Validation loss: 0.007196
# [1685/3000] Training loss: 0.000576	 Validation loss: 0.007578
# [1690/3000] Training loss: 0.000329	 Validation loss: 0.008144
# [1695/3000] Training loss: 0.001292	 Validation loss: 0.009652
# [1700/3000] Training loss: 0.002037	 Validation loss: 0.011534
# [1705/3000] Training loss: 0.001203	 Validation loss: 0.009077
# [1710/3000] Training loss: 0.000527	 Validation loss: 0.008506
# [1715/3000] Training loss: 0.000290	 Validation loss: 0.008022
# [1720/3000] Training loss: 0.000377	 Validation loss: 0.008594
# [1725/3000] Training loss: 0.000707	 Validation loss: 0.008984
# [1730/3000] Training loss: 0.002705	 Validation loss: 0.010934
# [1735/3000] Training loss: 0.000638	 Validation loss: 0.007686
# [1740/3000] Training loss: 0.000744	 Validation loss: 0.008047
# [1745/3000] Training loss: 0.001108	 Validation loss: 0.007839
# [1750/3000] Training loss: 0.000372	 Validation loss: 0.008427
# [1755/3000] Training loss: 0.000772	 Validation loss: 0.008936
# [1760/3000] Training loss: 0.000905	 Validation loss: 0.011471
# [1765/3000] Training loss: 0.003368	 Validation loss: 0.007296
# [1770/3000] Training loss: 0.000749	 Validation loss: 0.007747
# [1775/3000] Training loss: 0.000904	 Validation loss: 0.008075
# [1780/3000] Training loss: 0.000885	 Validation loss: 0.008699
# [1785/3000] Training loss: 0.001788	 Validation loss: 0.007421
# [1790/3000] Training loss: 0.000608	 Validation loss: 0.007324
# [1795/3000] Training loss: 0.000936	 Validation loss: 0.010048
# [1800/3000] Training loss: 0.001041	 Validation loss: 0.008362
# [1805/3000] Training loss: 0.000337	 Validation loss: 0.007690
# [1810/3000] Training loss: 0.000352	 Validation loss: 0.007858
# [1815/3000] Training loss: 0.000863	 Validation loss: 0.008493
# [1820/3000] Training loss: 0.002822	 Validation loss: 0.008147
# [1825/3000] Training loss: 0.000934	 Validation loss: 0.007174
# [1830/3000] Training loss: 0.000388	 Validation loss: 0.007367
# [1835/3000] Training loss: 0.000287	 Validation loss: 0.007101
# [1840/3000] Training loss: 0.000805	 Validation loss: 0.006837
# [1845/3000] Training loss: 0.008558	 Validation loss: 0.014723
# [1850/3000] Training loss: 0.002153	 Validation loss: 0.009085
# [1855/3000] Training loss: 0.000376	 Validation loss: 0.009019
# [1860/3000] Training loss: 0.000650	 Validation loss: 0.007139
# [1865/3000] Training loss: 0.000339	 Validation loss: 0.008057
# [1870/3000] Training loss: 0.000277	 Validation loss: 0.007364
# [1875/3000] Training loss: 0.000291	 Validation loss: 0.007034
# [1880/3000] Training loss: 0.001145	 Validation loss: 0.008328
# [1885/3000] Training loss: 0.001716	 Validation loss: 0.008763
# [1890/3000] Training loss: 0.001174	 Validation loss: 0.006828
# [1895/3000] Training loss: 0.000727	 Validation loss: 0.007543
# [1900/3000] Training loss: 0.000606	 Validation loss: 0.008397
# [1905/3000] Training loss: 0.001411	 Validation loss: 0.006828
# [1910/3000] Training loss: 0.000576	 Validation loss: 0.007823
# [1915/3000] Training loss: 0.000372	 Validation loss: 0.006304
# [1920/3000] Training loss: 0.002779	 Validation loss: 0.007945
# [1925/3000] Training loss: 0.000789	 Validation loss: 0.006702
# [1930/3000] Training loss: 0.000388	 Validation loss: 0.005927
# [1935/3000] Training loss: 0.000383	 Validation loss: 0.006227
# [1940/3000] Training loss: 0.000221	 Validation loss: 0.007193
# [1945/3000] Training loss: 0.001324	 Validation loss: 0.010901
# [1950/3000] Training loss: 0.000908	 Validation loss: 0.007656
# [1955/3000] Training loss: 0.003254	 Validation loss: 0.010560
# [1960/3000] Training loss: 0.000788	 Validation loss: 0.007247
# [1965/3000] Training loss: 0.000247	 Validation loss: 0.007037
# [1970/3000] Training loss: 0.000182	 Validation loss: 0.006478
# [1975/3000] Training loss: 0.000193	 Validation loss: 0.007009
# [1980/3000] Training loss: 0.000204	 Validation loss: 0.007599
# [1985/3000] Training loss: 0.001155	 Validation loss: 0.008295
# [1990/3000] Training loss: 0.000889	 Validation loss: 0.013252
# [1995/3000] Training loss: 0.003134	 Validation loss: 0.009883
# [2000/3000] Training loss: 0.000484	 Validation loss: 0.006847
# [2005/3000] Training loss: 0.000474	 Validation loss: 0.006518
# [2010/3000] Training loss: 0.000823	 Validation loss: 0.006750
# [2015/3000] Training loss: 0.000484	 Validation loss: 0.006111
# [2020/3000] Training loss: 0.000762	 Validation loss: 0.007385
# [2025/3000] Training loss: 0.000535	 Validation loss: 0.006184
# [2030/3000] Training loss: 0.000581	 Validation loss: 0.008506
# [2035/3000] Training loss: 0.000505	 Validation loss: 0.005562
# [2040/3000] Training loss: 0.000520	 Validation loss: 0.006694
# [2045/3000] Training loss: 0.000559	 Validation loss: 0.006308
# [2050/3000] Training loss: 0.000284	 Validation loss: 0.006078
# [2055/3000] Training loss: 0.004150	 Validation loss: 0.007908
# [2060/3000] Training loss: 0.001497	 Validation loss: 0.005833
# [2065/3000] Training loss: 0.000730	 Validation loss: 0.006799
# [2070/3000] Training loss: 0.000160	 Validation loss: 0.006230
# [2075/3000] Training loss: 0.000161	 Validation loss: 0.006373
# [2080/3000] Training loss: 0.000244	 Validation loss: 0.005829
# [2085/3000] Training loss: 0.000314	 Validation loss: 0.007258
# [2090/3000] Training loss: 0.000771	 Validation loss: 0.005747
# [2095/3000] Training loss: 0.000853	 Validation loss: 0.008582
# [2100/3000] Training loss: 0.001555	 Validation loss: 0.007453
# [2105/3000] Training loss: 0.000597	 Validation loss: 0.006817
# [2110/3000] Training loss: 0.000571	 Validation loss: 0.005611
# [2115/3000] Training loss: 0.000384	 Validation loss: 0.008689
# [2120/3000] Training loss: 0.000450	 Validation loss: 0.008835
# [2125/3000] Training loss: 0.000344	 Validation loss: 0.006027
# [2130/3000] Training loss: 0.001077	 Validation loss: 0.006849
# [2135/3000] Training loss: 0.000638	 Validation loss: 0.007188
# [2140/3000] Training loss: 0.000279	 Validation loss: 0.006442
# [2145/3000] Training loss: 0.000213	 Validation loss: 0.006372
# [2150/3000] Training loss: 0.000308	 Validation loss: 0.006053
# [2155/3000] Training loss: 0.001105	 Validation loss: 0.007814
# [2160/3000] Training loss: 0.002146	 Validation loss: 0.008058
# [2165/3000] Training loss: 0.000486	 Validation loss: 0.007177
# [2170/3000] Training loss: 0.000389	 Validation loss: 0.005516
# [2175/3000] Training loss: 0.000486	 Validation loss: 0.006540
# [2180/3000] Training loss: 0.000317	 Validation loss: 0.006352
# [2185/3000] Training loss: 0.000364	 Validation loss: 0.005866
# [2190/3000] Training loss: 0.000329	 Validation loss: 0.005695
# [2195/3000] Training loss: 0.000178	 Validation loss: 0.005422
# [2200/3000] Training loss: 0.000602	 Validation loss: 0.006660
# [2205/3000] Training loss: 0.001039	 Validation loss: 0.008664
# [2210/3000] Training loss: 0.001608	 Validation loss: 0.007370
# [2215/3000] Training loss: 0.000398	 Validation loss: 0.006657
# [2220/3000] Training loss: 0.000689	 Validation loss: 0.005790
# [2225/3000] Training loss: 0.000779	 Validation loss: 0.005969
# [2230/3000] Training loss: 0.000658	 Validation loss: 0.005669
# [2235/3000] Training loss: 0.000447	 Validation loss: 0.005850
# [2240/3000] Training loss: 0.000405	 Validation loss: 0.005213
# [2245/3000] Training loss: 0.000965	 Validation loss: 0.007767
# [2250/3000] Training loss: 0.000460	 Validation loss: 0.006139
# [2255/3000] Training loss: 0.000222	 Validation loss: 0.005675
# [2260/3000] Training loss: 0.001642	 Validation loss: 0.006514
# [2265/3000] Training loss: 0.000867	 Validation loss: 0.007368
# [2270/3000] Training loss: 0.000158	 Validation loss: 0.005670
# [2275/3000] Training loss: 0.000220	 Validation loss: 0.005702
# [2280/3000] Training loss: 0.000273	 Validation loss: 0.006805
# [2285/3000] Training loss: 0.001335	 Validation loss: 0.008990
# [2290/3000] Training loss: 0.001826	 Validation loss: 0.006930
# [2295/3000] Training loss: 0.000254	 Validation loss: 0.005441
# [2300/3000] Training loss: 0.000276	 Validation loss: 0.005382
# [2305/3000] Training loss: 0.000213	 Validation loss: 0.005445
# [2310/3000] Training loss: 0.000727	 Validation loss: 0.006497
# [2315/3000] Training loss: 0.001267	 Validation loss: 0.010449
# [2320/3000] Training loss: 0.001299	 Validation loss: 0.005232
# [2325/3000] Training loss: 0.000435	 Validation loss: 0.005277
# [2330/3000] Training loss: 0.000199	 Validation loss: 0.004905
# [2335/3000] Training loss: 0.000208	 Validation loss: 0.005341
# [2340/3000] Training loss: 0.000350	 Validation loss: 0.005309
# [2345/3000] Training loss: 0.000537	 Validation loss: 0.005763
# [2350/3000] Training loss: 0.000833	 Validation loss: 0.006060
# [2355/3000] Training loss: 0.000161	 Validation loss: 0.006147
# [2360/3000] Training loss: 0.000155	 Validation loss: 0.005940
# [2365/3000] Training loss: 0.000189	 Validation loss: 0.005320
# [2370/3000] Training loss: 0.000423	 Validation loss: 0.005921
# [2375/3000] Training loss: 0.000754	 Validation loss: 0.006866
# [2380/3000] Training loss: 0.001208	 Validation loss: 0.022238
# [2385/3000] Training loss: 0.000573	 Validation loss: 0.005994
# [2390/3000] Training loss: 0.000314	 Validation loss: 0.005388
# [2395/3000] Training loss: 0.000205	 Validation loss: 0.005112
# [2400/3000] Training loss: 0.000848	 Validation loss: 0.007022
# [2405/3000] Training loss: 0.000746	 Validation loss: 0.008648
# [2410/3000] Training loss: 0.000739	 Validation loss: 0.005818
# [2415/3000] Training loss: 0.000333	 Validation loss: 0.005854
# [2420/3000] Training loss: 0.000152	 Validation loss: 0.005557
# [2425/3000] Training loss: 0.000191	 Validation loss: 0.005310
# [2430/3000] Training loss: 0.000635	 Validation loss: 0.008296
# [2435/3000] Training loss: 0.001001	 Validation loss: 0.005714
# [2440/3000] Training loss: 0.000278	 Validation loss: 0.005572
# [2445/3000] Training loss: 0.000526	 Validation loss: 0.006993
# [2450/3000] Training loss: 0.001706	 Validation loss: 0.008491
# [2455/3000] Training loss: 0.001002	 Validation loss: 0.006481
# [2460/3000] Training loss: 0.000438	 Validation loss: 0.006090
# [2465/3000] Training loss: 0.000649	 Validation loss: 0.005160
# [2470/3000] Training loss: 0.000293	 Validation loss: 0.006055
# [2475/3000] Training loss: 0.000512	 Validation loss: 0.005782
# [2480/3000] Training loss: 0.000469	 Validation loss: 0.005301
# [2485/3000] Training loss: 0.000202	 Validation loss: 0.005971
# [2490/3000] Training loss: 0.000266	 Validation loss: 0.005422
# [2495/3000] Training loss: 0.001165	 Validation loss: 0.007438
# [2500/3000] Training loss: 0.001480	 Validation loss: 0.007603
# [2505/3000] Training loss: 0.001112	 Validation loss: 0.006417
# [2510/3000] Training loss: 0.000281	 Validation loss: 0.005412
# [2515/3000] Training loss: 0.000159	 Validation loss: 0.005419
# [2520/3000] Training loss: 0.000193	 Validation loss: 0.005491
# [2525/3000] Training loss: 0.000442	 Validation loss: 0.007626
# [2530/3000] Training loss: 0.000597	 Validation loss: 0.005727
# [2535/3000] Training loss: 0.000284	 Validation loss: 0.005232
# [2540/3000] Training loss: 0.000369	 Validation loss: 0.005513
# [2545/3000] Training loss: 0.001643	 Validation loss: 0.008187
# [2550/3000] Training loss: 0.000399	 Validation loss: 0.005017
# [2555/3000] Training loss: 0.002247	 Validation loss: 0.006283
# [2560/3000] Training loss: 0.000196	 Validation loss: 0.005268
# [2565/3000] Training loss: 0.000164	 Validation loss: 0.005460
# [2570/3000] Training loss: 0.000948	 Validation loss: 0.005322
# [2575/3000] Training loss: 0.000165	 Validation loss: 0.005073
# [2580/3000] Training loss: 0.000118	 Validation loss: 0.004741
# [2585/3000] Training loss: 0.000446	 Validation loss: 0.005758
# [2590/3000] Training loss: 0.000920	 Validation loss: 0.009023
# [2595/3000] Training loss: 0.001061	 Validation loss: 0.006597
# [2600/3000] Training loss: 0.000484	 Validation loss: 0.005472
# [2605/3000] Training loss: 0.000191	 Validation loss: 0.005311
# [2610/3000] Training loss: 0.000165	 Validation loss: 0.005207
# [2615/3000] Training loss: 0.000165	 Validation loss: 0.004981
# [2620/3000] Training loss: 0.000150	 Validation loss: 0.005061
# [2625/3000] Training loss: 0.000271	 Validation loss: 0.006486
# [2630/3000] Training loss: 0.000247	 Validation loss: 0.004971
# [2635/3000] Training loss: 0.000454	 Validation loss: 0.004999
# [2640/3000] Training loss: 0.000223	 Validation loss: 0.005031
# [2645/3000] Training loss: 0.000212	 Validation loss: 0.004853
# [2650/3000] Training loss: 0.000524	 Validation loss: 0.004888
# [2655/3000] Training loss: 0.000533	 Validation loss: 0.004850
# [2660/3000] Training loss: 0.000310	 Validation loss: 0.005350
# [2665/3000] Training loss: 0.000532	 Validation loss: 0.005462
# [2670/3000] Training loss: 0.000660	 Validation loss: 0.005330
# [2675/3000] Training loss: 0.000823	 Validation loss: 0.005479
# [2680/3000] Training loss: 0.000193	 Validation loss: 0.004894
# [2685/3000] Training loss: 0.000108	 Validation loss: 0.005226
# [2690/3000] Training loss: 0.000346	 Validation loss: 0.006438
# [2695/3000] Training loss: 0.000170	 Validation loss: 0.005513
# [2700/3000] Training loss: 0.000184	 Validation loss: 0.005455
# [2705/3000] Training loss: 0.000548	 Validation loss: 0.006139
# [2710/3000] Training loss: 0.002702	 Validation loss: 0.009879
# [2715/3000] Training loss: 0.000504	 Validation loss: 0.005825
# [2720/3000] Training loss: 0.000131	 Validation loss: 0.005204
# [2725/3000] Training loss: 0.000153	 Validation loss: 0.005522
# [2730/3000] Training loss: 0.000819	 Validation loss: 0.005861
# [2735/3000] Training loss: 0.000136	 Validation loss: 0.005212
# [2740/3000] Training loss: 0.000474	 Validation loss: 0.005748
# [2745/3000] Training loss: 0.000185	 Validation loss: 0.005615
# [2750/3000] Training loss: 0.000707	 Validation loss: 0.006725
# [2755/3000] Training loss: 0.000252	 Validation loss: 0.006139
# [2760/3000] Training loss: 0.000447	 Validation loss: 0.004358
# [2765/3000] Training loss: 0.000518	 Validation loss: 0.005064
# [2770/3000] Training loss: 0.000171	 Validation loss: 0.005302
# [2775/3000] Training loss: 0.000176	 Validation loss: 0.005156
# [2780/3000] Training loss: 0.011175	 Validation loss: 0.015749
# [2785/3000] Training loss: 0.000539	 Validation loss: 0.009276
# [2790/3000] Training loss: 0.000241	 Validation loss: 0.008840
# [2795/3000] Training loss: 0.000193	 Validation loss: 0.008489
# [2800/3000] Training loss: 0.000132	 Validation loss: 0.007688
# [2805/3000] Training loss: 0.000093	 Validation loss: 0.008058
# [2810/3000] Training loss: 0.000123	 Validation loss: 0.008460
# [2815/3000] Training loss: 0.000240	 Validation loss: 0.007665
# [2820/3000] Training loss: 0.000348	 Validation loss: 0.007168
# [2825/3000] Training loss: 0.000713	 Validation loss: 0.014624
# [2830/3000] Training loss: 0.000826	 Validation loss: 0.007182
# [2835/3000] Training loss: 0.000720	 Validation loss: 0.007145
# [2840/3000] Training loss: 0.000163	 Validation loss: 0.006511
# [2845/3000] Training loss: 0.000176	 Validation loss: 0.006409
# [2850/3000] Training loss: 0.000359	 Validation loss: 0.007042
# [2855/3000] Training loss: 0.000245	 Validation loss: 0.009026
# [2860/3000] Training loss: 0.000100	 Validation loss: 0.006688
# [2865/3000] Training loss: 0.000133	 Validation loss: 0.006653
# [2870/3000] Training loss: 0.000962	 Validation loss: 0.007048
# [2875/3000] Training loss: 0.000193	 Validation loss: 0.006675
# [2880/3000] Training loss: 0.000285	 Validation loss: 0.007376
# [2885/3000] Training loss: 0.000192	 Validation loss: 0.006624
# [2890/3000] Training loss: 0.000523	 Validation loss: 0.007740
# [2895/3000] Training loss: 0.000561	 Validation loss: 0.008603
# [2900/3000] Training loss: 0.000267	 Validation loss: 0.006238
# [2905/3000] Training loss: 0.000254	 Validation loss: 0.006763
# [2910/3000] Training loss: 0.000573	 Validation loss: 0.006541
# [2915/3000] Training loss: 0.000180	 Validation loss: 0.005634
# [2920/3000] Training loss: 0.000214	 Validation loss: 0.006527
# [2925/3000] Training loss: 0.000250	 Validation loss: 0.006745
# [2930/3000] Training loss: 0.001199	 Validation loss: 0.005862
# [2935/3000] Training loss: 0.001269	 Validation loss: 0.007055
# [2940/3000] Training loss: 0.000273	 Validation loss: 0.006619
# [2945/3000] Training loss: 0.000160	 Validation loss: 0.007067
# [2950/3000] Training loss: 0.000111	 Validation loss: 0.006254
# [2955/3000] Training loss: 0.000378	 Validation loss: 0.006784
# [2960/3000] Training loss: 0.000471	 Validation loss: 0.007362
# [2965/3000] Training loss: 0.000425	 Validation loss: 0.006750
# [2970/3000] Training loss: 0.001650	 Validation loss: 0.007020
# [2975/3000] Training loss: 0.000185	 Validation loss: 0.006720
# [2980/3000] Training loss: 0.000181	 Validation loss: 0.006523
# [2985/3000] Training loss: 0.000255	 Validation loss: 0.006215
# [2990/3000] Training loss: 0.000474	 Validation loss: 0.008226
# [2995/3000] Training loss: 0.000208	 Validation loss: 0.006317
# [3000/3000] Training loss: 0.000091	 Validation loss: 0.006117

# %%
predictions, values = opt.evaluate(test_loader_one, batch_size=1)

preds = np.array(predictions)
vals = np.array(values)

preds = np.reshape(preds, (5, 576, 384))
vals = np.reshape(vals, (5, 576, 384))

print(preds.shape, vals.shape)
# Out:
# (5, 576, 384) (5, 576, 384)

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[0, :, :].transpose() - vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[1, :, :].transpose() - vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[2, :, :].transpose() - vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[3, :, :].transpose() - vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[4, :, :].transpose() - vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
torch.save(model.state_dict(), 'Saved models/0SA0+Unet1024')

# %%
savfig_p = np.reshape(preds, (5, 576*384))
savfig_t = np.reshape(vals, (5, 576*384))

savfig_p = pd.DataFrame(savfig_p)
savfig_t = pd.DataFrame(savfig_t)

savfig_p.to_csv('CSVs/0SA0+Unet1024.csv', index=False)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def calculate_metrics(df1, df2):
    return {'mae' : mean_absolute_error(df1, df2),
            'rmse' : mean_squared_error(df1, df2) ** 0.5,
            'r2' : r2_score(df1, df2)}

# %%
result_metrics = calculate_metrics(savfig_t, savfig_p)
result_metrics
# Out:
# {'mae': 0.013890768, 'rmse': 0.07821442433355141, 'r2': -67.75639416208516}
