# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.interpolate import griddata
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import datetime
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, TensorDataset, DataLoader

from einops import rearrange

#PyTorch random number generator
torch.manual_seed(3407)
torch.cuda.manual_seed(3407)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
print(device)
# Out:
# cuda

# %%
bc_fine = np.zeros(((45, 168, 4)))

for i in range (45):
    df1 = pd.read_csv('C:/Users/59713/BC2MAP/inputs/case_{}.csv'.format(i+1))
    data1 = df1.values
    bc_fine[i, :, :] = data1

# %%
D_3d_fine = np.zeros(((45, 576, 384)))

for i in range (45):
    df2 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_{}.csv'.format(i))
    data2 = df2.values
    D_3d_fine[i, :, :] = np.reshape(data2[:, 5], (576, 384))

# %%
E_3d_fine = np.zeros((576, 384))
X_3d_fine = np.zeros((576, 384))
Y_3d_fine = np.zeros((576, 384))
S_3d_fine = np.zeros((576, 384))
map4all = np.zeros((576, 384))

df3 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_45.csv')
data3 = df3.values
X_3d_fine[:, :] = np.reshape(data3[:, 0], (576, 384))
Y_3d_fine[:, :] = np.reshape(data3[:, 1], (576, 384))
E_3d_fine[:, :] = np.reshape(data3[:, 3], (576, 384))
map4all[:, :] = np.reshape(data3[:, 5], (576, 384))

# %%
dzdx = np.zeros((576, 384))
dzdy = np.zeros((576, 384))

# calculate internal cell slope
for i in range (1, S_3d_fine.shape[0]-1):
    for j in range (1, S_3d_fine.shape[1]-1):
        dzdx[i, j] = ((E_3d_fine[i+1, j-1]+2*E_3d_fine[i+1, j]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i-1, j]+2*E_3d_fine[i-1, j+1]))/(8*(X_3d_fine[i+1, j]-X_3d_fine[i-1, j]))
        dzdy[i, j] = ((E_3d_fine[i-1, j+1]+2*E_3d_fine[i, j+1]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i, j-1]+2*E_3d_fine[i+1, j-1]))/(8*(Y_3d_fine[i, j+1]-Y_3d_fine[i, j-1]))
        S_3d_fine[i, j] = np.arctan(np.sqrt((dzdx[i, j])**2+(dzdy[i, j])**2))
        
# take care of the most oustside layer
S_3d_fine[0, :] = S_3d_fine[1, :]
S_3d_fine[-1, :] = S_3d_fine[-2, :]
S_3d_fine[:, 0] = S_3d_fine[:, 1]
S_3d_fine[:, -1] = S_3d_fine[:, -2]

# %% [markdown]
# ### make a 3D info

# %%
all_data_X = bc_fine
all_data_Y = D_3d_fine

# %%
print(all_data_X.shape, all_data_Y.shape)
# Out:
# (45, 168, 4) (45, 576, 384)

# %%
# split into train and test
train_X, test_X = all_data_X[:-5, :], all_data_X[-5:, :]
train_y, test_y = all_data_Y[:-5, :, :], all_data_Y[-5:, :, :]

# %%
batch_size = 1

train_features = torch.Tensor(train_X).to(device)
train_targets = torch.Tensor(train_y).to(device)
test_features = torch.Tensor(test_X).to(device)
test_targets = torch.Tensor(test_y).to(device)

train = TensorDataset(train_features, train_targets)
test = TensorDataset(test_features, test_targets)

train_loader = DataLoader(train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader_one = DataLoader(test, batch_size=1, shuffle=False, drop_last=True)

# %%
sup_feat = np.zeros(((batch_size, 3, 576, 384)))

# first channel is mapforall
sup_feat[:, 0, :, :] = map4all
# second channel is elevation
sup_feat[:, 1, :, :] = E_3d_fine
# third channel is slope
sup_feat[:, 2, :, :] = S_3d_fine
# fourth channel left for bc info after SA

# %%
class Self_Attention(nn.Module):
    def __init__(self):
        super(Self_Attention, self).__init__()
        
        self.embed_dim = 864
        self.num_heads = 1
        self.head_dim = self.embed_dim // self.num_heads
        
        self.value = nn.Linear(self.embed_dim, self.embed_dim)
        self.key = nn.Linear(self.embed_dim, self.embed_dim)
        self.query = nn.Linear(self.embed_dim, self.embed_dim)
                    
    def forward(self, x):
        queries = self.query(x)
        keys = self.key(x)
        values = self.value(x)
        
        batch_size, seq_len, embed_dim = x.size()
        # Reshape query, key, and value to split into multiple heads
        queries = queries.view(batch_size, seq_len, self.num_heads, self.head_dim)
        keys = keys.view(batch_size, seq_len, self.num_heads, self.head_dim)
        values = values.view(batch_size, seq_len, self.num_heads, self.head_dim)
        
        # Transpose to prepare for scaled dot-product attention
        queries = queries.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        keys = keys.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        values = values.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        
        # Apply softmax to get attention probabilities
        attention_scores = torch.matmul(queries, keys.transpose(-2, -1)) / (self.head_dim**0.5)
        attention_probs = F.softmax(attention_scores, dim=-1)
        
        # Compute the weighted sum of values
        x = torch.matmul(attention_probs, values)
        
        # Reshape and concatenate heads
        x = x.transpose(1, 2)
        
        out = x.reshape(x.size(0), seq_len, embed_dim)
        
        return out

# %%
class BC2Map(nn.Module):
    def __init__(self, input_size, output_size, background_map, batch_size):
        super(BC2Map, self).__init__()
        
        self.background_map = torch.Tensor(background_map).to(device)
        
        self.input_size = input_size
        self.hidden_dim = output_size
        batch_size = batch_size
                
        self.fc1 = nn.Linear(input_size*3, self.hidden_dim)
        self.fc2 = nn.Linear(input_size, self.hidden_dim)
        
        self.self_attention = Self_Attention().to(device)
        
        self.L1 = nn.Linear(864, 4096)
        self.L2 = nn.Linear(4096, 864)
        
        self.pos_embedding = nn.Parameter(data=torch.randn(1, 2, 576, 384)).to(device)
        
        ##-----------end of embedding ---------##
        ##-----------start of Unet ---------##
        
        self.conv1 = nn.Conv2d(in_channels=5, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv7 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv9 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1)
        self.conv10 = nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1)
        
        self.conv_s1 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=1, stride=1, padding=0)
        self.conv_s2 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=1, stride=1, padding=0)
        self.conv_s3 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=1, stride=1, padding=0)
        self.conv_s4 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=1, stride=1, padding=0)
        
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        
        self.conv_transpose0 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2, padding=0)
        self.conv_transpose1 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2, padding=0)
        self.conv_transpose2 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2, padding=0)
        self.conv_transpose3 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2, padding=0)
        self.conv_transpose4 = nn.ConvTranspose2d(in_channels=64, out_channels=1, kernel_size=3, stride=1, padding=1)
        
    def forward(self, x):
        # change dimension, maybe it's better to use embedding
        x = x.transpose(1, 2)
        x1 = x[:, :3, :].reshape(x.size(0), 1, -1)
        x1 = self.relu(self.fc1(x1))
        x2 = x[:, 3:, :]
        x2 = self.relu(self.fc2(x2))
        
        x = torch.cat((x1, x2), dim=1)
        x = rearrange(x, 'b c (h w) -> b c h w', h=576)
        
        # add positional embeddings
        x = x + self.pos_embedding
        
        x = rearrange(x, 'b c (h1 h) (w1 w) -> b (c h1 w1) (h w)', h1=16, w1=16)
        
        # Self-Attention #1
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #2
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #3
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #4
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #5
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #6
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #7
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #8
        x = self.self_attention(x)
        
        # Concat the full feature map
        x = rearrange(x, 'b (c h1 w1) (h w) -> b c (h1 h) (w1 w)', h1=16, w1=16, c=2, h=36, w=24)
        x = torch.cat((x, self.background_map), dim=1)
        
        # initial conv
        x = self.relu(self.conv1(x))
        
        # 1st resblock: 5->64
        x = self.conv2(self.relu(self.conv2(x))) + x
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 2nd resblock: 64->128
        x = self.conv4(self.relu(self.conv3(x))) + self.conv_s1(x)
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 3rd resblock: 128->256
        x = self.conv6(self.relu(self.conv5(x))) + self.conv_s2(x)
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 4th resblock: 256->512
        x = self.conv8(self.relu(self.conv7(x))) + self.conv_s3(x)
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 5th resblock: 512->1024
        x = self.conv10(self.relu(self.conv9(x))) + self.conv_s4(x)
        x = self.relu(x)
        
        # transpose0: 1024->512
        x = self.relu(self.conv_transpose0(x))
        x = self.conv8(self.relu(self.conv8(x))) + x
        x = self.relu(x)
        
        # transpose1: 512->256
        x = self.relu(self.conv_transpose1(x))
        x = self.conv6(self.relu(self.conv6(x))) + x
        x = self.relu(x)
        
        # transpose2: 256->128
        x = self.relu(self.conv_transpose2(x))
        x = self.conv4(self.relu(self.conv4(x))) + x
        x = self.relu(x)
        
        # transpose3: 128->64
        x = self.relu(self.conv_transpose3(x))
        x = self.conv2(self.relu(self.conv2(x))) + x
        x = self.relu(x)
        
        # transpose4: 64->1
        x = self.relu(self.conv_transpose4(x))
        
        out = x.reshape(x.size(0), -1)
        
        return out

# %%
class Optimization:
    def __init__(self, model, optimizer):
        self.model = model
        self.loss_fn = nn.MSELoss(reduction="mean")
        self.optimizer = optimizer
        self.train_losses = []
        self.val_losses = []
    
    def train_step(self, x, y):
        # Sets model to train mode
        self.model.train()

        # Makes predictions
        yhat = self.model(x)

        # Computes loss
        loss = self.loss_fn(y, yhat)

        # Computes gradients
        loss.backward()

        # Updates parameters and zeroes gradients
        self.optimizer.step()
        self.optimizer.zero_grad()

        # Returns the loss
        return loss.item()

    def train(self, train_loader, val_loader, batch_size=4, n_epochs=50):
        model_path = f'models/{self.model}_{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'

        for epoch in range(1, n_epochs + 1):
            batch_losses = []
            for x_batch, y_batch in train_loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.view([batch_size, 576*384]).to(device)
                loss = self.train_step(x_batch, y_batch)
                batch_losses.append(loss)
            training_loss = np.mean(batch_losses)
            self.train_losses.append(training_loss)

            with torch.no_grad():
                batch_val_losses = []
                for x_val, y_val in val_loader:
                    x_val = x_val.to(device)
                    y_val = y_val.view([batch_size, 576*384]).to(device)
                    self.model.eval()
                    yhat = self.model(x_val).to(device)
                    val_loss = self.loss_fn(y_val, yhat).item()
                    batch_val_losses.append(val_loss)
                validation_loss = np.mean(batch_val_losses)
                self.val_losses.append(validation_loss)

            if (epoch % 5 == 0):
                print(
                    f"[{epoch}/{n_epochs}] Training loss: {training_loss:.6f}\t Validation loss: {validation_loss:.6f}"
                )
            
            if (validation_loss <= 0.0045):
                break

#         torch.save(self.model.state_dict(), model_path)

    def evaluate(self, test_loader, batch_size=1):
        with torch.no_grad():
            predictions = []
            values = []
            for x_test, y_test in test_loader:
                x_test = x_test.to(device)
                y_test = y_test.view([batch_size, 576*384]).to(device)
                self.model.eval()
                yhat = self.model(x_test)
                predictions.append(yhat.cpu().detach().numpy())
                values.append(y_test.cpu().detach().numpy())

        return predictions, values

    def plot_losses(self):
        plt.plot(self.train_losses, label="Training loss")
        plt.plot(self.val_losses, label="Validation loss")
        plt.legend()
        plt.title("Losses")
        plt.show()
        plt.close()

# %%
input_size = 672//4
output_size = 576 * 384

batch_size = batch_size
n_epochs = 5000
learning_rate = 1e-4
weight_decay = learning_rate/n_epochs

model = BC2Map(input_size, output_size, background_map=sup_feat, batch_size=batch_size).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

opt = Optimization(model=model, optimizer=optimizer)
opt.train(train_loader, test_loader, batch_size=batch_size, n_epochs=n_epochs)
opt.plot_losses()
# Out:
# [5/5000] Training loss: 0.718065	 Validation loss: 0.466900
# [10/5000] Training loss: 0.214783	 Validation loss: 0.194496
# [15/5000] Training loss: 0.122397	 Validation loss: 0.143908
# [20/5000] Training loss: 0.097269	 Validation loss: 0.124396
# [25/5000] Training loss: 0.080237	 Validation loss: 0.129396
# [30/5000] Training loss: 0.085534	 Validation loss: 0.175288
# [35/5000] Training loss: 0.075247	 Validation loss: 0.131906
# [40/5000] Training loss: 0.145350	 Validation loss: 0.185898
# [45/5000] Training loss: 0.068310	 Validation loss: 0.097177
# [50/5000] Training loss: 0.068940	 Validation loss: 0.083603
# [55/5000] Training loss: 0.074266	 Validation loss: 0.187345
# [60/5000] Training loss: 0.046402	 Validation loss: 0.076786
# [65/5000] Training loss: 0.073623	 Validation loss: 0.107619
# [70/5000] Training loss: 0.206415	 Validation loss: 0.193889
# [75/5000] Training loss: 0.046893	 Validation loss: 0.086738
# [80/5000] Training loss: 0.073660	 Validation loss: 0.084079
# [85/5000] Training loss: 0.056993	 Validation loss: 0.082544
# [90/5000] Training loss: 0.036452	 Validation loss: 0.092184
# [95/5000] Training loss: 0.047812	 Validation loss: 0.061459
# [100/5000] Training loss: 0.047682	 Validation loss: 0.067915
# [105/5000] Training loss: 0.066556	 Validation loss: 0.076291
# [110/5000] Training loss: 0.042867	 Validation loss: 0.057246
# [115/5000] Training loss: 0.032414	 Validation loss: 0.050122
# [120/5000] Training loss: 0.037078	 Validation loss: 0.068334
# [125/5000] Training loss: 0.033068	 Validation loss: 0.054697
# [130/5000] Training loss: 0.075746	 Validation loss: 0.126849
# [135/5000] Training loss: 0.042704	 Validation loss: 0.053379
# [140/5000] Training loss: 0.044301	 Validation loss: 0.133898
# [145/5000] Training loss: 0.050389	 Validation loss: 0.052168
# [150/5000] Training loss: 0.024581	 Validation loss: 0.050599
# [155/5000] Training loss: 0.022870	 Validation loss: 0.036484
# [160/5000] Training loss: 0.020033	 Validation loss: 0.034893
# [165/5000] Training loss: 0.087680	 Validation loss: 0.043721
# [170/5000] Training loss: 0.046702	 Validation loss: 0.054987
# [175/5000] Training loss: 0.034407	 Validation loss: 0.043722
# [180/5000] Training loss: 0.072533	 Validation loss: 0.326139
# [185/5000] Training loss: 0.022689	 Validation loss: 0.033468
# [190/5000] Training loss: 0.023031	 Validation loss: 0.033513
# [195/5000] Training loss: 0.034019	 Validation loss: 0.036835
# [200/5000] Training loss: 0.020007	 Validation loss: 0.039826
# [205/5000] Training loss: 0.030178	 Validation loss: 0.038594
# [210/5000] Training loss: 0.017077	 Validation loss: 0.024750
# [215/5000] Training loss: 0.022450	 Validation loss: 0.029617
# [220/5000] Training loss: 0.039681	 Validation loss: 0.036078
# [225/5000] Training loss: 0.013746	 Validation loss: 0.029935
# [230/5000] Training loss: 0.018026	 Validation loss: 0.029339
# [235/5000] Training loss: 0.048846	 Validation loss: 0.033397
# [240/5000] Training loss: 0.018118	 Validation loss: 0.038864
# [245/5000] Training loss: 0.015988	 Validation loss: 0.021811
# [250/5000] Training loss: 0.012918	 Validation loss: 0.019036
# [255/5000] Training loss: 0.021043	 Validation loss: 0.023670
# [260/5000] Training loss: 0.014673	 Validation loss: 0.032121
# [265/5000] Training loss: 0.021255	 Validation loss: 0.067696
# [270/5000] Training loss: 0.016496	 Validation loss: 0.020477
# [275/5000] Training loss: 0.009803	 Validation loss: 0.017105
# [280/5000] Training loss: 0.027296	 Validation loss: 0.089646
# [285/5000] Training loss: 0.015722	 Validation loss: 0.030391
# [290/5000] Training loss: 0.011066	 Validation loss: 0.035309
# [295/5000] Training loss: 0.032090	 Validation loss: 0.022099
# [300/5000] Training loss: 0.006636	 Validation loss: 0.013450
# [305/5000] Training loss: 0.041453	 Validation loss: 0.037609
# [310/5000] Training loss: 0.014931	 Validation loss: 0.020311
# [315/5000] Training loss: 0.022550	 Validation loss: 0.018802
# [320/5000] Training loss: 0.011140	 Validation loss: 0.043650
# [325/5000] Training loss: 0.011479	 Validation loss: 0.019911
# [330/5000] Training loss: 0.006313	 Validation loss: 0.014371
# [335/5000] Training loss: 0.012977	 Validation loss: 0.039002
# [340/5000] Training loss: 0.022863	 Validation loss: 0.030814
# [345/5000] Training loss: 0.017409	 Validation loss: 0.020360
# [350/5000] Training loss: 0.006752	 Validation loss: 0.014497
# [355/5000] Training loss: 0.005684	 Validation loss: 0.040660
# [360/5000] Training loss: 0.006518	 Validation loss: 0.021051
# [365/5000] Training loss: 0.004519	 Validation loss: 0.016993
# [370/5000] Training loss: 0.006131	 Validation loss: 0.012591
# [375/5000] Training loss: 0.007895	 Validation loss: 0.016116
# [380/5000] Training loss: 0.020011	 Validation loss: 0.020696
# [385/5000] Training loss: 0.027260	 Validation loss: 0.015703
# [390/5000] Training loss: 0.030051	 Validation loss: 0.018136
# [395/5000] Training loss: 0.006534	 Validation loss: 0.011982
# [400/5000] Training loss: 0.005946	 Validation loss: 0.024761
# [405/5000] Training loss: 0.004344	 Validation loss: 0.019643
# [410/5000] Training loss: 0.007024	 Validation loss: 0.016274
# [415/5000] Training loss: 0.004501	 Validation loss: 0.010437
# [420/5000] Training loss: 0.003976	 Validation loss: 0.013695
# [425/5000] Training loss: 0.007078	 Validation loss: 0.012157
# [430/5000] Training loss: 0.006355	 Validation loss: 0.027885
# [435/5000] Training loss: 0.043582	 Validation loss: 0.027305
# [440/5000] Training loss: 0.011850	 Validation loss: 0.037261
# [445/5000] Training loss: 0.018145	 Validation loss: 0.013986
# [450/5000] Training loss: 0.011816	 Validation loss: 0.013465
# [455/5000] Training loss: 0.012291	 Validation loss: 0.034010
# [460/5000] Training loss: 0.006302	 Validation loss: 0.008688
# [465/5000] Training loss: 0.006906	 Validation loss: 0.019619
# [470/5000] Training loss: 0.005834	 Validation loss: 0.012452
# [475/5000] Training loss: 0.030052	 Validation loss: 0.030436
# [480/5000] Training loss: 0.016047	 Validation loss: 0.013464
# [485/5000] Training loss: 0.010545	 Validation loss: 0.008332
# [490/5000] Training loss: 0.011199	 Validation loss: 0.019025
# [495/5000] Training loss: 0.009393	 Validation loss: 0.022619
# [500/5000] Training loss: 0.005599	 Validation loss: 0.012642
# [505/5000] Training loss: 0.011155	 Validation loss: 0.014719
# [510/5000] Training loss: 0.006266	 Validation loss: 0.010968
# [515/5000] Training loss: 0.003515	 Validation loss: 0.011085
# [520/5000] Training loss: 0.002824	 Validation loss: 0.010848
# [525/5000] Training loss: 0.002575	 Validation loss: 0.007474
# [530/5000] Training loss: 0.005693	 Validation loss: 0.011400
# [535/5000] Training loss: 0.003929	 Validation loss: 0.014689
# [540/5000] Training loss: 0.012366	 Validation loss: 0.019832
# [545/5000] Training loss: 0.007731	 Validation loss: 0.033506
# [550/5000] Training loss: 0.008351	 Validation loss: 0.025151
# [555/5000] Training loss: 0.035073	 Validation loss: 0.020034
# [560/5000] Training loss: 0.006028	 Validation loss: 0.009165
# [565/5000] Training loss: 0.001771	 Validation loss: 0.010531
# [570/5000] Training loss: 0.005546	 Validation loss: 0.024674
# [575/5000] Training loss: 0.018664	 Validation loss: 0.029452
# [580/5000] Training loss: 0.005959	 Validation loss: 0.011608
# [585/5000] Training loss: 0.053911	 Validation loss: 0.024984
# [590/5000] Training loss: 0.011316	 Validation loss: 0.010504
# [595/5000] Training loss: 0.008069	 Validation loss: 0.009389
# [600/5000] Training loss: 0.005109	 Validation loss: 0.008210
# [605/5000] Training loss: 0.002761	 Validation loss: 0.009815
# [610/5000] Training loss: 0.002460	 Validation loss: 0.009673
# [615/5000] Training loss: 0.003662	 Validation loss: 0.008041
# [620/5000] Training loss: 0.028008	 Validation loss: 0.028112
# [625/5000] Training loss: 0.002809	 Validation loss: 0.010881
# [630/5000] Training loss: 0.001299	 Validation loss: 0.010448
# [635/5000] Training loss: 0.002227	 Validation loss: 0.009081
# [640/5000] Training loss: 0.001642	 Validation loss: 0.013715
# [645/5000] Training loss: 0.004366	 Validation loss: 0.010694
# [650/5000] Training loss: 0.004582	 Validation loss: 0.013403
# [655/5000] Training loss: 0.005534	 Validation loss: 0.012391
# [660/5000] Training loss: 0.004982	 Validation loss: 0.013940
# [665/5000] Training loss: 0.013858	 Validation loss: 0.033218
# [670/5000] Training loss: 0.026720	 Validation loss: 0.026581
# [675/5000] Training loss: 0.004234	 Validation loss: 0.008053
# [680/5000] Training loss: 0.013557	 Validation loss: 0.018387
# [685/5000] Training loss: 0.002735	 Validation loss: 0.010737
# [690/5000] Training loss: 0.001324	 Validation loss: 0.008678
# [695/5000] Training loss: 0.001276	 Validation loss: 0.008002
# [700/5000] Training loss: 0.002158	 Validation loss: 0.013855
# [705/5000] Training loss: 0.001820	 Validation loss: 0.009403
# [710/5000] Training loss: 0.002536	 Validation loss: 0.017259
# [715/5000] Training loss: 0.024682	 Validation loss: 0.016318
# [720/5000] Training loss: 0.006605	 Validation loss: 0.009530
# [725/5000] Training loss: 0.006428	 Validation loss: 0.010103
# [730/5000] Training loss: 0.002528	 Validation loss: 0.015062
# [735/5000] Training loss: 0.008484	 Validation loss: 0.007560
# [740/5000] Training loss: 0.001296	 Validation loss: 0.008160
# [745/5000] Training loss: 0.005078	 Validation loss: 0.013343
# [750/5000] Training loss: 0.001984	 Validation loss: 0.008328
# [755/5000] Training loss: 0.002125	 Validation loss: 0.008190
# [760/5000] Training loss: 0.002640	 Validation loss: 0.021373
# [765/5000] Training loss: 0.001841	 Validation loss: 0.007947
# [770/5000] Training loss: 0.001028	 Validation loss: 0.007877
# [775/5000] Training loss: 0.007319	 Validation loss: 0.013997
# [780/5000] Training loss: 0.001776	 Validation loss: 0.007522
# [785/5000] Training loss: 0.008674	 Validation loss: 0.009728
# [790/5000] Training loss: 0.001336	 Validation loss: 0.007091
# [795/5000] Training loss: 0.001718	 Validation loss: 0.007762
# [800/5000] Training loss: 0.001303	 Validation loss: 0.007622
# [805/5000] Training loss: 0.001540	 Validation loss: 0.012996
# [810/5000] Training loss: 0.004594	 Validation loss: 0.009845
# [815/5000] Training loss: 0.002469	 Validation loss: 0.007089
# [820/5000] Training loss: 0.009908	 Validation loss: 0.012206
# [825/5000] Training loss: 0.003501	 Validation loss: 0.009428
# [830/5000] Training loss: 0.005709	 Validation loss: 0.007135
# [835/5000] Training loss: 0.001976	 Validation loss: 0.007636
# [840/5000] Training loss: 0.001387	 Validation loss: 0.010393
# [845/5000] Training loss: 0.002208	 Validation loss: 0.007687
# [850/5000] Training loss: 0.001347	 Validation loss: 0.007060
# [855/5000] Training loss: 0.003116	 Validation loss: 0.010723
# [860/5000] Training loss: 0.036069	 Validation loss: 0.021323
# [865/5000] Training loss: 0.002337	 Validation loss: 0.020074
# [870/5000] Training loss: 0.002821	 Validation loss: 0.009929
# [875/5000] Training loss: 0.002852	 Validation loss: 0.008188
# [880/5000] Training loss: 0.002065	 Validation loss: 0.024601
# [885/5000] Training loss: 0.004936	 Validation loss: 0.015192
# [890/5000] Training loss: 0.001212	 Validation loss: 0.011925
# [895/5000] Training loss: 0.000965	 Validation loss: 0.007129
# [900/5000] Training loss: 0.001238	 Validation loss: 0.008918
# [905/5000] Training loss: 0.001737	 Validation loss: 0.011023
# [910/5000] Training loss: 0.001888	 Validation loss: 0.014707
# [915/5000] Training loss: 0.000889	 Validation loss: 0.010828
# [920/5000] Training loss: 0.001020	 Validation loss: 0.008041
# [925/5000] Training loss: 0.002470	 Validation loss: 0.011425
# [930/5000] Training loss: 0.091564	 Validation loss: 0.043310
# [935/5000] Training loss: 0.001571	 Validation loss: 0.009086
# [940/5000] Training loss: 0.001842	 Validation loss: 0.008688
# [945/5000] Training loss: 0.001551	 Validation loss: 0.010791
# [950/5000] Training loss: 0.001385	 Validation loss: 0.010150
# [955/5000] Training loss: 0.005495	 Validation loss: 0.009258
# [960/5000] Training loss: 0.008914	 Validation loss: 0.014613
# [965/5000] Training loss: 0.003347	 Validation loss: 0.010590
# [970/5000] Training loss: 0.000685	 Validation loss: 0.007214
# [975/5000] Training loss: 0.002223	 Validation loss: 0.010847
# [980/5000] Training loss: 0.001666	 Validation loss: 0.012480
# [985/5000] Training loss: 0.007408	 Validation loss: 0.009887
# [990/5000] Training loss: 0.029776	 Validation loss: 0.027106
# [995/5000] Training loss: 0.002165	 Validation loss: 0.008636
# [1000/5000] Training loss: 0.000803	 Validation loss: 0.008200
# [1005/5000] Training loss: 0.001129	 Validation loss: 0.014081
# [1010/5000] Training loss: 0.001383	 Validation loss: 0.010731
# [1015/5000] Training loss: 0.008247	 Validation loss: 0.011590
# [1020/5000] Training loss: 0.004023	 Validation loss: 0.008984
# [1025/5000] Training loss: 0.004974	 Validation loss: 0.015775
# [1030/5000] Training loss: 0.002342	 Validation loss: 0.007692
# [1035/5000] Training loss: 0.002396	 Validation loss: 0.010343
# [1040/5000] Training loss: 0.001790	 Validation loss: 0.007803
# [1045/5000] Training loss: 0.000823	 Validation loss: 0.008536
# [1050/5000] Training loss: 0.001035	 Validation loss: 0.008498
# [1055/5000] Training loss: 0.001750	 Validation loss: 0.007109
# [1060/5000] Training loss: 0.001180	 Validation loss: 0.012393
# [1065/5000] Training loss: 0.003145	 Validation loss: 0.007757
# [1070/5000] Training loss: 0.042681	 Validation loss: 0.098349
# [1075/5000] Training loss: 0.001249	 Validation loss: 0.008452
# [1080/5000] Training loss: 0.000735	 Validation loss: 0.009070
# [1085/5000] Training loss: 0.000456	 Validation loss: 0.007678
# [1090/5000] Training loss: 0.002011	 Validation loss: 0.007673
# [1095/5000] Training loss: 0.002757	 Validation loss: 0.014396
# [1100/5000] Training loss: 0.016111	 Validation loss: 0.022410
# [1105/5000] Training loss: 0.007722	 Validation loss: 0.011848
# [1110/5000] Training loss: 0.010502	 Validation loss: 0.029353
# [1115/5000] Training loss: 0.012201	 Validation loss: 0.036739
# [1120/5000] Training loss: 0.007990	 Validation loss: 0.018903
# [1125/5000] Training loss: 0.040797	 Validation loss: 0.043742
# [1130/5000] Training loss: 0.015741	 Validation loss: 0.017804
# [1135/5000] Training loss: 0.012482	 Validation loss: 0.010495
# [1140/5000] Training loss: 0.010167	 Validation loss: 0.010778
# [1145/5000] Training loss: 0.007470	 Validation loss: 0.017110
# [1150/5000] Training loss: 0.003131	 Validation loss: 0.009733
# [1155/5000] Training loss: 0.004853	 Validation loss: 0.010894
# [1160/5000] Training loss: 0.003600	 Validation loss: 0.008630
# [1165/5000] Training loss: 0.001778	 Validation loss: 0.010009
# [1170/5000] Training loss: 0.004196	 Validation loss: 0.017514
# [1175/5000] Training loss: 0.002116	 Validation loss: 0.011315
# [1180/5000] Training loss: 0.004347	 Validation loss: 0.010883
# [1185/5000] Training loss: 0.001569	 Validation loss: 0.012113
# [1190/5000] Training loss: 0.001182	 Validation loss: 0.009133
# [1195/5000] Training loss: 0.000963	 Validation loss: 0.009060
# [1200/5000] Training loss: 0.001443	 Validation loss: 0.012119
# [1205/5000] Training loss: 0.002631	 Validation loss: 0.011994
# [1210/5000] Training loss: 0.008909	 Validation loss: 0.032518
# [1215/5000] Training loss: 0.001427	 Validation loss: 0.016280
# [1220/5000] Training loss: 0.006082	 Validation loss: 0.009674
# [1225/5000] Training loss: 0.001341	 Validation loss: 0.009261
# [1230/5000] Training loss: 0.000849	 Validation loss: 0.009203
# [1235/5000] Training loss: 0.004535	 Validation loss: 0.011870
# [1240/5000] Training loss: 0.000703	 Validation loss: 0.008438
# [1245/5000] Training loss: 0.000527	 Validation loss: 0.011107
# [1250/5000] Training loss: 0.001297	 Validation loss: 0.007513
# [1255/5000] Training loss: 0.000848	 Validation loss: 0.010058
# [1260/5000] Training loss: 0.008874	 Validation loss: 0.012943
# [1265/5000] Training loss: 0.029976	 Validation loss: 0.051664
# [1270/5000] Training loss: 0.011762	 Validation loss: 0.014605
# [1275/5000] Training loss: 0.014632	 Validation loss: 0.011514
# [1280/5000] Training loss: 0.038997	 Validation loss: 0.165857
# [1285/5000] Training loss: 0.012781	 Validation loss: 0.031140
# [1290/5000] Training loss: 0.009483	 Validation loss: 0.009291
# [1295/5000] Training loss: 0.004130	 Validation loss: 0.005276
# [1300/5000] Training loss: 0.003246	 Validation loss: 0.005147
# [1305/5000] Training loss: 0.001946	 Validation loss: 0.003174

# %%
predictions, values = opt.evaluate(test_loader_one, batch_size=1)

preds = np.array(predictions)
vals = np.array(values)

preds = np.reshape(preds, (5, 576, 384))
vals = np.reshape(vals, (5, 576, 384))

print(preds.shape, vals.shape)
# Out:
# (5, 576, 384) (5, 576, 384)

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[0, :, :].transpose() - vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[1, :, :].transpose() - vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[2, :, :].transpose() - vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[3, :, :].transpose() - vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[4, :, :].transpose() - vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
torch.save(model.state_dict(), 'Saved models/0SA8+Unet1024')

# %%
savfig_p = np.reshape(preds, (5, 576*384))
savfig_t = np.reshape(vals, (5, 576*384))

savfig_p = pd.DataFrame(savfig_p)
savfig_t = pd.DataFrame(savfig_t)

savfig_p.to_csv('CSVs/0SA8+Unet1024.csv', index=False)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def calculate_metrics(df1, df2):
    return {'mae' : mean_absolute_error(df1, df2),
            'rmse' : mean_squared_error(df1, df2) ** 0.5,
            'r2' : r2_score(df1, df2)}

# %%
result_metrics = calculate_metrics(savfig_t, savfig_p)
result_metrics
# Out:
# {'mae': 0.01210769, 'rmse': 0.05634143752056446, 'r2': -979.008687048252}
