# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.interpolate import griddata
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import datetime
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, TensorDataset, DataLoader

from einops import rearrange

#PyTorch random number generator
torch.manual_seed(3407)
torch.cuda.manual_seed(3407)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
print(device)
# Out:
# cuda

# %%
bc_fine = np.zeros(((45, 168, 4)))

for i in range (45):
    df1 = pd.read_csv('C:/Users/59713/BC2MAP/inputs/case_{}.csv'.format(i+1))
    data1 = df1.values
    bc_fine[i, :, :] = data1

# %%
D_3d_fine = np.zeros(((45, 576, 384)))

for i in range (45):
    df2 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_{}.csv'.format(i))
    data2 = df2.values
    D_3d_fine[i, :, :] = np.reshape(data2[:, 5], (576, 384))

# %%
E_3d_fine = np.zeros((576, 384))
X_3d_fine = np.zeros((576, 384))
Y_3d_fine = np.zeros((576, 384))
S_3d_fine = np.zeros((576, 384))
map4all = np.zeros((576, 384))

df3 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_45.csv')
data3 = df3.values
X_3d_fine[:, :] = np.reshape(data3[:, 0], (576, 384))
Y_3d_fine[:, :] = np.reshape(data3[:, 1], (576, 384))
E_3d_fine[:, :] = np.reshape(data3[:, 3], (576, 384))
map4all[:, :] = np.reshape(data3[:, 5], (576, 384))

# %%
dzdx = np.zeros((576, 384))
dzdy = np.zeros((576, 384))

# calculate internal cell slope
for i in range (1, S_3d_fine.shape[0]-1):
    for j in range (1, S_3d_fine.shape[1]-1):
        dzdx[i, j] = ((E_3d_fine[i+1, j-1]+2*E_3d_fine[i+1, j]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i-1, j]+2*E_3d_fine[i-1, j+1]))/(8*(X_3d_fine[i+1, j]-X_3d_fine[i-1, j]))
        dzdy[i, j] = ((E_3d_fine[i-1, j+1]+2*E_3d_fine[i, j+1]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i, j-1]+2*E_3d_fine[i+1, j-1]))/(8*(Y_3d_fine[i, j+1]-Y_3d_fine[i, j-1]))
        S_3d_fine[i, j] = np.arctan(np.sqrt((dzdx[i, j])**2+(dzdy[i, j])**2))
        
# take care of the most oustside layer
S_3d_fine[0, :] = S_3d_fine[1, :]
S_3d_fine[-1, :] = S_3d_fine[-2, :]
S_3d_fine[:, 0] = S_3d_fine[:, 1]
S_3d_fine[:, -1] = S_3d_fine[:, -2]

# %% [markdown]
# ### make a 3D info

# %%
all_data_X = bc_fine
all_data_Y = D_3d_fine

# %%
print(all_data_X.shape, all_data_Y.shape)
# Out:
# (45, 168, 4) (45, 576, 384)

# %%
# split into train and test
train_X, test_X = all_data_X[:-5, :], all_data_X[-5:, :]
train_y, test_y = all_data_Y[:-5, :, :], all_data_Y[-5:, :, :]

# %%
batch_size = 1

train_features = torch.Tensor(train_X).to(device)
train_targets = torch.Tensor(train_y).to(device)
test_features = torch.Tensor(test_X).to(device)
test_targets = torch.Tensor(test_y).to(device)

train = TensorDataset(train_features, train_targets)
test = TensorDataset(test_features, test_targets)

train_loader = DataLoader(train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader_one = DataLoader(test, batch_size=1, shuffle=False, drop_last=True)

# %%
sup_feat = np.zeros(((batch_size, 3, 576, 384)))

# first channel is mapforall
sup_feat[:, 0, :, :] = map4all
# second channel is elevation
sup_feat[:, 1, :, :] = E_3d_fine
# third channel is slope
sup_feat[:, 2, :, :] = S_3d_fine
# fourth channel left for bc info after SA

# %%
class Self_Attention(nn.Module):
    def __init__(self):
        super(Self_Attention, self).__init__()
        
        self.embed_dim = 864
        self.num_heads = 1
        self.head_dim = self.embed_dim // self.num_heads
        
        self.value = nn.Linear(self.embed_dim, self.embed_dim)
        self.key = nn.Linear(self.embed_dim, self.embed_dim)
        self.query = nn.Linear(self.embed_dim, self.embed_dim)
                    
    def forward(self, x):
        queries = self.query(x)
        keys = self.key(x)
        values = self.value(x)
        
        batch_size, seq_len, embed_dim = x.size()
        # Reshape query, key, and value to split into multiple heads
        queries = queries.view(batch_size, seq_len, self.num_heads, self.head_dim)
        keys = keys.view(batch_size, seq_len, self.num_heads, self.head_dim)
        values = values.view(batch_size, seq_len, self.num_heads, self.head_dim)
        
        # Transpose to prepare for scaled dot-product attention
        queries = queries.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        keys = keys.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        values = values.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        
        # Apply softmax to get attention probabilities
        attention_scores = torch.matmul(queries, keys.transpose(-2, -1)) / (self.head_dim**0.5)
        attention_probs = F.softmax(attention_scores, dim=-1)
        
        # Compute the weighted sum of values
        x = torch.matmul(attention_probs, values)
        
        # Reshape and concatenate heads
        x = x.transpose(1, 2)
        
        out = x.reshape(x.size(0), seq_len, embed_dim)
        
        return out

# %%
class BC2Map(nn.Module):
    def __init__(self, input_size, output_size, background_map, batch_size):
        super(BC2Map, self).__init__()
        
        self.background_map = torch.Tensor(background_map).to(device)
        
        self.input_size = input_size
        self.hidden_dim = output_size
        batch_size = batch_size
                
        self.fc1 = nn.Linear(input_size*3, self.hidden_dim)
        self.fc2 = nn.Linear(input_size, self.hidden_dim)
        
        self.self_attention = Self_Attention().to(device)
        
        self.L1 = nn.Linear(864, 4096)
        self.L2 = nn.Linear(4096, 864)
        
        self.pos_embedding = nn.Parameter(data=torch.randn(1, 2, 576, 384)).to(device)
        
        ##-----------end of embedding ---------##
        ##-----------start of Unet ---------##
        
        self.conv1 = nn.Conv2d(in_channels=5, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv7 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv9 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1)
        self.conv10 = nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1)
        
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        
        self.conv_transpose0 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2, padding=0)
        self.conv_transpose1 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2, padding=0)
        self.conv_transpose2 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2, padding=0)
        self.conv_transpose3 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2, padding=0)
        self.conv_transpose4 = nn.ConvTranspose2d(in_channels=64, out_channels=1, kernel_size=3, stride=1, padding=1)
        
    def forward(self, x):
        # change dimension, maybe it's better to use embedding
        x = x.transpose(1, 2)
        x1 = x[:, :3, :].reshape(x.size(0), 1, -1)
        x1 = self.relu(self.fc1(x1))
        x2 = x[:, 3:, :]
        x2 = self.relu(self.fc2(x2))
        
        x = torch.cat((x1, x2), dim=1)
        x = rearrange(x, 'b c (h w) -> b c h w', h=576)
        
        # add positional embeddings
        x = x + self.pos_embedding
        
        x = rearrange(x, 'b c (h1 h) (w1 w) -> b (c h1 w1) (h w)', h1=16, w1=16)
        
        # Self-Attention #1
        x = self.self_attention(x)
        
        # Concat the full feature map
        x = rearrange(x, 'b (c h1 w1) (h w) -> b c (h1 h) (w1 w)', h1=16, w1=16, c=2, h=36, w=24)
        x = torch.cat((x, self.background_map), dim=1)
        
        # initial conv: 1->64
        x = self.relu(self.conv1(x))
        
        # 1st resblock: 64->64
        identity = x
        x = self.conv2(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = x + identity
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 2nd resblock: 64->128
        identity2 = x
        x = self.conv3(x)
        x = self.relu(x)
        x = self.conv4(x)
        identity2 = self.conv3(identity2)
        x = x + identity2
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 3rd resblock: 128->256
        identity3 = x
        x = self.conv5(x)
        x = self.relu(x)
        x = self.conv6(x)
        identity3 = self.conv5(identity3)
        x = x + identity3
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 4th resblock: 256->512
        identity4 = x
        x = self.conv7(x)
        x = self.relu(x)
        x = self.conv8(x)
        identity4 = self.conv7(identity4)
        x = x + identity4
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 5th resblock: 512->1024
        identity5 = x
        x = self.conv9(x)
        x = self.relu(x)
        x = self.conv10(x)
        identity5 = self.conv9(identity5)
        x = x + identity5
        x = self.relu(x)
        
        # transpose0: 1024->512
        x = self.relu(self.conv_transpose0(x))
        identity7 = x
        x = self.conv8(x)
        x = self.relu(x)
        x = self.conv8(x)
        x = x + identity7
        x = self.relu(x)
        
        # transpose1: 512->256
        x = self.relu(self.conv_transpose1(x))
        identity8 = x
        x = self.conv6(x)
        x = self.relu(x)
        x = self.conv6(x)
        x = x + identity8
        x = self.relu(x)
        
        # transpose2: 256->128
        x = self.relu(self.conv_transpose2(x))
        identity9 = x
        x = self.conv4(x)
        x = self.relu(x)
        x = self.conv4(x)
        x = x + identity9
        
        # transpose3: 128->64
        x = self.relu(self.conv_transpose3(x))
        identity10 = x
        x = self.conv2(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = x + identity10
        x = self.relu(x)
        
        # transpose4: 64->1
        x = self.relu(self.conv_transpose4(x))
        
        out = x.reshape(x.size(0), -1)
        
        return out

# %%
class Optimization:
    def __init__(self, model, optimizer):
        self.model = model
        self.loss_fn = nn.MSELoss(reduction="mean")
        self.optimizer = optimizer
        self.train_losses = []
        self.val_losses = []
    
    def train_step(self, x, y):
        # Sets model to train mode
        self.model.train()

        # Makes predictions
        yhat = self.model(x)

        # Computes loss
        loss = self.loss_fn(y, yhat)

        # Computes gradients
        loss.backward()

        # Updates parameters and zeroes gradients
        self.optimizer.step()
        self.optimizer.zero_grad()

        # Returns the loss
        return loss.item()

    def train(self, train_loader, val_loader, batch_size=4, n_epochs=50):
        model_path = f'models/{self.model}_{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'

        for epoch in range(1, n_epochs + 1):
            batch_losses = []
            for x_batch, y_batch in train_loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.view([batch_size, 576*384]).to(device)
                loss = self.train_step(x_batch, y_batch)
                batch_losses.append(loss)
            training_loss = np.mean(batch_losses)
            self.train_losses.append(training_loss)

            with torch.no_grad():
                batch_val_losses = []
                for x_val, y_val in val_loader:
                    x_val = x_val.to(device)
                    y_val = y_val.view([batch_size, 576*384]).to(device)
                    self.model.eval()
                    yhat = self.model(x_val).to(device)
                    val_loss = self.loss_fn(y_val, yhat).item()
                    batch_val_losses.append(val_loss)
                validation_loss = np.mean(batch_val_losses)
                self.val_losses.append(validation_loss)

            if (epoch % 5 == 0):
                print(
                    f"[{epoch}/{n_epochs}] Training loss: {training_loss:.6f}\t Validation loss: {validation_loss:.6f}"
                )
            
            if (validation_loss <= 0.0045):
                break

#         torch.save(self.model.state_dict(), model_path)

    def evaluate(self, test_loader, batch_size=1):
        with torch.no_grad():
            predictions = []
            values = []
            for x_test, y_test in test_loader:
                x_test = x_test.to(device)
                y_test = y_test.view([batch_size, 576*384]).to(device)
                self.model.eval()
                yhat = self.model(x_test)
                predictions.append(yhat.cpu().detach().numpy())
                values.append(y_test.cpu().detach().numpy())

        return predictions, values

    def plot_losses(self):
        plt.plot(self.train_losses, label="Training loss")
        plt.plot(self.val_losses, label="Validation loss")
        plt.legend()
        plt.title("Losses")
        plt.show()
        plt.close()

# %%
input_size = 672//4
output_size = 576 * 384

batch_size = batch_size
n_epochs = 5000
learning_rate = 1e-4
weight_decay = learning_rate/n_epochs

model = BC2Map(input_size, output_size, background_map=sup_feat, batch_size=batch_size).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

opt = Optimization(model=model, optimizer=optimizer)
opt.train(train_loader, test_loader, batch_size=batch_size, n_epochs=n_epochs)
opt.plot_losses()
# Out:
# [5/5000] Training loss: 1.507126	 Validation loss: 2.759225
# [10/5000] Training loss: 0.254114	 Validation loss: 0.255046
# [15/5000] Training loss: 0.109363	 Validation loss: 0.173954
# [20/5000] Training loss: 0.079664	 Validation loss: 0.137747
# [25/5000] Training loss: 0.073244	 Validation loss: 0.145695
# [30/5000] Training loss: 0.086772	 Validation loss: 0.128187
# [35/5000] Training loss: 0.079887	 Validation loss: 0.122368
# [40/5000] Training loss: 0.080538	 Validation loss: 0.125294
# [45/5000] Training loss: 0.090958	 Validation loss: 0.149716
# [50/5000] Training loss: 0.091435	 Validation loss: 0.160590
# [55/5000] Training loss: 0.064856	 Validation loss: 0.115860
# [60/5000] Training loss: 0.202075	 Validation loss: 0.607233
# [65/5000] Training loss: 0.114255	 Validation loss: 0.333409
# [70/5000] Training loss: 0.058237	 Validation loss: 0.104546
# [75/5000] Training loss: 0.103305	 Validation loss: 0.119842
# [80/5000] Training loss: 0.048274	 Validation loss: 0.085118
# [85/5000] Training loss: 0.045259	 Validation loss: 0.084627
# [90/5000] Training loss: 0.045842	 Validation loss: 0.083613
# [95/5000] Training loss: 0.055982	 Validation loss: 0.084078
# [100/5000] Training loss: 0.058008	 Validation loss: 0.088815
# [105/5000] Training loss: 0.050904	 Validation loss: 0.089234
# [110/5000] Training loss: 0.052169	 Validation loss: 0.087562
# [115/5000] Training loss: 0.189726	 Validation loss: 0.221619
# [120/5000] Training loss: 0.093035	 Validation loss: 0.109599
# [125/5000] Training loss: 0.048530	 Validation loss: 0.086827
# [130/5000] Training loss: 0.042759	 Validation loss: 0.078642
# [135/5000] Training loss: 0.043304	 Validation loss: 0.084051
# [140/5000] Training loss: 0.041946	 Validation loss: 0.077242
# [145/5000] Training loss: 0.040840	 Validation loss: 0.076298
# [150/5000] Training loss: 0.046075	 Validation loss: 0.077302
# [155/5000] Training loss: 0.046016	 Validation loss: 0.086811
# [160/5000] Training loss: 0.043933	 Validation loss: 0.073599
# [165/5000] Training loss: 0.042462	 Validation loss: 0.074492
# [170/5000] Training loss: 0.039429	 Validation loss: 0.088496
# [175/5000] Training loss: 0.061892	 Validation loss: 0.092782
# [180/5000] Training loss: 0.045705	 Validation loss: 0.084128
# [185/5000] Training loss: 0.048704	 Validation loss: 0.075729
# [190/5000] Training loss: 0.037179	 Validation loss: 0.073151
# [195/5000] Training loss: 0.041097	 Validation loss: 0.074089
# [200/5000] Training loss: 0.046732	 Validation loss: 0.067440
# [205/5000] Training loss: 0.033517	 Validation loss: 0.063842
# [210/5000] Training loss: 0.032535	 Validation loss: 0.061481
# [215/5000] Training loss: 0.041676	 Validation loss: 0.056320
# [220/5000] Training loss: 0.042303	 Validation loss: 0.088116
# [225/5000] Training loss: 0.036711	 Validation loss: 0.054242
# [230/5000] Training loss: 0.035209	 Validation loss: 0.050639
# [235/5000] Training loss: 0.027418	 Validation loss: 0.053932
# [240/5000] Training loss: 0.034658	 Validation loss: 0.060141
# [245/5000] Training loss: 0.032459	 Validation loss: 0.072503
# [250/5000] Training loss: 0.053802	 Validation loss: 0.051725
# [255/5000] Training loss: 0.032854	 Validation loss: 0.055427
# [260/5000] Training loss: 0.033912	 Validation loss: 0.053618
# [265/5000] Training loss: 0.020573	 Validation loss: 0.051685
# [270/5000] Training loss: 0.030805	 Validation loss: 0.052147
# [275/5000] Training loss: 0.039970	 Validation loss: 0.063087
# [280/5000] Training loss: 0.030695	 Validation loss: 0.071854
# [285/5000] Training loss: 0.035387	 Validation loss: 0.040360
# [290/5000] Training loss: 0.019821	 Validation loss: 0.044588
# [295/5000] Training loss: 0.026308	 Validation loss: 0.030825
# [300/5000] Training loss: 0.024093	 Validation loss: 0.055226
# [305/5000] Training loss: 0.032627	 Validation loss: 0.026251
# [310/5000] Training loss: 0.017148	 Validation loss: 0.034109
# [315/5000] Training loss: 0.022429	 Validation loss: 0.027856
# [320/5000] Training loss: 0.013753	 Validation loss: 0.021620
# [325/5000] Training loss: 0.008225	 Validation loss: 0.018345
# [330/5000] Training loss: 0.008610	 Validation loss: 0.026156
# [335/5000] Training loss: 0.009402	 Validation loss: 0.025456
# [340/5000] Training loss: 0.009473	 Validation loss: 0.019697
# [345/5000] Training loss: 0.009229	 Validation loss: 0.046130
# [350/5000] Training loss: 0.179947	 Validation loss: 0.152924
# [355/5000] Training loss: 0.043546	 Validation loss: 0.155338
# [360/5000] Training loss: 0.027161	 Validation loss: 0.031863
# [365/5000] Training loss: 0.012261	 Validation loss: 0.021766
# [370/5000] Training loss: 0.011656	 Validation loss: 0.029453
# [375/5000] Training loss: 0.006610	 Validation loss: 0.021722
# [380/5000] Training loss: 0.005882	 Validation loss: 0.017928
# [385/5000] Training loss: 0.005444	 Validation loss: 0.015815
# [390/5000] Training loss: 0.011460	 Validation loss: 0.031583
# [395/5000] Training loss: 0.007673	 Validation loss: 0.016498
# [400/5000] Training loss: 0.010688	 Validation loss: 0.022062
# [405/5000] Training loss: 0.006392	 Validation loss: 0.022827
# [410/5000] Training loss: 0.004423	 Validation loss: 0.018691
# [415/5000] Training loss: 0.006703	 Validation loss: 0.041612
# [420/5000] Training loss: 0.016215	 Validation loss: 0.036701
# [425/5000] Training loss: 0.006537	 Validation loss: 0.028315
# [430/5000] Training loss: 0.023010	 Validation loss: 0.031634
# [435/5000] Training loss: 0.014392	 Validation loss: 0.017084
# [440/5000] Training loss: 0.011647	 Validation loss: 0.018458
# [445/5000] Training loss: 0.008116	 Validation loss: 0.021273
# [450/5000] Training loss: 0.003290	 Validation loss: 0.014316
# [455/5000] Training loss: 0.005750	 Validation loss: 0.036421
# [460/5000] Training loss: 0.013155	 Validation loss: 0.034233
# [465/5000] Training loss: 0.025592	 Validation loss: 0.020226
# [470/5000] Training loss: 0.010131	 Validation loss: 0.019200
# [475/5000] Training loss: 0.203293	 Validation loss: 0.129276
# [480/5000] Training loss: 0.023119	 Validation loss: 0.022946
# [485/5000] Training loss: 0.011579	 Validation loss: 0.014453
# [490/5000] Training loss: 0.012306	 Validation loss: 0.016282
# [495/5000] Training loss: 0.004411	 Validation loss: 0.016140
# [500/5000] Training loss: 0.003497	 Validation loss: 0.011465
# [505/5000] Training loss: 0.005181	 Validation loss: 0.011413
# [510/5000] Training loss: 0.007346	 Validation loss: 0.018473
# [515/5000] Training loss: 0.011932	 Validation loss: 0.011788
# [520/5000] Training loss: 0.018389	 Validation loss: 0.021483
# [525/5000] Training loss: 0.004936	 Validation loss: 0.014148
# [530/5000] Training loss: 0.008222	 Validation loss: 0.017322
# [535/5000] Training loss: 0.006926	 Validation loss: 0.012651
# [540/5000] Training loss: 0.006666	 Validation loss: 0.012987
# [545/5000] Training loss: 0.002346	 Validation loss: 0.010079
# [550/5000] Training loss: 0.003644	 Validation loss: 0.019306
# [555/5000] Training loss: 0.028903	 Validation loss: 0.026775
# [560/5000] Training loss: 0.010230	 Validation loss: 0.013301
# [565/5000] Training loss: 0.004280	 Validation loss: 0.028731
# [570/5000] Training loss: 0.002720	 Validation loss: 0.013975
# [575/5000] Training loss: 0.003290	 Validation loss: 0.019243
# [580/5000] Training loss: 0.007961	 Validation loss: 0.030601
# [585/5000] Training loss: 0.025640	 Validation loss: 0.016114
# [590/5000] Training loss: 0.007298	 Validation loss: 0.014531
# [595/5000] Training loss: 0.003839	 Validation loss: 0.013759
# [600/5000] Training loss: 0.002212	 Validation loss: 0.013258
# [605/5000] Training loss: 0.002127	 Validation loss: 0.013010
# [610/5000] Training loss: 0.002666	 Validation loss: 0.010947
# [615/5000] Training loss: 0.002374	 Validation loss: 0.012235
# [620/5000] Training loss: 0.016833	 Validation loss: 0.027193
# [625/5000] Training loss: 0.024637	 Validation loss: 0.028044
# [630/5000] Training loss: 0.021699	 Validation loss: 0.031260
# [635/5000] Training loss: 0.003490	 Validation loss: 0.020220
# [640/5000] Training loss: 0.003034	 Validation loss: 0.014111
# [645/5000] Training loss: 0.001816	 Validation loss: 0.017349
# [650/5000] Training loss: 0.001722	 Validation loss: 0.023093
# [655/5000] Training loss: 0.002644	 Validation loss: 0.019398
# [660/5000] Training loss: 0.017963	 Validation loss: 0.037507
# [665/5000] Training loss: 0.003858	 Validation loss: 0.016526
# [670/5000] Training loss: 0.009511	 Validation loss: 0.083426
# [675/5000] Training loss: 0.005328	 Validation loss: 0.017772
# [680/5000] Training loss: 0.006908	 Validation loss: 0.013078
# [685/5000] Training loss: 0.002153	 Validation loss: 0.012718
# [690/5000] Training loss: 0.001379	 Validation loss: 0.013593
# [695/5000] Training loss: 0.001555	 Validation loss: 0.013491
# [700/5000] Training loss: 0.004651	 Validation loss: 0.012667
# [705/5000] Training loss: 0.005106	 Validation loss: 0.014950
# [710/5000] Training loss: 0.009394	 Validation loss: 0.014292
# [715/5000] Training loss: 0.007408	 Validation loss: 0.015187
# [720/5000] Training loss: 0.011530	 Validation loss: 0.016909
# [725/5000] Training loss: 0.003376	 Validation loss: 0.015873
# [730/5000] Training loss: 0.004124	 Validation loss: 0.013953
# [735/5000] Training loss: 0.003883	 Validation loss: 0.010011
# [740/5000] Training loss: 0.001975	 Validation loss: 0.031112
# [745/5000] Training loss: 0.003191	 Validation loss: 0.015003
# [750/5000] Training loss: 0.001999	 Validation loss: 0.012814
# [755/5000] Training loss: 0.001425	 Validation loss: 0.013537
# [760/5000] Training loss: 0.002404	 Validation loss: 0.018204
# [765/5000] Training loss: 0.015450	 Validation loss: 0.017439
# [770/5000] Training loss: 0.002638	 Validation loss: 0.016662
# [775/5000] Training loss: 0.003412	 Validation loss: 0.010553
# [780/5000] Training loss: 0.001558	 Validation loss: 0.010134
# [785/5000] Training loss: 0.004137	 Validation loss: 0.012163
# [790/5000] Training loss: 0.010468	 Validation loss: 0.009270
# [795/5000] Training loss: 0.002191	 Validation loss: 0.011622
# [800/5000] Training loss: 0.002328	 Validation loss: 0.009354
# [805/5000] Training loss: 0.000983	 Validation loss: 0.011522
# [810/5000] Training loss: 0.004625	 Validation loss: 0.055237
# [815/5000] Training loss: 0.004040	 Validation loss: 0.014118
# [820/5000] Training loss: 0.004763	 Validation loss: 0.019202
# [825/5000] Training loss: 0.002675	 Validation loss: 0.011231
# [830/5000] Training loss: 0.004312	 Validation loss: 0.021976
# [835/5000] Training loss: 0.012302	 Validation loss: 0.024801
# [840/5000] Training loss: 0.005250	 Validation loss: 0.013143
# [845/5000] Training loss: 0.003588	 Validation loss: 0.018176
# [850/5000] Training loss: 0.000997	 Validation loss: 0.009483
# [855/5000] Training loss: 0.001315	 Validation loss: 0.009193
# [860/5000] Training loss: 0.001635	 Validation loss: 0.012887
# [865/5000] Training loss: 0.006467	 Validation loss: 0.015854
# [870/5000] Training loss: 0.010269	 Validation loss: 0.013912
# [875/5000] Training loss: 0.001449	 Validation loss: 0.015135
# [880/5000] Training loss: 0.001300	 Validation loss: 0.011284
# [885/5000] Training loss: 0.001427	 Validation loss: 0.010794
# [890/5000] Training loss: 0.011027	 Validation loss: 0.133345
# [895/5000] Training loss: 0.009625	 Validation loss: 0.029197
# [900/5000] Training loss: 0.008457	 Validation loss: 0.011447
# [905/5000] Training loss: 0.008486	 Validation loss: 0.018228
# [910/5000] Training loss: 0.008346	 Validation loss: 0.017343
# [915/5000] Training loss: 0.002695	 Validation loss: 0.020361
# [920/5000] Training loss: 0.004560	 Validation loss: 0.026592
# [925/5000] Training loss: 0.002981	 Validation loss: 0.017222
# [930/5000] Training loss: 0.001588	 Validation loss: 0.016136
# [935/5000] Training loss: 0.001179	 Validation loss: 0.012517
# [940/5000] Training loss: 0.001286	 Validation loss: 0.011963
# [945/5000] Training loss: 0.003024	 Validation loss: 0.014765
# [950/5000] Training loss: 0.001678	 Validation loss: 0.012256
# [955/5000] Training loss: 0.001943	 Validation loss: 0.014811
# [960/5000] Training loss: 0.001127	 Validation loss: 0.015694
# [965/5000] Training loss: 0.001835	 Validation loss: 0.011396
# [970/5000] Training loss: 0.004643	 Validation loss: 0.010815
# [975/5000] Training loss: 0.007650	 Validation loss: 0.012526
# [980/5000] Training loss: 0.001770	 Validation loss: 0.031298
# [985/5000] Training loss: 0.001721	 Validation loss: 0.016269
# [990/5000] Training loss: 0.001404	 Validation loss: 0.014572
# [995/5000] Training loss: 0.000881	 Validation loss: 0.011097
# [1000/5000] Training loss: 0.002540	 Validation loss: 0.013631
# [1005/5000] Training loss: 0.008373	 Validation loss: 0.018800
# [1010/5000] Training loss: 0.005841	 Validation loss: 0.024952
# [1015/5000] Training loss: 0.011558	 Validation loss: 0.034340
# [1020/5000] Training loss: 0.001541	 Validation loss: 0.012211
# [1025/5000] Training loss: 0.001849	 Validation loss: 0.029927
# [1030/5000] Training loss: 0.001977	 Validation loss: 0.016954
# [1035/5000] Training loss: 0.000978	 Validation loss: 0.013251
# [1040/5000] Training loss: 0.002468	 Validation loss: 0.013348
# [1045/5000] Training loss: 0.001197	 Validation loss: 0.017157
# [1050/5000] Training loss: 0.002705	 Validation loss: 0.014112
# [1055/5000] Training loss: 0.002695	 Validation loss: 0.013733
# [1060/5000] Training loss: 0.010369	 Validation loss: 0.014481
# [1065/5000] Training loss: 0.001730	 Validation loss: 0.013264
# [1070/5000] Training loss: 0.006389	 Validation loss: 0.011657
# [1075/5000] Training loss: 0.002427	 Validation loss: 0.010101
# [1080/5000] Training loss: 0.001286	 Validation loss: 0.011081
# [1085/5000] Training loss: 0.002057	 Validation loss: 0.016724
# [1090/5000] Training loss: 0.005611	 Validation loss: 0.015046
# [1095/5000] Training loss: 0.001579	 Validation loss: 0.011769
# [1100/5000] Training loss: 0.002235	 Validation loss: 0.011357
# [1105/5000] Training loss: 0.003959	 Validation loss: 0.014685
# [1110/5000] Training loss: 0.000629	 Validation loss: 0.015476
# [1115/5000] Training loss: 0.002856	 Validation loss: 0.016198
# [1120/5000] Training loss: 0.001870	 Validation loss: 0.016287
# [1125/5000] Training loss: 0.001274	 Validation loss: 0.020917
# [1130/5000] Training loss: 0.000848	 Validation loss: 0.010655
# [1135/5000] Training loss: 0.005438	 Validation loss: 0.028328
# [1140/5000] Training loss: 0.010296	 Validation loss: 0.029718
# [1145/5000] Training loss: 0.005464	 Validation loss: 0.011040
# [1150/5000] Training loss: 0.005846	 Validation loss: 0.023848
# [1155/5000] Training loss: 0.001258	 Validation loss: 0.014297
# [1160/5000] Training loss: 0.002258	 Validation loss: 0.010085
# [1165/5000] Training loss: 0.002657	 Validation loss: 0.024040
# [1170/5000] Training loss: 0.007574	 Validation loss: 0.013853
# [1175/5000] Training loss: 0.006524	 Validation loss: 0.012189
# [1180/5000] Training loss: 0.000818	 Validation loss: 0.011716
# [1185/5000] Training loss: 0.008298	 Validation loss: 0.014271
# [1190/5000] Training loss: 0.001327	 Validation loss: 0.011528
# [1195/5000] Training loss: 0.001132	 Validation loss: 0.011090
# [1200/5000] Training loss: 0.001490	 Validation loss: 0.030221
# [1205/5000] Training loss: 0.001390	 Validation loss: 0.013927
# [1210/5000] Training loss: 0.002328	 Validation loss: 0.020992
# [1215/5000] Training loss: 0.002786	 Validation loss: 0.024048
# [1220/5000] Training loss: 0.001004	 Validation loss: 0.010350
# [1225/5000] Training loss: 0.002395	 Validation loss: 0.013172
# [1230/5000] Training loss: 0.002638	 Validation loss: 0.009837
# [1235/5000] Training loss: 0.004483	 Validation loss: 0.011564
# [1240/5000] Training loss: 0.002681	 Validation loss: 0.012774
# [1245/5000] Training loss: 0.000492	 Validation loss: 0.012361
# [1250/5000] Training loss: 0.000924	 Validation loss: 0.010733
# [1255/5000] Training loss: 0.002877	 Validation loss: 0.010741
# [1260/5000] Training loss: 0.006029	 Validation loss: 0.011556
# [1265/5000] Training loss: 0.001841	 Validation loss: 0.012474
# [1270/5000] Training loss: 0.000736	 Validation loss: 0.011861
# [1275/5000] Training loss: 0.058977	 Validation loss: 0.081253
# [1280/5000] Training loss: 0.010920	 Validation loss: 0.033384
# [1285/5000] Training loss: 0.003355	 Validation loss: 0.023225
# [1290/5000] Training loss: 0.002700	 Validation loss: 0.021111
# [1295/5000] Training loss: 0.001898	 Validation loss: 0.021408
# [1300/5000] Training loss: 0.001422	 Validation loss: 0.022155
# [1305/5000] Training loss: 0.001247	 Validation loss: 0.021000
# [1310/5000] Training loss: 0.001311	 Validation loss: 0.019168
# [1315/5000] Training loss: 0.001637	 Validation loss: 0.019737
# [1320/5000] Training loss: 0.001517	 Validation loss: 0.020508
# [1325/5000] Training loss: 0.001077	 Validation loss: 0.020427
# [1330/5000] Training loss: 0.002149	 Validation loss: 0.017649
# [1335/5000] Training loss: 0.015266	 Validation loss: 0.016388
# [1340/5000] Training loss: 0.002424	 Validation loss: 0.017478
# [1345/5000] Training loss: 0.001274	 Validation loss: 0.020330
# [1350/5000] Training loss: 0.001375	 Validation loss: 0.014949
# [1355/5000] Training loss: 0.001539	 Validation loss: 0.016928
# [1360/5000] Training loss: 0.000901	 Validation loss: 0.016436
# [1365/5000] Training loss: 0.002827	 Validation loss: 0.015185
# [1370/5000] Training loss: 0.001100	 Validation loss: 0.012912
# [1375/5000] Training loss: 0.000924	 Validation loss: 0.013913
# [1380/5000] Training loss: 0.005153	 Validation loss: 0.014132
# [1385/5000] Training loss: 0.003122	 Validation loss: 0.016908
# [1390/5000] Training loss: 0.000915	 Validation loss: 0.013284
# [1395/5000] Training loss: 0.000440	 Validation loss: 0.014306
# [1400/5000] Training loss: 0.001868	 Validation loss: 0.032136
# [1405/5000] Training loss: 0.001645	 Validation loss: 0.016713
# [1410/5000] Training loss: 0.002900	 Validation loss: 0.014120
# [1415/5000] Training loss: 0.001481	 Validation loss: 0.027547
# [1420/5000] Training loss: 0.001365	 Validation loss: 0.016294
# [1425/5000] Training loss: 0.003646	 Validation loss: 0.022914
# [1430/5000] Training loss: 0.006459	 Validation loss: 0.016803
# [1435/5000] Training loss: 0.003087	 Validation loss: 0.012225
# [1440/5000] Training loss: 0.001181	 Validation loss: 0.012790
# [1445/5000] Training loss: 0.000470	 Validation loss: 0.011252
# [1450/5000] Training loss: 0.000390	 Validation loss: 0.015635
# [1455/5000] Training loss: 0.000560	 Validation loss: 0.016445
# [1460/5000] Training loss: 0.003883	 Validation loss: 0.026993
# [1465/5000] Training loss: 0.004885	 Validation loss: 0.016995
# [1470/5000] Training loss: 0.007679	 Validation loss: 0.018612
# [1475/5000] Training loss: 0.000771	 Validation loss: 0.015477
# [1480/5000] Training loss: 0.001687	 Validation loss: 0.012431
# [1485/5000] Training loss: 0.002532	 Validation loss: 0.018074
# [1490/5000] Training loss: 0.000502	 Validation loss: 0.015200
# [1495/5000] Training loss: 0.000715	 Validation loss: 0.018295
# [1500/5000] Training loss: 0.000579	 Validation loss: 0.014976
# [1505/5000] Training loss: 0.003553	 Validation loss: 0.014302
# [1510/5000] Training loss: 0.007969	 Validation loss: 0.011284
# [1515/5000] Training loss: 0.001228	 Validation loss: 0.014226
# [1520/5000] Training loss: 0.000619	 Validation loss: 0.011027
# [1525/5000] Training loss: 0.000450	 Validation loss: 0.011872
# [1530/5000] Training loss: 0.000866	 Validation loss: 0.012343
# [1535/5000] Training loss: 0.000693	 Validation loss: 0.013102
# [1540/5000] Training loss: 0.002879	 Validation loss: 0.016120
# [1545/5000] Training loss: 0.005425	 Validation loss: 0.010735
# [1550/5000] Training loss: 0.001084	 Validation loss: 0.013828
# [1555/5000] Training loss: 0.001548	 Validation loss: 0.012051
# [1560/5000] Training loss: 0.000908	 Validation loss: 0.015631
# [1565/5000] Training loss: 0.001965	 Validation loss: 0.009671
# [1570/5000] Training loss: 0.000422	 Validation loss: 0.012924
# [1575/5000] Training loss: 0.000851	 Validation loss: 0.010757
# [1580/5000] Training loss: 0.078862	 Validation loss: 0.046129
# [1585/5000] Training loss: 0.001840	 Validation loss: 0.013431
# [1590/5000] Training loss: 0.000574	 Validation loss: 0.012633
# [1595/5000] Training loss: 0.000432	 Validation loss: 0.012519
# [1600/5000] Training loss: 0.000285	 Validation loss: 0.011720
# [1605/5000] Training loss: 0.000355	 Validation loss: 0.011343
# [1610/5000] Training loss: 0.000865	 Validation loss: 0.012250
# [1615/5000] Training loss: 0.005266	 Validation loss: 0.022430
# [1620/5000] Training loss: 0.000657	 Validation loss: 0.010229
# [1625/5000] Training loss: 0.000287	 Validation loss: 0.013782
# [1630/5000] Training loss: 0.000202	 Validation loss: 0.011308
# [1635/5000] Training loss: 0.000186	 Validation loss: 0.012022
# [1640/5000] Training loss: 0.000363	 Validation loss: 0.011865
# [1645/5000] Training loss: 0.002937	 Validation loss: 0.016665
# [1650/5000] Training loss: 0.002966	 Validation loss: 0.016889
# [1655/5000] Training loss: 0.000925	 Validation loss: 0.013925
# [1660/5000] Training loss: 0.000394	 Validation loss: 0.010833
# [1665/5000] Training loss: 0.000328	 Validation loss: 0.010716
# [1670/5000] Training loss: 0.000871	 Validation loss: 0.010459
# [1675/5000] Training loss: 0.002108	 Validation loss: 0.020066
# [1680/5000] Training loss: 0.000812	 Validation loss: 0.013434
# [1685/5000] Training loss: 0.000295	 Validation loss: 0.010359
# [1690/5000] Training loss: 0.002128	 Validation loss: 0.014696
# [1695/5000] Training loss: 0.001854	 Validation loss: 0.008830
# [1700/5000] Training loss: 0.001706	 Validation loss: 0.009334
# [1705/5000] Training loss: 0.001239	 Validation loss: 0.011750
# [1710/5000] Training loss: 0.000314	 Validation loss: 0.010654
# [1715/5000] Training loss: 0.000323	 Validation loss: 0.009565
# [1720/5000] Training loss: 0.000402	 Validation loss: 0.008770
# [1725/5000] Training loss: 0.000742	 Validation loss: 0.010187
# [1730/5000] Training loss: 0.006638	 Validation loss: 0.013913
# [1735/5000] Training loss: 0.001028	 Validation loss: 0.011135
# [1740/5000] Training loss: 0.000788	 Validation loss: 0.009784
# [1745/5000] Training loss: 0.001007	 Validation loss: 0.015538
# [1750/5000] Training loss: 0.088772	 Validation loss: 0.157826
# [1755/5000] Training loss: 0.003386	 Validation loss: 0.021235
# [1760/5000] Training loss: 0.002042	 Validation loss: 0.016353
# [1765/5000] Training loss: 0.001041	 Validation loss: 0.016909
# [1770/5000] Training loss: 0.000834	 Validation loss: 0.015492
# [1775/5000] Training loss: 0.000917	 Validation loss: 0.017861
# [1780/5000] Training loss: 0.000643	 Validation loss: 0.016198
# [1785/5000] Training loss: 0.000596	 Validation loss: 0.014978
# [1790/5000] Training loss: 0.000457	 Validation loss: 0.015502
# [1795/5000] Training loss: 0.000774	 Validation loss: 0.014316
# [1800/5000] Training loss: 0.000509	 Validation loss: 0.013841
# [1805/5000] Training loss: 0.000415	 Validation loss: 0.014847
# [1810/5000] Training loss: 0.000848	 Validation loss: 0.017837
# [1815/5000] Training loss: 0.002099	 Validation loss: 0.012230
# [1820/5000] Training loss: 0.004470	 Validation loss: 0.018401
# [1825/5000] Training loss: 0.000974	 Validation loss: 0.010502
# [1830/5000] Training loss: 0.000665	 Validation loss: 0.013308
# [1835/5000] Training loss: 0.000972	 Validation loss: 0.013654
# [1840/5000] Training loss: 0.000633	 Validation loss: 0.012919
# [1845/5000] Training loss: 0.002287	 Validation loss: 0.019549
# [1850/5000] Training loss: 0.002774	 Validation loss: 0.022919
# [1855/5000] Training loss: 0.000845	 Validation loss: 0.013403
# [1860/5000] Training loss: 0.000486	 Validation loss: 0.013081
# [1865/5000] Training loss: 0.004268	 Validation loss: 0.011678
# [1870/5000] Training loss: 0.000798	 Validation loss: 0.011460
# [1875/5000] Training loss: 0.000370	 Validation loss: 0.010130
# [1880/5000] Training loss: 0.000450	 Validation loss: 0.009311
# [1885/5000] Training loss: 0.000350	 Validation loss: 0.012294
# [1890/5000] Training loss: 0.000803	 Validation loss: 0.011638
# [1895/5000] Training loss: 0.000902	 Validation loss: 0.008733
# [1900/5000] Training loss: 0.000571	 Validation loss: 0.010214
# [1905/5000] Training loss: 0.002711	 Validation loss: 0.007490
# [1910/5000] Training loss: 0.000720	 Validation loss: 0.010448
# [1915/5000] Training loss: 0.005623	 Validation loss: 0.011211
# [1920/5000] Training loss: 0.001089	 Validation loss: 0.007534
# [1925/5000] Training loss: 0.000383	 Validation loss: 0.009629
# [1930/5000] Training loss: 0.000271	 Validation loss: 0.008028
# [1935/5000] Training loss: 0.000574	 Validation loss: 0.010958
# [1940/5000] Training loss: 0.000392	 Validation loss: 0.008131
# [1945/5000] Training loss: 0.001912	 Validation loss: 0.008236
# [1950/5000] Training loss: 0.000610	 Validation loss: 0.011149
# [1955/5000] Training loss: 0.001094	 Validation loss: 0.008718
# [1960/5000] Training loss: 0.000415	 Validation loss: 0.007295
# [1965/5000] Training loss: 0.001214	 Validation loss: 0.009025
# [1970/5000] Training loss: 0.000897	 Validation loss: 0.010987
# [1975/5000] Training loss: 0.000707	 Validation loss: 0.009560
# [1980/5000] Training loss: 0.000227	 Validation loss: 0.009090
# [1985/5000] Training loss: 0.003471	 Validation loss: 0.008863
# [1990/5000] Training loss: 0.000832	 Validation loss: 0.009420
# [1995/5000] Training loss: 0.000373	 Validation loss: 0.008441
# [2000/5000] Training loss: 0.001659	 Validation loss: 0.008207
# [2005/5000] Training loss: 0.001872	 Validation loss: 0.024059
# [2010/5000] Training loss: 0.004230	 Validation loss: 0.014807
# [2015/5000] Training loss: 0.002737	 Validation loss: 0.009801
# [2020/5000] Training loss: 0.000535	 Validation loss: 0.008527
# [2025/5000] Training loss: 0.000459	 Validation loss: 0.010297
# [2030/5000] Training loss: 0.000151	 Validation loss: 0.008978
# [2035/5000] Training loss: 0.000263	 Validation loss: 0.008951
# [2040/5000] Training loss: 0.000272	 Validation loss: 0.009611
# [2045/5000] Training loss: 0.000694	 Validation loss: 0.011526
# [2050/5000] Training loss: 0.000689	 Validation loss: 0.008513
# [2055/5000] Training loss: 0.000944	 Validation loss: 0.007582
# [2060/5000] Training loss: 0.001746	 Validation loss: 0.012135
# [2065/5000] Training loss: 0.003300	 Validation loss: 0.007630
# [2070/5000] Training loss: 0.000433	 Validation loss: 0.008650
# [2075/5000] Training loss: 0.001020	 Validation loss: 0.009558
# [2080/5000] Training loss: 0.000206	 Validation loss: 0.009566
# [2085/5000] Training loss: 0.000295	 Validation loss: 0.009902
# [2090/5000] Training loss: 0.000928	 Validation loss: 0.007959
# [2095/5000] Training loss: 0.000395	 Validation loss: 0.008764
# [2100/5000] Training loss: 0.000429	 Validation loss: 0.009896
# [2105/5000] Training loss: 0.000847	 Validation loss: 0.008004
# [2110/5000] Training loss: 0.002293	 Validation loss: 0.010632
# [2115/5000] Training loss: 0.000437	 Validation loss: 0.009051
# [2120/5000] Training loss: 0.000314	 Validation loss: 0.010021
# [2125/5000] Training loss: 0.000272	 Validation loss: 0.008787
# [2130/5000] Training loss: 0.000287	 Validation loss: 0.008233
# [2135/5000] Training loss: 0.000326	 Validation loss: 0.008742
# [2140/5000] Training loss: 0.001450	 Validation loss: 0.011460
# [2145/5000] Training loss: 0.001124	 Validation loss: 0.019228
# [2150/5000] Training loss: 0.001870	 Validation loss: 0.015644
# [2155/5000] Training loss: 0.000445	 Validation loss: 0.014472
# [2160/5000] Training loss: 0.000232	 Validation loss: 0.012208
# [2165/5000] Training loss: 0.000144	 Validation loss: 0.012651
# [2170/5000] Training loss: 0.000130	 Validation loss: 0.011867
# [2175/5000] Training loss: 0.000124	 Validation loss: 0.011875
# [2180/5000] Training loss: 0.000170	 Validation loss: 0.012317
# [2185/5000] Training loss: 0.000322	 Validation loss: 0.012379
# [2190/5000] Training loss: 0.001005	 Validation loss: 0.012512
# [2195/5000] Training loss: 0.001077	 Validation loss: 0.008981
# [2200/5000] Training loss: 0.000253	 Validation loss: 0.011289
# [2205/5000] Training loss: 0.000427	 Validation loss: 0.012654
# [2210/5000] Training loss: 0.000230	 Validation loss: 0.009196
# [2215/5000] Training loss: 0.000223	 Validation loss: 0.012038
# [2220/5000] Training loss: 0.000412	 Validation loss: 0.009074
# [2225/5000] Training loss: 0.000588	 Validation loss: 0.008484
# [2230/5000] Training loss: 0.001297	 Validation loss: 0.008772
# [2235/5000] Training loss: 0.000291	 Validation loss: 0.009719
# [2240/5000] Training loss: 0.000203	 Validation loss: 0.009917
# [2245/5000] Training loss: 0.000139	 Validation loss: 0.008517
# [2250/5000] Training loss: 0.000243	 Validation loss: 0.008307
# [2255/5000] Training loss: 0.000829	 Validation loss: 0.007841
# [2260/5000] Training loss: 0.002019	 Validation loss: 0.008866
# [2265/5000] Training loss: 0.000347	 Validation loss: 0.008796
# [2270/5000] Training loss: 0.000214	 Validation loss: 0.009440
# [2275/5000] Training loss: 0.000174	 Validation loss: 0.009479
# [2280/5000] Training loss: 0.000165	 Validation loss: 0.009011
# [2285/5000] Training loss: 0.000568	 Validation loss: 0.011039
# [2290/5000] Training loss: 0.000371	 Validation loss: 0.010505
# [2295/5000] Training loss: 0.000270	 Validation loss: 0.008457
# [2300/5000] Training loss: 0.000332	 Validation loss: 0.011345
# [2305/5000] Training loss: 0.000713	 Validation loss: 0.008010
# [2310/5000] Training loss: 0.000665	 Validation loss: 0.009067
# [2315/5000] Training loss: 0.000279	 Validation loss: 0.009851
# [2320/5000] Training loss: 0.001313	 Validation loss: 0.008932
# [2325/5000] Training loss: 0.002049	 Validation loss: 0.007674
# [2330/5000] Training loss: 0.002145	 Validation loss: 0.011266
# [2335/5000] Training loss: 0.000394	 Validation loss: 0.010293
# [2340/5000] Training loss: 0.000179	 Validation loss: 0.011062
# [2345/5000] Training loss: 0.000228	 Validation loss: 0.009577
# [2350/5000] Training loss: 0.000195	 Validation loss: 0.009662
# [2355/5000] Training loss: 0.000162	 Validation loss: 0.009148
# [2360/5000] Training loss: 0.016088	 Validation loss: 0.013072
# [2365/5000] Training loss: 0.001024	 Validation loss: 0.011111
# [2370/5000] Training loss: 0.000300	 Validation loss: 0.009366
# [2375/5000] Training loss: 0.000130	 Validation loss: 0.008811
# [2380/5000] Training loss: 0.000090	 Validation loss: 0.008468
# [2385/5000] Training loss: 0.000174	 Validation loss: 0.008369
# [2390/5000] Training loss: 0.000076	 Validation loss: 0.009425
# [2395/5000] Training loss: 0.000187	 Validation loss: 0.008245
# [2400/5000] Training loss: 0.001104	 Validation loss: 0.013796
# [2405/5000] Training loss: 0.000728	 Validation loss: 0.008928
# [2410/5000] Training loss: 0.000413	 Validation loss: 0.007788
# [2415/5000] Training loss: 0.000176	 Validation loss: 0.008553
# [2420/5000] Training loss: 0.000136	 Validation loss: 0.008034
# [2425/5000] Training loss: 0.000619	 Validation loss: 0.008927
# [2430/5000] Training loss: 0.001886	 Validation loss: 0.008979
# [2435/5000] Training loss: 0.000841	 Validation loss: 0.007545
# [2440/5000] Training loss: 0.000361	 Validation loss: 0.009285
# [2445/5000] Training loss: 0.000143	 Validation loss: 0.009190
# [2450/5000] Training loss: 0.000105	 Validation loss: 0.008055
# [2455/5000] Training loss: 0.000280	 Validation loss: 0.007614
# [2460/5000] Training loss: 0.000088	 Validation loss: 0.008712
# [2465/5000] Training loss: 0.000987	 Validation loss: 0.006789
# [2470/5000] Training loss: 0.003541	 Validation loss: 0.009322
# [2475/5000] Training loss: 0.000426	 Validation loss: 0.008890
# [2480/5000] Training loss: 0.000210	 Validation loss: 0.007765
# [2485/5000] Training loss: 0.000143	 Validation loss: 0.008627
# [2490/5000] Training loss: 0.000111	 Validation loss: 0.008116
# [2495/5000] Training loss: 0.000101	 Validation loss: 0.007668
# [2500/5000] Training loss: 0.000090	 Validation loss: 0.007633
# [2505/5000] Training loss: 0.000130	 Validation loss: 0.006966
# [2510/5000] Training loss: 0.000086	 Validation loss: 0.007558
# [2515/5000] Training loss: 0.000062	 Validation loss: 0.007942
# [2520/5000] Training loss: 0.000124	 Validation loss: 0.007509
# [2525/5000] Training loss: 0.000898	 Validation loss: 0.007137
# [2530/5000] Training loss: 0.000823	 Validation loss: 0.007739
# [2535/5000] Training loss: 0.000229	 Validation loss: 0.007771
# [2540/5000] Training loss: 0.000153	 Validation loss: 0.008332
# [2545/5000] Training loss: 0.000100	 Validation loss: 0.007880
# [2550/5000] Training loss: 0.000070	 Validation loss: 0.007888
# [2555/5000] Training loss: 0.000088	 Validation loss: 0.007726
# [2560/5000] Training loss: 0.000212	 Validation loss: 0.008136
# [2565/5000] Training loss: 0.000414	 Validation loss: 0.010105
# [2570/5000] Training loss: 0.000862	 Validation loss: 0.007645
# [2575/5000] Training loss: 0.000594	 Validation loss: 0.008203
# [2580/5000] Training loss: 0.000252	 Validation loss: 0.008050
# [2585/5000] Training loss: 0.000083	 Validation loss: 0.007719
# [2590/5000] Training loss: 0.000062	 Validation loss: 0.007597
# [2595/5000] Training loss: 0.000080	 Validation loss: 0.007384
# [2600/5000] Training loss: 0.000070	 Validation loss: 0.007741
# [2605/5000] Training loss: 0.000156	 Validation loss: 0.007855
# [2610/5000] Training loss: 0.000544	 Validation loss: 0.007576
# [2615/5000] Training loss: 0.001347	 Validation loss: 0.011559
# [2620/5000] Training loss: 0.000827	 Validation loss: 0.006787
# [2625/5000] Training loss: 0.000370	 Validation loss: 0.008195
# [2630/5000] Training loss: 0.000242	 Validation loss: 0.008129
# [2635/5000] Training loss: 0.000239	 Validation loss: 0.007770
# [2640/5000] Training loss: 0.001595	 Validation loss: 0.008352
# [2645/5000] Training loss: 0.000705	 Validation loss: 0.011454
# [2650/5000] Training loss: 0.000152	 Validation loss: 0.009064
# [2655/5000] Training loss: 0.000107	 Validation loss: 0.008406
# [2660/5000] Training loss: 0.000125	 Validation loss: 0.007969
# [2665/5000] Training loss: 0.000188	 Validation loss: 0.007517
# [2670/5000] Training loss: 0.000760	 Validation loss: 0.009765
# [2675/5000] Training loss: 0.014080	 Validation loss: 0.013591
# [2680/5000] Training loss: 0.000671	 Validation loss: 0.006638
# [2685/5000] Training loss: 0.000279	 Validation loss: 0.007544
# [2690/5000] Training loss: 0.000156	 Validation loss: 0.007041
# [2695/5000] Training loss: 0.000110	 Validation loss: 0.006777
# [2700/5000] Training loss: 0.000090	 Validation loss: 0.007058
# [2705/5000] Training loss: 0.000079	 Validation loss: 0.006878
# [2710/5000] Training loss: 0.000090	 Validation loss: 0.006682
# [2715/5000] Training loss: 0.000134	 Validation loss: 0.006267
# [2720/5000] Training loss: 0.000541	 Validation loss: 0.007523
# [2725/5000] Training loss: 0.001407	 Validation loss: 0.007964
# [2730/5000] Training loss: 0.000178	 Validation loss: 0.006068
# [2735/5000] Training loss: 0.000089	 Validation loss: 0.007265
# [2740/5000] Training loss: 0.000071	 Validation loss: 0.007056
# [2745/5000] Training loss: 0.000111	 Validation loss: 0.006225
# [2750/5000] Training loss: 0.000393	 Validation loss: 0.007254
# [2755/5000] Training loss: 0.000830	 Validation loss: 0.006944
# [2760/5000] Training loss: 0.000767	 Validation loss: 0.009489
# [2765/5000] Training loss: 0.000677	 Validation loss: 0.008496
# [2770/5000] Training loss: 0.000204	 Validation loss: 0.008153
# [2775/5000] Training loss: 0.000084	 Validation loss: 0.007781
# [2780/5000] Training loss: 0.000227	 Validation loss: 0.007322
# [2785/5000] Training loss: 0.001519	 Validation loss: 0.006649
# [2790/5000] Training loss: 0.000743	 Validation loss: 0.006950
# [2795/5000] Training loss: 0.014355	 Validation loss: 0.025121
# [2800/5000] Training loss: 0.000875	 Validation loss: 0.007702
# [2805/5000] Training loss: 0.000248	 Validation loss: 0.010044
# [2810/5000] Training loss: 0.000260	 Validation loss: 0.009191
# [2815/5000] Training loss: 0.000118	 Validation loss: 0.008712
# [2820/5000] Training loss: 0.000095	 Validation loss: 0.008622
# [2825/5000] Training loss: 0.000106	 Validation loss: 0.008678
# [2830/5000] Training loss: 0.000219	 Validation loss: 0.009755
# [2835/5000] Training loss: 0.000760	 Validation loss: 0.008156
# [2840/5000] Training loss: 0.000871	 Validation loss: 0.016178
# [2845/5000] Training loss: 0.000344	 Validation loss: 0.008529
# [2850/5000] Training loss: 0.000199	 Validation loss: 0.009013
# [2855/5000] Training loss: 0.000095	 Validation loss: 0.008874
# [2860/5000] Training loss: 0.000076	 Validation loss: 0.009685
# [2865/5000] Training loss: 0.000049	 Validation loss: 0.008315
# [2870/5000] Training loss: 0.000042	 Validation loss: 0.008159
# [2875/5000] Training loss: 0.000825	 Validation loss: 0.011022
# [2880/5000] Training loss: 0.001651	 Validation loss: 0.016814
# [2885/5000] Training loss: 0.000432	 Validation loss: 0.007765
# [2890/5000] Training loss: 0.000882	 Validation loss: 0.008920
# [2895/5000] Training loss: 0.000106	 Validation loss: 0.007134
# [2900/5000] Training loss: 0.000083	 Validation loss: 0.007862
# [2905/5000] Training loss: 0.000159	 Validation loss: 0.008982
# [2910/5000] Training loss: 0.000653	 Validation loss: 0.006877
# [2915/5000] Training loss: 0.001260	 Validation loss: 0.012204
# [2920/5000] Training loss: 0.000267	 Validation loss: 0.007990
# [2925/5000] Training loss: 0.000113	 Validation loss: 0.007454
# [2930/5000] Training loss: 0.000237	 Validation loss: 0.010035
# [2935/5000] Training loss: 0.001429	 Validation loss: 0.009111
# [2940/5000] Training loss: 0.000530	 Validation loss: 0.007747
# [2945/5000] Training loss: 0.000098	 Validation loss: 0.007919
# [2950/5000] Training loss: 0.000351	 Validation loss: 0.008770
# [2955/5000] Training loss: 0.000229	 Validation loss: 0.007227
# [2960/5000] Training loss: 0.000517	 Validation loss: 0.006664
# [2965/5000] Training loss: 0.000497	 Validation loss: 0.007408
# [2970/5000] Training loss: 0.000328	 Validation loss: 0.006464
# [2975/5000] Training loss: 0.000353	 Validation loss: 0.007056
# [2980/5000] Training loss: 0.000133	 Validation loss: 0.006604
# [2985/5000] Training loss: 0.000238	 Validation loss: 0.006021
# [2990/5000] Training loss: 0.000182	 Validation loss: 0.007054
# [2995/5000] Training loss: 0.000312	 Validation loss: 0.008656
# [3000/5000] Training loss: 0.020514	 Validation loss: 0.024040
# [3005/5000] Training loss: 0.002561	 Validation loss: 0.011436
# [3010/5000] Training loss: 0.001036	 Validation loss: 0.014523
# [3015/5000] Training loss: 0.000301	 Validation loss: 0.012240
# [3020/5000] Training loss: 0.000216	 Validation loss: 0.013003
# [3025/5000] Training loss: 0.000129	 Validation loss: 0.012513
# [3030/5000] Training loss: 0.000106	 Validation loss: 0.012173
# [3035/5000] Training loss: 0.000084	 Validation loss: 0.011410
# [3040/5000] Training loss: 0.000083	 Validation loss: 0.011806
# [3045/5000] Training loss: 0.000075	 Validation loss: 0.011777
# [3050/5000] Training loss: 0.000188	 Validation loss: 0.012826
# [3055/5000] Training loss: 0.000870	 Validation loss: 0.011540
# [3060/5000] Training loss: 0.000653	 Validation loss: 0.012686
# [3065/5000] Training loss: 0.000537	 Validation loss: 0.009480
# [3070/5000] Training loss: 0.000267	 Validation loss: 0.008631
# [3075/5000] Training loss: 0.000250	 Validation loss: 0.010441
# [3080/5000] Training loss: 0.000110	 Validation loss: 0.009136
# [3085/5000] Training loss: 0.000092	 Validation loss: 0.007771
# [3090/5000] Training loss: 0.000068	 Validation loss: 0.008245
# [3095/5000] Training loss: 0.000849	 Validation loss: 0.008234
# [3100/5000] Training loss: 0.001864	 Validation loss: 0.008633
# [3105/5000] Training loss: 0.000505	 Validation loss: 0.008370
# [3110/5000] Training loss: 0.000259	 Validation loss: 0.009847
# [3115/5000] Training loss: 0.000088	 Validation loss: 0.008213
# [3120/5000] Training loss: 0.000123	 Validation loss: 0.007978
# [3125/5000] Training loss: 0.000090	 Validation loss: 0.009534
# [3130/5000] Training loss: 0.000123	 Validation loss: 0.009173
# [3135/5000] Training loss: 0.000143	 Validation loss: 0.009334
# [3140/5000] Training loss: 0.000243	 Validation loss: 0.007564
# [3145/5000] Training loss: 0.001819	 Validation loss: 0.010610
# [3150/5000] Training loss: 0.000453	 Validation loss: 0.006357
# [3155/5000] Training loss: 0.000371	 Validation loss: 0.007890
# [3160/5000] Training loss: 0.000551	 Validation loss: 0.011099
# [3165/5000] Training loss: 0.000125	 Validation loss: 0.008622
# [3170/5000] Training loss: 0.000104	 Validation loss: 0.006852
# [3175/5000] Training loss: 0.000094	 Validation loss: 0.007429
# [3180/5000] Training loss: 0.000185	 Validation loss: 0.006896
# [3185/5000] Training loss: 0.000724	 Validation loss: 0.008353
# [3190/5000] Training loss: 0.000399	 Validation loss: 0.006896
# [3195/5000] Training loss: 0.000737	 Validation loss: 0.007291
# [3200/5000] Training loss: 0.000299	 Validation loss: 0.008850
# [3205/5000] Training loss: 0.000209	 Validation loss: 0.011314
# [3210/5000] Training loss: 0.000472	 Validation loss: 0.006873
# [3215/5000] Training loss: 0.000353	 Validation loss: 0.006647
# [3220/5000] Training loss: 0.001284	 Validation loss: 0.007415
# [3225/5000] Training loss: 0.000394	 Validation loss: 0.006661
# [3230/5000] Training loss: 0.000145	 Validation loss: 0.007187
# [3235/5000] Training loss: 0.000082	 Validation loss: 0.007519
# [3240/5000] Training loss: 0.000079	 Validation loss: 0.007091
# [3245/5000] Training loss: 0.000074	 Validation loss: 0.006552
# [3250/5000] Training loss: 0.000052	 Validation loss: 0.006826
# [3255/5000] Training loss: 0.004276	 Validation loss: 0.044640
# [3260/5000] Training loss: 0.001046	 Validation loss: 0.006776
# [3265/5000] Training loss: 0.002915	 Validation loss: 0.009979
# [3270/5000] Training loss: 0.000499	 Validation loss: 0.011317
# [3275/5000] Training loss: 0.000298	 Validation loss: 0.010333
# [3280/5000] Training loss: 0.000347	 Validation loss: 0.009810
# [3285/5000] Training loss: 0.000151	 Validation loss: 0.008593
# [3290/5000] Training loss: 0.000078	 Validation loss: 0.008865
# [3295/5000] Training loss: 0.000060	 Validation loss: 0.008451
# [3300/5000] Training loss: 0.000051	 Validation loss: 0.008343
# [3305/5000] Training loss: 0.000045	 Validation loss: 0.008296
# [3310/5000] Training loss: 0.000038	 Validation loss: 0.007989
# [3315/5000] Training loss: 0.000079	 Validation loss: 0.008830
# [3320/5000] Training loss: 0.000199	 Validation loss: 0.009259
# [3325/5000] Training loss: 0.000317	 Validation loss: 0.008855
# [3330/5000] Training loss: 0.000354	 Validation loss: 0.013046
# [3335/5000] Training loss: 0.000208	 Validation loss: 0.009169
# [3340/5000] Training loss: 0.000421	 Validation loss: 0.008679
# [3345/5000] Training loss: 0.001254	 Validation loss: 0.009361
# [3350/5000] Training loss: 0.000204	 Validation loss: 0.008479
# [3355/5000] Training loss: 0.012623	 Validation loss: 0.023907
# [3360/5000] Training loss: 0.000652	 Validation loss: 0.007241
# [3365/5000] Training loss: 0.000449	 Validation loss: 0.009632
# [3370/5000] Training loss: 0.000085	 Validation loss: 0.010029
# [3375/5000] Training loss: 0.000054	 Validation loss: 0.010591
# [3380/5000] Training loss: 0.000041	 Validation loss: 0.010544
# [3385/5000] Training loss: 0.000036	 Validation loss: 0.010530
# [3390/5000] Training loss: 0.000059	 Validation loss: 0.010006
# [3395/5000] Training loss: 0.000403	 Validation loss: 0.009764
# [3400/5000] Training loss: 0.002730	 Validation loss: 0.009275
# [3405/5000] Training loss: 0.001704	 Validation loss: 0.014725
# [3410/5000] Training loss: 0.000234	 Validation loss: 0.013941
# [3415/5000] Training loss: 0.000099	 Validation loss: 0.014479
# [3420/5000] Training loss: 0.000061	 Validation loss: 0.011622
# [3425/5000] Training loss: 0.000048	 Validation loss: 0.011524
# [3430/5000] Training loss: 0.000047	 Validation loss: 0.010822
# [3435/5000] Training loss: 0.000155	 Validation loss: 0.009239
# [3440/5000] Training loss: 0.000699	 Validation loss: 0.014870
# [3445/5000] Training loss: 0.000392	 Validation loss: 0.009992
# [3450/5000] Training loss: 0.000149	 Validation loss: 0.012478
# [3455/5000] Training loss: 0.000087	 Validation loss: 0.009645
# [3460/5000] Training loss: 0.000416	 Validation loss: 0.007240
# [3465/5000] Training loss: 0.000257	 Validation loss: 0.010446
# [3470/5000] Training loss: 0.000130	 Validation loss: 0.008103
# [3475/5000] Training loss: 0.000249	 Validation loss: 0.008191
# [3480/5000] Training loss: 0.000348	 Validation loss: 0.007968
# [3485/5000] Training loss: 0.000220	 Validation loss: 0.007544
# [3490/5000] Training loss: 0.000811	 Validation loss: 0.007345
# [3495/5000] Training loss: 0.000116	 Validation loss: 0.008913
# [3500/5000] Training loss: 0.000093	 Validation loss: 0.008278
# [3505/5000] Training loss: 0.000116	 Validation loss: 0.008292
# [3510/5000] Training loss: 0.000341	 Validation loss: 0.007048
# [3515/5000] Training loss: 0.001713	 Validation loss: 0.006962
# [3520/5000] Training loss: 0.000479	 Validation loss: 0.008446
# [3525/5000] Training loss: 0.000127	 Validation loss: 0.008809
# [3530/5000] Training loss: 0.000076	 Validation loss: 0.008754
# [3535/5000] Training loss: 0.000040	 Validation loss: 0.007707
# [3540/5000] Training loss: 0.000044	 Validation loss: 0.008099
# [3545/5000] Training loss: 0.000144	 Validation loss: 0.007232
# [3550/5000] Training loss: 0.001457	 Validation loss: 0.012218
# [3555/5000] Training loss: 0.000451	 Validation loss: 0.008732
# [3560/5000] Training loss: 0.000225	 Validation loss: 0.008075
# [3565/5000] Training loss: 0.000066	 Validation loss: 0.007856
# [3570/5000] Training loss: 0.000060	 Validation loss: 0.007030
# [3575/5000] Training loss: 0.000474	 Validation loss: 0.008011
# [3580/5000] Training loss: 0.001963	 Validation loss: 0.010629
# [3585/5000] Training loss: 0.002029	 Validation loss: 0.011738
# [3590/5000] Training loss: 0.000712	 Validation loss: 0.018161
# [3595/5000] Training loss: 0.000290	 Validation loss: 0.019377
# [3600/5000] Training loss: 0.000314	 Validation loss: 0.011074
# [3605/5000] Training loss: 0.000174	 Validation loss: 0.013518
# [3610/5000] Training loss: 0.000127	 Validation loss: 0.010951
# [3615/5000] Training loss: 0.000098	 Validation loss: 0.011547
# [3620/5000] Training loss: 0.000107	 Validation loss: 0.010038
# [3625/5000] Training loss: 0.000165	 Validation loss: 0.009198
# [3630/5000] Training loss: 0.000099	 Validation loss: 0.009636
# [3635/5000] Training loss: 0.000204	 Validation loss: 0.009283
# [3640/5000] Training loss: 0.000353	 Validation loss: 0.008204
# [3645/5000] Training loss: 0.000241	 Validation loss: 0.008030
# [3650/5000] Training loss: 0.000358	 Validation loss: 0.009953
# [3655/5000] Training loss: 0.000228	 Validation loss: 0.008046
# [3660/5000] Training loss: 0.000099	 Validation loss: 0.008074
# [3665/5000] Training loss: 0.000073	 Validation loss: 0.007917
# [3670/5000] Training loss: 0.000109	 Validation loss: 0.008077
# [3675/5000] Training loss: 0.000083	 Validation loss: 0.007973
# [3680/5000] Training loss: 0.000062	 Validation loss: 0.007894
# [3685/5000] Training loss: 0.000091	 Validation loss: 0.007606
# [3690/5000] Training loss: 0.001977	 Validation loss: 0.009618
# [3695/5000] Training loss: 0.000568	 Validation loss: 0.006593
# [3700/5000] Training loss: 0.000104	 Validation loss: 0.006875
# [3705/5000] Training loss: 0.000124	 Validation loss: 0.007732
# [3710/5000] Training loss: 0.000052	 Validation loss: 0.007548
# [3715/5000] Training loss: 0.000032	 Validation loss: 0.007475
# [3720/5000] Training loss: 0.000059	 Validation loss: 0.007641
# [3725/5000] Training loss: 0.003895	 Validation loss: 0.016093
# [3730/5000] Training loss: 0.000908	 Validation loss: 0.005897
# [3735/5000] Training loss: 0.000086	 Validation loss: 0.007114
# [3740/5000] Training loss: 0.000062	 Validation loss: 0.006404
# [3745/5000] Training loss: 0.000306	 Validation loss: 0.008177
# [3750/5000] Training loss: 0.000088	 Validation loss: 0.007175
# [3755/5000] Training loss: 0.000164	 Validation loss: 0.007746
# [3760/5000] Training loss: 0.000096	 Validation loss: 0.006441
# [3765/5000] Training loss: 0.000073	 Validation loss: 0.008014
# [3770/5000] Training loss: 0.000463	 Validation loss: 0.006495
# [3775/5000] Training loss: 0.000955	 Validation loss: 0.008393
# [3780/5000] Training loss: 0.000230	 Validation loss: 0.006613
# [3785/5000] Training loss: 0.000056	 Validation loss: 0.006523
# [3790/5000] Training loss: 0.000038	 Validation loss: 0.007136
# [3795/5000] Training loss: 0.000196	 Validation loss: 0.006542
# [3800/5000] Training loss: 0.000851	 Validation loss: 0.006243
# [3805/5000] Training loss: 0.000438	 Validation loss: 0.006297
# [3810/5000] Training loss: 0.000142	 Validation loss: 0.006061
# [3815/5000] Training loss: 0.000323	 Validation loss: 0.006039
# [3820/5000] Training loss: 0.000290	 Validation loss: 0.006498
# [3825/5000] Training loss: 0.000234	 Validation loss: 0.004934
# [3830/5000] Training loss: 0.000259	 Validation loss: 0.005809
# [3835/5000] Training loss: 0.000212	 Validation loss: 0.007901
# [3840/5000] Training loss: 0.000175	 Validation loss: 0.006670
# [3845/5000] Training loss: 0.000529	 Validation loss: 0.006658
# [3850/5000] Training loss: 0.000161	 Validation loss: 0.006638
# [3855/5000] Training loss: 0.000048	 Validation loss: 0.005915
# [3860/5000] Training loss: 0.000051	 Validation loss: 0.006037
# [3865/5000] Training loss: 0.000104	 Validation loss: 0.006260
# [3870/5000] Training loss: 0.000844	 Validation loss: 0.005049
# [3875/5000] Training loss: 0.000562	 Validation loss: 0.005911
# [3880/5000] Training loss: 0.000391	 Validation loss: 0.005870
# [3885/5000] Training loss: 0.000221	 Validation loss: 0.006106
# [3890/5000] Training loss: 0.000037	 Validation loss: 0.006101
# [3895/5000] Training loss: 0.000024	 Validation loss: 0.006017
# [3900/5000] Training loss: 0.000023	 Validation loss: 0.006122
# [3905/5000] Training loss: 0.000042	 Validation loss: 0.005793
# [3910/5000] Training loss: 0.001172	 Validation loss: 0.006219
# [3915/5000] Training loss: 0.000488	 Validation loss: 0.005962
# [3920/5000] Training loss: 0.000526	 Validation loss: 0.005657
# [3925/5000] Training loss: 0.000139	 Validation loss: 0.006513
# [3930/5000] Training loss: 0.000149	 Validation loss: 0.005402
# [3935/5000] Training loss: 0.000123	 Validation loss: 0.006205
# [3940/5000] Training loss: 0.000062	 Validation loss: 0.005697
# [3945/5000] Training loss: 0.000106	 Validation loss: 0.005425
# [3950/5000] Training loss: 0.000070	 Validation loss: 0.006503
# [3955/5000] Training loss: 0.000059	 Validation loss: 0.005798
# [3960/5000] Training loss: 0.000244	 Validation loss: 0.005379
# [3965/5000] Training loss: 0.000272	 Validation loss: 0.004153

# %%
predictions, values = opt.evaluate(test_loader_one, batch_size=1)

preds = np.array(predictions)
vals = np.array(values)

preds = np.reshape(preds, (5, 576, 384))
vals = np.reshape(vals, (5, 576, 384))

print(preds.shape, vals.shape)
# Out:
# (5, 576, 384) (5, 576, 384)

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[0, :, :].transpose() - vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[1, :, :].transpose() - vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[2, :, :].transpose() - vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[3, :, :].transpose() - vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[4, :, :].transpose() - vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
torch.save(model.state_dict(), 'Saved models/0SA1+Unet1024')

# %%
savfig_p = np.reshape(preds, (5, 576*384))
savfig_t = np.reshape(vals, (5, 576*384))

savfig_p = pd.DataFrame(savfig_p)
savfig_t = pd.DataFrame(savfig_t)

savfig_p.to_csv('CSVs/0SA1+Unet1024.csv', index=False)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def calculate_metrics(df1, df2):
    return {'mae' : mean_absolute_error(df1, df2),
            'rmse' : mean_squared_error(df1, df2) ** 0.5,
            'r2' : r2_score(df1, df2)}

# %%
result_metrics = calculate_metrics(savfig_t, savfig_p)
result_metrics
# Out:
# {'mae': 0.014203816, 'rmse': 0.06444586004870173, 'r2': -123.65236168838608}
