# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.interpolate import griddata
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import datetime
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, TensorDataset, DataLoader

from einops import rearrange

#PyTorch random number generator
torch.manual_seed(3407)
torch.cuda.manual_seed(3407)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
print(device)
# Out:
# cuda

# %%
bc_fine = np.zeros(((45, 168, 4)))

for i in range (45):
    df1 = pd.read_csv('C:/Users/59713/BC2MAP/inputs/case_{}.csv'.format(i+1))
    data1 = df1.values
    bc_fine[i, :, :] = data1

# %%
D_3d_fine = np.zeros(((45, 576, 384)))

for i in range (45):
    df2 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_{}.csv'.format(i))
    data2 = df2.values
    D_3d_fine[i, :, :] = np.reshape(data2[:, 5], (576, 384))

# %%
E_3d_fine = np.zeros((576, 384))
X_3d_fine = np.zeros((576, 384))
Y_3d_fine = np.zeros((576, 384))
S_3d_fine = np.zeros((576, 384))
map4all = np.zeros((576, 384))

df3 = pd.read_csv('C:/Users/59713/BC2MAP/Saved data/fine_45.csv')
data3 = df3.values
X_3d_fine[:, :] = np.reshape(data3[:, 0], (576, 384))
Y_3d_fine[:, :] = np.reshape(data3[:, 1], (576, 384))
E_3d_fine[:, :] = np.reshape(data3[:, 3], (576, 384))
map4all[:, :] = np.reshape(data3[:, 5], (576, 384))

# %%
dzdx = np.zeros((576, 384))
dzdy = np.zeros((576, 384))

# calculate internal cell slope
for i in range (1, S_3d_fine.shape[0]-1):
    for j in range (1, S_3d_fine.shape[1]-1):
        dzdx[i, j] = ((E_3d_fine[i+1, j-1]+2*E_3d_fine[i+1, j]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i-1, j]+2*E_3d_fine[i-1, j+1]))/(8*(X_3d_fine[i+1, j]-X_3d_fine[i-1, j]))
        dzdy[i, j] = ((E_3d_fine[i-1, j+1]+2*E_3d_fine[i, j+1]+E_3d_fine[i+1, j+1]) - (E_3d_fine[i-1, j-1]+E_3d_fine[i, j-1]+2*E_3d_fine[i+1, j-1]))/(8*(Y_3d_fine[i, j+1]-Y_3d_fine[i, j-1]))
        S_3d_fine[i, j] = np.arctan(np.sqrt((dzdx[i, j])**2+(dzdy[i, j])**2))
        
# take care of the most oustside layer
S_3d_fine[0, :] = S_3d_fine[1, :]
S_3d_fine[-1, :] = S_3d_fine[-2, :]
S_3d_fine[:, 0] = S_3d_fine[:, 1]
S_3d_fine[:, -1] = S_3d_fine[:, -2]

# %% [markdown]
# ### make a 3D info

# %%
all_data_X = bc_fine
all_data_Y = D_3d_fine

# %%
print(all_data_X.shape, all_data_Y.shape)
# Out:
# (45, 168, 4) (45, 576, 384)

# %%
# split into train and test
train_X, test_X = all_data_X[:-5, :], all_data_X[-5:, :]
train_y, test_y = all_data_Y[:-5, :, :], all_data_Y[-5:, :, :]

# %%
batch_size = 1

train_features = torch.Tensor(train_X).to(device)
train_targets = torch.Tensor(train_y).to(device)
test_features = torch.Tensor(test_X).to(device)
test_targets = torch.Tensor(test_y).to(device)

train = TensorDataset(train_features, train_targets)
test = TensorDataset(test_features, test_targets)

train_loader = DataLoader(train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader_one = DataLoader(test, batch_size=1, shuffle=False, drop_last=True)

# %%
sup_feat = np.zeros(((batch_size, 3, 576, 384)))

# first channel is mapforall
sup_feat[:, 0, :, :] = map4all
# second channel is elevation
sup_feat[:, 1, :, :] = E_3d_fine
# third channel is slope
sup_feat[:, 2, :, :] = S_3d_fine
# fourth channel left for bc info after SA

# %%
class Self_Attention(nn.Module):
    def __init__(self):
        super(Self_Attention, self).__init__()
        
        self.embed_dim = 864
        self.num_heads = 1
        self.head_dim = self.embed_dim // self.num_heads
        
        self.value = nn.Linear(self.embed_dim, self.embed_dim)
        self.key = nn.Linear(self.embed_dim, self.embed_dim)
        self.query = nn.Linear(self.embed_dim, self.embed_dim)
                    
    def forward(self, x):
        queries = self.query(x)
        keys = self.key(x)
        values = self.value(x)
        
        batch_size, seq_len, embed_dim = x.size()
        # Reshape query, key, and value to split into multiple heads
        queries = queries.view(batch_size, seq_len, self.num_heads, self.head_dim)
        keys = keys.view(batch_size, seq_len, self.num_heads, self.head_dim)
        values = values.view(batch_size, seq_len, self.num_heads, self.head_dim)
        
        # Transpose to prepare for scaled dot-product attention
        queries = queries.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        keys = keys.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        values = values.transpose(1, 2)  # (batch_size, num_heads, seq_len, head_dim)
        
        # Apply softmax to get attention probabilities
        attention_scores = torch.matmul(queries, keys.transpose(-2, -1)) / (self.head_dim**0.5)
        attention_probs = F.softmax(attention_scores, dim=-1)
        
        # Compute the weighted sum of values
        x = torch.matmul(attention_probs, values)
        
        # Reshape and concatenate heads
        x = x.transpose(1, 2)
        
        out = x.reshape(x.size(0), seq_len, embed_dim)
        
        return out

# %%
class BC2Map(nn.Module):
    def __init__(self, input_size, output_size, background_map, batch_size):
        super(BC2Map, self).__init__()
        
        self.background_map = torch.Tensor(background_map).to(device)
        
        self.input_size = input_size
        self.hidden_dim = output_size
        batch_size = batch_size
                
        self.fc1 = nn.Linear(input_size*3, self.hidden_dim)
        self.fc2 = nn.Linear(input_size, self.hidden_dim)
        
        self.self_attention = Self_Attention().to(device)
        
        self.L1 = nn.Linear(864, 4096)
        self.L2 = nn.Linear(4096, 864)
        
        self.pos_embedding = nn.Parameter(data=torch.randn(1, 2, 576, 384)).to(device)
        
        ##-----------end of embedding ---------##
        ##-----------start of Unet ---------##
        
        self.conv1 = nn.Conv2d(in_channels=5, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv7 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1)
        self.conv9 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1)
        self.conv10 = nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1)
        
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        
        self.conv_transpose0 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2, padding=0)
        self.conv_transpose1 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2, padding=0)
        self.conv_transpose2 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2, padding=0)
        self.conv_transpose3 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2, padding=0)
        self.conv_transpose4 = nn.ConvTranspose2d(in_channels=64, out_channels=1, kernel_size=3, stride=1, padding=1)
        
    def forward(self, x):
        # change dimension, maybe it's better to use embedding
        x = x.transpose(1, 2)
        x1 = x[:, :3, :].reshape(x.size(0), 1, -1)
        x1 = self.relu(self.fc1(x1))
        x2 = x[:, 3:, :]
        x2 = self.relu(self.fc2(x2))
        
        x = torch.cat((x1, x2), dim=1)
        x = rearrange(x, 'b c (h w) -> b c h w', h=576)
        
        # add positional embeddings
        x = x + self.pos_embedding
        
        x = rearrange(x, 'b c (h1 h) (w1 w) -> b (c h1 w1) (h w)', h1=16, w1=16)
        
        # Self-Attention #1
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #2
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #3
        x = self.self_attention(x)
        x = self.L2(self.relu(self.L1(x))) + x
        x = self.relu(x)
        
        # Self-Attention #4
        x = self.self_attention(x)
        
        # Concat the full feature map
        x = rearrange(x, 'b (c h1 w1) (h w) -> b c (h1 h) (w1 w)', h1=16, w1=16, c=2, h=36, w=24)
        x = torch.cat((x, self.background_map), dim=1)
        
        # initial conv: 1->64
        x = self.relu(self.conv1(x))
        
        # 1st resblock: 64->64
        identity = x
        x = self.conv2(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = x + identity
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 2nd resblock: 64->128
        identity2 = x
        x = self.conv3(x)
        x = self.relu(x)
        x = self.conv4(x)
        identity2 = self.conv3(identity2)
        x = x + identity2
        x = self.relu(x)
        x = self.maxpool(x)
        
        # 3rd resblock: 128->256
        identity3 = x
        x = self.conv5(x)
        x = self.relu(x)
        x = self.conv6(x)
        identity3 = self.conv5(identity3)
        x = x + identity3
        x = self.relu(x)
        
        # transpose2: 256->128
        x = self.relu(self.conv_transpose2(x))
        identity9 = x
        x = self.conv4(x)
        x = self.relu(x)
        x = self.conv4(x)
        x = x + identity9
        
        # transpose3: 128->64
        x = self.relu(self.conv_transpose3(x))
        identity10 = x
        x = self.conv2(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = x + identity10
        x = self.relu(x)
        
        # transpose4: 64->1
        x = self.relu(self.conv_transpose4(x))
        
        out = x.reshape(x.size(0), -1)
        
        return out

# %%
class Optimization:
    def __init__(self, model, optimizer):
        self.model = model
        self.loss_fn = nn.MSELoss(reduction="mean")
        self.optimizer = optimizer
        self.train_losses = []
        self.val_losses = []
    
    def train_step(self, x, y):
        # Sets model to train mode
        self.model.train()

        # Makes predictions
        yhat = self.model(x)

        # Computes loss
        loss = self.loss_fn(y, yhat)

        # Computes gradients
        loss.backward()

        # Updates parameters and zeroes gradients
        self.optimizer.step()
        self.optimizer.zero_grad()

        # Returns the loss
        return loss.item()

    def train(self, train_loader, val_loader, batch_size=4, n_epochs=50):
        model_path = f'models/{self.model}_{datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")}'

        for epoch in range(1, n_epochs + 1):
            batch_losses = []
            for x_batch, y_batch in train_loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.view([batch_size, 576*384]).to(device)
                loss = self.train_step(x_batch, y_batch)
                batch_losses.append(loss)
            training_loss = np.mean(batch_losses)
            self.train_losses.append(training_loss)

            with torch.no_grad():
                batch_val_losses = []
                for x_val, y_val in val_loader:
                    x_val = x_val.to(device)
                    y_val = y_val.view([batch_size, 576*384]).to(device)
                    self.model.eval()
                    yhat = self.model(x_val).to(device)
                    val_loss = self.loss_fn(y_val, yhat).item()
                    batch_val_losses.append(val_loss)
                validation_loss = np.mean(batch_val_losses)
                self.val_losses.append(validation_loss)

            if (epoch % 5 == 0):
                print(
                    f"[{epoch}/{n_epochs}] Training loss: {training_loss:.6f}\t Validation loss: {validation_loss:.6f}"
                )
            
            if (validation_loss <= 0.004):
                break

#         torch.save(self.model.state_dict(), model_path)

    def evaluate(self, test_loader, batch_size=1):
        with torch.no_grad():
            predictions = []
            values = []
            for x_test, y_test in test_loader:
                x_test = x_test.to(device)
                y_test = y_test.view([batch_size, 576*384]).to(device)
                self.model.eval()
                yhat = self.model(x_test)
                predictions.append(yhat.cpu().detach().numpy())
                values.append(y_test.cpu().detach().numpy())

        return predictions, values

    def plot_losses(self):
        plt.plot(self.train_losses, label="Training loss")
        plt.plot(self.val_losses, label="Validation loss")
        plt.legend()
        plt.title("Losses")
        plt.show()
        plt.close()

# %%
input_size = 672//4
output_size = 576 * 384

batch_size = batch_size
n_epochs = 5000
learning_rate = 1e-4
weight_decay = learning_rate/n_epochs

model = BC2Map(input_size, output_size, background_map=sup_feat, batch_size=batch_size).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

opt = Optimization(model=model, optimizer=optimizer)
opt.train(train_loader, test_loader, batch_size=batch_size, n_epochs=n_epochs)
opt.plot_losses()
# Out:
# [5/5000] Training loss: 0.428126	 Validation loss: 0.423165
# [10/5000] Training loss: 0.207249	 Validation loss: 0.272618
# [15/5000] Training loss: 0.127555	 Validation loss: 0.169086
# [20/5000] Training loss: 0.098761	 Validation loss: 0.153643
# [25/5000] Training loss: 0.091014	 Validation loss: 0.135578
# [30/5000] Training loss: 0.090365	 Validation loss: 0.194658
# [35/5000] Training loss: 0.074658	 Validation loss: 0.113596
# [40/5000] Training loss: 0.094222	 Validation loss: 0.122399
# [45/5000] Training loss: 0.106503	 Validation loss: 0.264085
# [50/5000] Training loss: 0.059507	 Validation loss: 0.106752
# [55/5000] Training loss: 0.053922	 Validation loss: 0.097774
# [60/5000] Training loss: 0.056806	 Validation loss: 0.138270
# [65/5000] Training loss: 0.058171	 Validation loss: 0.088821
# [70/5000] Training loss: 0.041288	 Validation loss: 0.096371
# [75/5000] Training loss: 0.051697	 Validation loss: 0.093184
# [80/5000] Training loss: 0.039881	 Validation loss: 0.080846
# [85/5000] Training loss: 0.037896	 Validation loss: 0.073388
# [90/5000] Training loss: 0.069382	 Validation loss: 0.096293
# [95/5000] Training loss: 0.061353	 Validation loss: 0.120427
# [100/5000] Training loss: 0.039767	 Validation loss: 0.088504
# [105/5000] Training loss: 0.037378	 Validation loss: 0.070328
# [110/5000] Training loss: 0.029939	 Validation loss: 0.083465
# [115/5000] Training loss: 0.049496	 Validation loss: 0.098974
# [120/5000] Training loss: 0.034879	 Validation loss: 0.060900
# [125/5000] Training loss: 0.025364	 Validation loss: 0.080752
# [130/5000] Training loss: 0.044859	 Validation loss: 0.132620
# [135/5000] Training loss: 0.079349	 Validation loss: 0.100375
# [140/5000] Training loss: 0.046630	 Validation loss: 0.060321
# [145/5000] Training loss: 0.036347	 Validation loss: 0.053916
# [150/5000] Training loss: 0.031898	 Validation loss: 0.065600
# [155/5000] Training loss: 0.029346	 Validation loss: 0.053110
# [160/5000] Training loss: 0.024860	 Validation loss: 0.067353
# [165/5000] Training loss: 0.039432	 Validation loss: 0.078465
# [170/5000] Training loss: 0.024741	 Validation loss: 0.044656
# [175/5000] Training loss: 0.044462	 Validation loss: 0.055928
# [180/5000] Training loss: 0.022439	 Validation loss: 0.037846
# [185/5000] Training loss: 0.017921	 Validation loss: 0.039467
# [190/5000] Training loss: 0.021146	 Validation loss: 0.044922
# [195/5000] Training loss: 0.018630	 Validation loss: 0.037485
# [200/5000] Training loss: 0.018928	 Validation loss: 0.062803
# [205/5000] Training loss: 0.017520	 Validation loss: 0.036898
# [210/5000] Training loss: 0.014542	 Validation loss: 0.043538
# [215/5000] Training loss: 0.023108	 Validation loss: 0.032785
# [220/5000] Training loss: 0.014014	 Validation loss: 0.039786
# [225/5000] Training loss: 0.011501	 Validation loss: 0.034003
# [230/5000] Training loss: 0.068205	 Validation loss: 0.066146
# [235/5000] Training loss: 0.015742	 Validation loss: 0.026108
# [240/5000] Training loss: 0.009721	 Validation loss: 0.026824
# [245/5000] Training loss: 0.009445	 Validation loss: 0.026559
# [250/5000] Training loss: 0.011953	 Validation loss: 0.036774
# [255/5000] Training loss: 0.014725	 Validation loss: 0.036731
# [260/5000] Training loss: 0.040868	 Validation loss: 0.042863
# [265/5000] Training loss: 0.028110	 Validation loss: 0.044843
# [270/5000] Training loss: 0.019801	 Validation loss: 0.025294
# [275/5000] Training loss: 0.008653	 Validation loss: 0.024444
# [280/5000] Training loss: 0.008831	 Validation loss: 0.022392
# [285/5000] Training loss: 0.006238	 Validation loss: 0.021666
# [290/5000] Training loss: 0.009316	 Validation loss: 0.026700
# [295/5000] Training loss: 0.010550	 Validation loss: 0.032652
# [300/5000] Training loss: 0.005814	 Validation loss: 0.018548
# [305/5000] Training loss: 0.006172	 Validation loss: 0.025064
# [310/5000] Training loss: 0.004605	 Validation loss: 0.022877
# [315/5000] Training loss: 0.010957	 Validation loss: 0.024654
# [320/5000] Training loss: 0.007791	 Validation loss: 0.018684
# [325/5000] Training loss: 0.009072	 Validation loss: 0.025646
# [330/5000] Training loss: 0.006940	 Validation loss: 0.019668
# [335/5000] Training loss: 0.017283	 Validation loss: 0.022790
# [340/5000] Training loss: 0.006252	 Validation loss: 0.017753
# [345/5000] Training loss: 0.007193	 Validation loss: 0.015942
# [350/5000] Training loss: 0.011177	 Validation loss: 0.022463
# [355/5000] Training loss: 0.005331	 Validation loss: 0.021581
# [360/5000] Training loss: 0.007477	 Validation loss: 0.028032
# [365/5000] Training loss: 0.004512	 Validation loss: 0.016482
# [370/5000] Training loss: 0.005010	 Validation loss: 0.027196
# [375/5000] Training loss: 0.008534	 Validation loss: 0.017981
# [380/5000] Training loss: 0.008141	 Validation loss: 0.015395
# [385/5000] Training loss: 0.003921	 Validation loss: 0.014086
# [390/5000] Training loss: 0.011494	 Validation loss: 0.023270
# [395/5000] Training loss: 0.014027	 Validation loss: 0.019070
# [400/5000] Training loss: 0.005560	 Validation loss: 0.021222
# [405/5000] Training loss: 0.026078	 Validation loss: 0.018202
# [410/5000] Training loss: 0.006315	 Validation loss: 0.014377
# [415/5000] Training loss: 0.002697	 Validation loss: 0.014345
# [420/5000] Training loss: 0.002510	 Validation loss: 0.017541
# [425/5000] Training loss: 0.007252	 Validation loss: 0.019810
# [430/5000] Training loss: 0.012976	 Validation loss: 0.046210
# [435/5000] Training loss: 0.002822	 Validation loss: 0.015548
# [440/5000] Training loss: 0.002581	 Validation loss: 0.013557
# [445/5000] Training loss: 0.002389	 Validation loss: 0.017881
# [450/5000] Training loss: 0.003352	 Validation loss: 0.015280
# [455/5000] Training loss: 0.037412	 Validation loss: 0.039286
# [460/5000] Training loss: 0.003423	 Validation loss: 0.012786
# [465/5000] Training loss: 0.004316	 Validation loss: 0.020631
# [470/5000] Training loss: 0.002738	 Validation loss: 0.013497
# [475/5000] Training loss: 0.007120	 Validation loss: 0.014182
# [480/5000] Training loss: 0.007320	 Validation loss: 0.015675
# [485/5000] Training loss: 0.034738	 Validation loss: 0.028443
# [490/5000] Training loss: 0.004840	 Validation loss: 0.018513
# [495/5000] Training loss: 0.001700	 Validation loss: 0.014513
# [500/5000] Training loss: 0.001460	 Validation loss: 0.013417
# [505/5000] Training loss: 0.002263	 Validation loss: 0.013492
# [510/5000] Training loss: 0.001806	 Validation loss: 0.013534
# [515/5000] Training loss: 0.002659	 Validation loss: 0.015147
# [520/5000] Training loss: 0.003501	 Validation loss: 0.013212
# [525/5000] Training loss: 0.004180	 Validation loss: 0.019993
# [530/5000] Training loss: 0.002680	 Validation loss: 0.017100
# [535/5000] Training loss: 0.002638	 Validation loss: 0.017076
# [540/5000] Training loss: 0.002835	 Validation loss: 0.016656
# [545/5000] Training loss: 0.002181	 Validation loss: 0.013495
# [550/5000] Training loss: 0.002733	 Validation loss: 0.012642
# [555/5000] Training loss: 0.006720	 Validation loss: 0.013072
# [560/5000] Training loss: 0.002260	 Validation loss: 0.016765
# [565/5000] Training loss: 0.004338	 Validation loss: 0.014619
# [570/5000] Training loss: 0.001277	 Validation loss: 0.014294
# [575/5000] Training loss: 0.002359	 Validation loss: 0.013736
# [580/5000] Training loss: 0.014487	 Validation loss: 0.026875
# [585/5000] Training loss: 0.002621	 Validation loss: 0.014239
# [590/5000] Training loss: 0.002079	 Validation loss: 0.013314
# [595/5000] Training loss: 0.001523	 Validation loss: 0.014302
# [600/5000] Training loss: 0.001810	 Validation loss: 0.016576
# [605/5000] Training loss: 0.001221	 Validation loss: 0.014363
# [610/5000] Training loss: 0.002579	 Validation loss: 0.014833
# [615/5000] Training loss: 0.001595	 Validation loss: 0.013331
# [620/5000] Training loss: 0.005693	 Validation loss: 0.017655
# [625/5000] Training loss: 0.002744	 Validation loss: 0.021271
# [630/5000] Training loss: 0.002820	 Validation loss: 0.019584
# [635/5000] Training loss: 0.003733	 Validation loss: 0.015700
# [640/5000] Training loss: 0.085573	 Validation loss: 0.139833
# [645/5000] Training loss: 0.005980	 Validation loss: 0.014063
# [650/5000] Training loss: 0.004479	 Validation loss: 0.013319
# [655/5000] Training loss: 0.002684	 Validation loss: 0.012162
# [660/5000] Training loss: 0.002981	 Validation loss: 0.015178
# [665/5000] Training loss: 0.001950	 Validation loss: 0.018403
# [670/5000] Training loss: 0.003128	 Validation loss: 0.012148
# [675/5000] Training loss: 0.001751	 Validation loss: 0.012790
# [680/5000] Training loss: 0.001341	 Validation loss: 0.015272
# [685/5000] Training loss: 0.002474	 Validation loss: 0.015325
# [690/5000] Training loss: 0.001804	 Validation loss: 0.014934
# [695/5000] Training loss: 0.001048	 Validation loss: 0.013076
# [700/5000] Training loss: 0.005026	 Validation loss: 0.013087
# [705/5000] Training loss: 0.004114	 Validation loss: 0.012717
# [710/5000] Training loss: 0.001864	 Validation loss: 0.015290
# [715/5000] Training loss: 0.003349	 Validation loss: 0.015088
# [720/5000] Training loss: 0.021446	 Validation loss: 0.016087
# [725/5000] Training loss: 0.001430	 Validation loss: 0.015733
# [730/5000] Training loss: 0.001116	 Validation loss: 0.012771
# [735/5000] Training loss: 0.001132	 Validation loss: 0.013299
# [740/5000] Training loss: 0.001672	 Validation loss: 0.019073
# [745/5000] Training loss: 0.001820	 Validation loss: 0.012722
# [750/5000] Training loss: 0.002694	 Validation loss: 0.015243
# [755/5000] Training loss: 0.001173	 Validation loss: 0.012003
# [760/5000] Training loss: 0.041299	 Validation loss: 0.037835
# [765/5000] Training loss: 0.023741	 Validation loss: 0.027654
# [770/5000] Training loss: 0.002133	 Validation loss: 0.014833
# [775/5000] Training loss: 0.001084	 Validation loss: 0.013878
# [780/5000] Training loss: 0.000883	 Validation loss: 0.014337
# [785/5000] Training loss: 0.000817	 Validation loss: 0.014558
# [790/5000] Training loss: 0.002628	 Validation loss: 0.014554
# [795/5000] Training loss: 0.002359	 Validation loss: 0.014560
# [800/5000] Training loss: 0.002160	 Validation loss: 0.018730
# [805/5000] Training loss: 0.004177	 Validation loss: 0.016011
# [810/5000] Training loss: 0.002543	 Validation loss: 0.018336
# [815/5000] Training loss: 0.001526	 Validation loss: 0.014057
# [820/5000] Training loss: 0.001749	 Validation loss: 0.014158
# [825/5000] Training loss: 0.001444	 Validation loss: 0.012937
# [830/5000] Training loss: 0.001648	 Validation loss: 0.016947
# [835/5000] Training loss: 0.005822	 Validation loss: 0.016931
# [840/5000] Training loss: 0.003172	 Validation loss: 0.014393
# [845/5000] Training loss: 0.001838	 Validation loss: 0.019286
# [850/5000] Training loss: 0.000914	 Validation loss: 0.014433
# [855/5000] Training loss: 0.001465	 Validation loss: 0.010242
# [860/5000] Training loss: 0.002109	 Validation loss: 0.012765
# [865/5000] Training loss: 0.013630	 Validation loss: 0.034023
# [870/5000] Training loss: 0.004310	 Validation loss: 0.016464
# [875/5000] Training loss: 0.001426	 Validation loss: 0.013104
# [880/5000] Training loss: 0.000846	 Validation loss: 0.012695
# [885/5000] Training loss: 0.000729	 Validation loss: 0.013707
# [890/5000] Training loss: 0.001240	 Validation loss: 0.016382
# [895/5000] Training loss: 0.000768	 Validation loss: 0.014016
# [900/5000] Training loss: 0.000748	 Validation loss: 0.013128
# [905/5000] Training loss: 0.001022	 Validation loss: 0.018692
# [910/5000] Training loss: 0.002132	 Validation loss: 0.013642
# [915/5000] Training loss: 0.002192	 Validation loss: 0.015751
# [920/5000] Training loss: 0.001336	 Validation loss: 0.011464
# [925/5000] Training loss: 0.000831	 Validation loss: 0.011688
# [930/5000] Training loss: 0.002020	 Validation loss: 0.014040
# [935/5000] Training loss: 0.013011	 Validation loss: 0.014730
# [940/5000] Training loss: 0.002980	 Validation loss: 0.011005
# [945/5000] Training loss: 0.001647	 Validation loss: 0.019260
# [950/5000] Training loss: 0.001617	 Validation loss: 0.012528
# [955/5000] Training loss: 0.001609	 Validation loss: 0.012744
# [960/5000] Training loss: 0.000951	 Validation loss: 0.012878
# [965/5000] Training loss: 0.003128	 Validation loss: 0.016203
# [970/5000] Training loss: 0.002419	 Validation loss: 0.011940
# [975/5000] Training loss: 0.001228	 Validation loss: 0.012394
# [980/5000] Training loss: 0.000807	 Validation loss: 0.012996
# [985/5000] Training loss: 0.000736	 Validation loss: 0.011520
# [990/5000] Training loss: 0.001032	 Validation loss: 0.016213
# [995/5000] Training loss: 0.001359	 Validation loss: 0.012872
# [1000/5000] Training loss: 0.010418	 Validation loss: 0.013743
# [1005/5000] Training loss: 0.001321	 Validation loss: 0.013090
# [1010/5000] Training loss: 0.000897	 Validation loss: 0.011320
# [1015/5000] Training loss: 0.001487	 Validation loss: 0.012687
# [1020/5000] Training loss: 0.001895	 Validation loss: 0.013428
# [1025/5000] Training loss: 0.000959	 Validation loss: 0.014098
# [1030/5000] Training loss: 0.000965	 Validation loss: 0.011042
# [1035/5000] Training loss: 0.000761	 Validation loss: 0.011943
# [1040/5000] Training loss: 0.000532	 Validation loss: 0.012639
# [1045/5000] Training loss: 0.000654	 Validation loss: 0.013019
# [1050/5000] Training loss: 0.000773	 Validation loss: 0.012115
# [1055/5000] Training loss: 0.005085	 Validation loss: 0.013391
# [1060/5000] Training loss: 0.003165	 Validation loss: 0.027683
# [1065/5000] Training loss: 0.001362	 Validation loss: 0.011353
# [1070/5000] Training loss: 0.000720	 Validation loss: 0.011188
# [1075/5000] Training loss: 0.000768	 Validation loss: 0.013584
# [1080/5000] Training loss: 0.002929	 Validation loss: 0.012472
# [1085/5000] Training loss: 0.002009	 Validation loss: 0.011103
# [1090/5000] Training loss: 0.001591	 Validation loss: 0.009640
# [1095/5000] Training loss: 0.001362	 Validation loss: 0.015128
# [1100/5000] Training loss: 0.004204	 Validation loss: 0.011606
# [1105/5000] Training loss: 0.003301	 Validation loss: 0.013219
# [1110/5000] Training loss: 0.002048	 Validation loss: 0.014503
# [1115/5000] Training loss: 0.000753	 Validation loss: 0.011998
# [1120/5000] Training loss: 0.000527	 Validation loss: 0.013053
# [1125/5000] Training loss: 0.000336	 Validation loss: 0.010210
# [1130/5000] Training loss: 0.000288	 Validation loss: 0.010753
# [1135/5000] Training loss: 0.003528	 Validation loss: 0.028460
# [1140/5000] Training loss: 0.007715	 Validation loss: 0.025606
# [1145/5000] Training loss: 0.001237	 Validation loss: 0.014654
# [1150/5000] Training loss: 0.000650	 Validation loss: 0.013040
# [1155/5000] Training loss: 0.001865	 Validation loss: 0.011962
# [1160/5000] Training loss: 0.000781	 Validation loss: 0.010512
# [1165/5000] Training loss: 0.001306	 Validation loss: 0.012223
# [1170/5000] Training loss: 0.000831	 Validation loss: 0.012218
# [1175/5000] Training loss: 0.002404	 Validation loss: 0.010517
# [1180/5000] Training loss: 0.000659	 Validation loss: 0.013241
# [1185/5000] Training loss: 0.001243	 Validation loss: 0.013419
# [1190/5000] Training loss: 0.000600	 Validation loss: 0.011489
# [1195/5000] Training loss: 0.001205	 Validation loss: 0.010964
# [1200/5000] Training loss: 0.000371	 Validation loss: 0.010758
# [1205/5000] Training loss: 0.000592	 Validation loss: 0.011973
# [1210/5000] Training loss: 0.000866	 Validation loss: 0.010784
# [1215/5000] Training loss: 0.006859	 Validation loss: 0.016539
# [1220/5000] Training loss: 0.007177	 Validation loss: 0.010432
# [1225/5000] Training loss: 0.003538	 Validation loss: 0.009415
# [1230/5000] Training loss: 0.000538	 Validation loss: 0.010710
# [1235/5000] Training loss: 0.001198	 Validation loss: 0.010928
# [1240/5000] Training loss: 0.000783	 Validation loss: 0.011058
# [1245/5000] Training loss: 0.001143	 Validation loss: 0.020627
# [1250/5000] Training loss: 0.000751	 Validation loss: 0.013686
# [1255/5000] Training loss: 0.001174	 Validation loss: 0.014583
# [1260/5000] Training loss: 0.000451	 Validation loss: 0.010340
# [1265/5000] Training loss: 0.000380	 Validation loss: 0.011587
# [1270/5000] Training loss: 0.001031	 Validation loss: 0.015171
# [1275/5000] Training loss: 0.000494	 Validation loss: 0.011190
# [1280/5000] Training loss: 0.001038	 Validation loss: 0.010355
# [1285/5000] Training loss: 0.004937	 Validation loss: 0.014707
# [1290/5000] Training loss: 0.000638	 Validation loss: 0.011541
# [1295/5000] Training loss: 0.002344	 Validation loss: 0.012731
# [1300/5000] Training loss: 0.000574	 Validation loss: 0.013389
# [1305/5000] Training loss: 0.000551	 Validation loss: 0.011369
# [1310/5000] Training loss: 0.000508	 Validation loss: 0.012523
# [1315/5000] Training loss: 0.001019	 Validation loss: 0.012461
# [1320/5000] Training loss: 0.002763	 Validation loss: 0.012367
# [1325/5000] Training loss: 0.006227	 Validation loss: 0.014385
# [1330/5000] Training loss: 0.001487	 Validation loss: 0.010400
# [1335/5000] Training loss: 0.000509	 Validation loss: 0.010935
# [1340/5000] Training loss: 0.000422	 Validation loss: 0.011527
# [1345/5000] Training loss: 0.000224	 Validation loss: 0.011423
# [1350/5000] Training loss: 0.000250	 Validation loss: 0.010979
# [1355/5000] Training loss: 0.000359	 Validation loss: 0.010484
# [1360/5000] Training loss: 0.000293	 Validation loss: 0.012647
# [1365/5000] Training loss: 0.001021	 Validation loss: 0.012609
# [1370/5000] Training loss: 0.005017	 Validation loss: 0.016544
# [1375/5000] Training loss: 0.000913	 Validation loss: 0.010940
# [1380/5000] Training loss: 0.000345	 Validation loss: 0.011336
# [1385/5000] Training loss: 0.001294	 Validation loss: 0.012904
# [1390/5000] Training loss: 0.001014	 Validation loss: 0.009446
# [1395/5000] Training loss: 0.001098	 Validation loss: 0.014358
# [1400/5000] Training loss: 0.000559	 Validation loss: 0.010269
# [1405/5000] Training loss: 0.000335	 Validation loss: 0.012443
# [1410/5000] Training loss: 0.000238	 Validation loss: 0.011370
# [1415/5000] Training loss: 0.001611	 Validation loss: 0.015631
# [1420/5000] Training loss: 0.002808	 Validation loss: 0.011765
# [1425/5000] Training loss: 0.000894	 Validation loss: 0.011884
# [1430/5000] Training loss: 0.000678	 Validation loss: 0.011052
# [1435/5000] Training loss: 0.000679	 Validation loss: 0.012720
# [1440/5000] Training loss: 0.000534	 Validation loss: 0.011806
# [1445/5000] Training loss: 0.000910	 Validation loss: 0.010610
# [1450/5000] Training loss: 0.000960	 Validation loss: 0.011328
# [1455/5000] Training loss: 0.000982	 Validation loss: 0.010136
# [1460/5000] Training loss: 0.000845	 Validation loss: 0.010036
# [1465/5000] Training loss: 0.001950	 Validation loss: 0.014416
# [1470/5000] Training loss: 0.000436	 Validation loss: 0.011260
# [1475/5000] Training loss: 0.000311	 Validation loss: 0.012279
# [1480/5000] Training loss: 0.000925	 Validation loss: 0.013738
# [1485/5000] Training loss: 0.000758	 Validation loss: 0.011324
# [1490/5000] Training loss: 0.001107	 Validation loss: 0.011287
# [1495/5000] Training loss: 0.001112	 Validation loss: 0.013098
# [1500/5000] Training loss: 0.000954	 Validation loss: 0.010364
# [1505/5000] Training loss: 0.000447	 Validation loss: 0.012024
# [1510/5000] Training loss: 0.001245	 Validation loss: 0.009436
# [1515/5000] Training loss: 0.002003	 Validation loss: 0.016728
# [1520/5000] Training loss: 0.000639	 Validation loss: 0.011490
# [1525/5000] Training loss: 0.000776	 Validation loss: 0.010978
# [1530/5000] Training loss: 0.000773	 Validation loss: 0.010514
# [1535/5000] Training loss: 0.000485	 Validation loss: 0.012258
# [1540/5000] Training loss: 0.002668	 Validation loss: 0.010937
# [1545/5000] Training loss: 0.001138	 Validation loss: 0.015777
# [1550/5000] Training loss: 0.000711	 Validation loss: 0.013293
# [1555/5000] Training loss: 0.003794	 Validation loss: 0.023675
# [1560/5000] Training loss: 0.000975	 Validation loss: 0.009567
# [1565/5000] Training loss: 0.000452	 Validation loss: 0.010261
# [1570/5000] Training loss: 0.000333	 Validation loss: 0.010212
# [1575/5000] Training loss: 0.000486	 Validation loss: 0.011351
# [1580/5000] Training loss: 0.000282	 Validation loss: 0.010541
# [1585/5000] Training loss: 0.000272	 Validation loss: 0.012154
# [1590/5000] Training loss: 0.000310	 Validation loss: 0.010384
# [1595/5000] Training loss: 0.000368	 Validation loss: 0.010326
# [1600/5000] Training loss: 0.000306	 Validation loss: 0.010436
# [1605/5000] Training loss: 0.000333	 Validation loss: 0.011087
# [1610/5000] Training loss: 0.001330	 Validation loss: 0.012662
# [1615/5000] Training loss: 0.001817	 Validation loss: 0.009173
# [1620/5000] Training loss: 0.001330	 Validation loss: 0.009455
# [1625/5000] Training loss: 0.000879	 Validation loss: 0.013282
# [1630/5000] Training loss: 0.000457	 Validation loss: 0.009026
# [1635/5000] Training loss: 0.019852	 Validation loss: 0.026672
# [1640/5000] Training loss: 0.011440	 Validation loss: 0.019907
# [1645/5000] Training loss: 0.006636	 Validation loss: 0.006145
# [1650/5000] Training loss: 0.000496	 Validation loss: 0.009368
# [1655/5000] Training loss: 0.000383	 Validation loss: 0.010176
# [1660/5000] Training loss: 0.000258	 Validation loss: 0.010044
# [1665/5000] Training loss: 0.000221	 Validation loss: 0.010095
# [1670/5000] Training loss: 0.006417	 Validation loss: 0.019647
# [1675/5000] Training loss: 0.003511	 Validation loss: 0.010339
# [1680/5000] Training loss: 0.000207	 Validation loss: 0.010362
# [1685/5000] Training loss: 0.000184	 Validation loss: 0.010088
# [1690/5000] Training loss: 0.000163	 Validation loss: 0.010134
# [1695/5000] Training loss: 0.000139	 Validation loss: 0.010079
# [1700/5000] Training loss: 0.000221	 Validation loss: 0.010847
# [1705/5000] Training loss: 0.001356	 Validation loss: 0.010899
# [1710/5000] Training loss: 0.000997	 Validation loss: 0.010364
# [1715/5000] Training loss: 0.000240	 Validation loss: 0.009660
# [1720/5000] Training loss: 0.000410	 Validation loss: 0.010304
# [1725/5000] Training loss: 0.004377	 Validation loss: 0.012501
# [1730/5000] Training loss: 0.000931	 Validation loss: 0.012679
# [1735/5000] Training loss: 0.000878	 Validation loss: 0.010309
# [1740/5000] Training loss: 0.000528	 Validation loss: 0.011805
# [1745/5000] Training loss: 0.000876	 Validation loss: 0.010194
# [1750/5000] Training loss: 0.000271	 Validation loss: 0.010536
# [1755/5000] Training loss: 0.000244	 Validation loss: 0.011033
# [1760/5000] Training loss: 0.000247	 Validation loss: 0.010796
# [1765/5000] Training loss: 0.000517	 Validation loss: 0.010224
# [1770/5000] Training loss: 0.001531	 Validation loss: 0.010176
# [1775/5000] Training loss: 0.001645	 Validation loss: 0.015396
# [1780/5000] Training loss: 0.001278	 Validation loss: 0.008986
# [1785/5000] Training loss: 0.000564	 Validation loss: 0.010605
# [1790/5000] Training loss: 0.020814	 Validation loss: 0.019036
# [1795/5000] Training loss: 0.000696	 Validation loss: 0.010430
# [1800/5000] Training loss: 0.000350	 Validation loss: 0.009055
# [1805/5000] Training loss: 0.000236	 Validation loss: 0.009252
# [1810/5000] Training loss: 0.000454	 Validation loss: 0.009600
# [1815/5000] Training loss: 0.000188	 Validation loss: 0.010765
# [1820/5000] Training loss: 0.000357	 Validation loss: 0.009548
# [1825/5000] Training loss: 0.000904	 Validation loss: 0.010704
# [1830/5000] Training loss: 0.001663	 Validation loss: 0.009156
# [1835/5000] Training loss: 0.001917	 Validation loss: 0.012615
# [1840/5000] Training loss: 0.000370	 Validation loss: 0.008484
# [1845/5000] Training loss: 0.007453	 Validation loss: 0.034179
# [1850/5000] Training loss: 0.015724	 Validation loss: 0.020063
# [1855/5000] Training loss: 0.003496	 Validation loss: 0.009727
# [1860/5000] Training loss: 0.002112	 Validation loss: 0.013907
# [1865/5000] Training loss: 0.001149	 Validation loss: 0.010958
# [1870/5000] Training loss: 0.000413	 Validation loss: 0.009510
# [1875/5000] Training loss: 0.000328	 Validation loss: 0.009509
# [1880/5000] Training loss: 0.000315	 Validation loss: 0.009937
# [1885/5000] Training loss: 0.000203	 Validation loss: 0.010375
# [1890/5000] Training loss: 0.000174	 Validation loss: 0.009821
# [1895/5000] Training loss: 0.000181	 Validation loss: 0.009531
# [1900/5000] Training loss: 0.001166	 Validation loss: 0.013054
# [1905/5000] Training loss: 0.001612	 Validation loss: 0.009600
# [1910/5000] Training loss: 0.000711	 Validation loss: 0.009243
# [1915/5000] Training loss: 0.000476	 Validation loss: 0.010028
# [1920/5000] Training loss: 0.000677	 Validation loss: 0.009872
# [1925/5000] Training loss: 0.000796	 Validation loss: 0.009131
# [1930/5000] Training loss: 0.000879	 Validation loss: 0.011772
# [1935/5000] Training loss: 0.000875	 Validation loss: 0.008702
# [1940/5000] Training loss: 0.000357	 Validation loss: 0.010331
# [1945/5000] Training loss: 0.000240	 Validation loss: 0.010133
# [1950/5000] Training loss: 0.000596	 Validation loss: 0.011945
# [1955/5000] Training loss: 0.004869	 Validation loss: 0.013933
# [1960/5000] Training loss: 0.000304	 Validation loss: 0.011329
# [1965/5000] Training loss: 0.000463	 Validation loss: 0.010579
# [1970/5000] Training loss: 0.001793	 Validation loss: 0.010644
# [1975/5000] Training loss: 0.000467	 Validation loss: 0.010646
# [1980/5000] Training loss: 0.000209	 Validation loss: 0.010667
# [1985/5000] Training loss: 0.000925	 Validation loss: 0.009808
# [1990/5000] Training loss: 0.001082	 Validation loss: 0.012067
# [1995/5000] Training loss: 0.000975	 Validation loss: 0.008412
# [2000/5000] Training loss: 0.000535	 Validation loss: 0.009699
# [2005/5000] Training loss: 0.001309	 Validation loss: 0.009141
# [2010/5000] Training loss: 0.001863	 Validation loss: 0.009455
# [2015/5000] Training loss: 0.000718	 Validation loss: 0.009506
# [2020/5000] Training loss: 0.000561	 Validation loss: 0.009521
# [2025/5000] Training loss: 0.000172	 Validation loss: 0.011473
# [2030/5000] Training loss: 0.000317	 Validation loss: 0.009496
# [2035/5000] Training loss: 0.001090	 Validation loss: 0.010037
# [2040/5000] Training loss: 0.001645	 Validation loss: 0.013827
# [2045/5000] Training loss: 0.002660	 Validation loss: 0.012626
# [2050/5000] Training loss: 0.000886	 Validation loss: 0.009454
# [2055/5000] Training loss: 0.025604	 Validation loss: 0.024187
# [2060/5000] Training loss: 0.001789	 Validation loss: 0.011417
# [2065/5000] Training loss: 0.012746	 Validation loss: 0.010771
# [2070/5000] Training loss: 0.000476	 Validation loss: 0.011078
# [2075/5000] Training loss: 0.000304	 Validation loss: 0.011288
# [2080/5000] Training loss: 0.000332	 Validation loss: 0.011506
# [2085/5000] Training loss: 0.000169	 Validation loss: 0.012442
# [2090/5000] Training loss: 0.000144	 Validation loss: 0.011932
# [2095/5000] Training loss: 0.000284	 Validation loss: 0.011642
# [2100/5000] Training loss: 0.000244	 Validation loss: 0.010991
# [2105/5000] Training loss: 0.003053	 Validation loss: 0.019326
# [2110/5000] Training loss: 0.000678	 Validation loss: 0.012085
# [2115/5000] Training loss: 0.000428	 Validation loss: 0.010130
# [2120/5000] Training loss: 0.000460	 Validation loss: 0.011786
# [2125/5000] Training loss: 0.009672	 Validation loss: 0.023810
# [2130/5000] Training loss: 0.000775	 Validation loss: 0.011832
# [2135/5000] Training loss: 0.000451	 Validation loss: 0.011258
# [2140/5000] Training loss: 0.000177	 Validation loss: 0.010586
# [2145/5000] Training loss: 0.000138	 Validation loss: 0.010863
# [2150/5000] Training loss: 0.000140	 Validation loss: 0.010785
# [2155/5000] Training loss: 0.000091	 Validation loss: 0.010831
# [2160/5000] Training loss: 0.009565	 Validation loss: 0.043801
# [2165/5000] Training loss: 0.016626	 Validation loss: 0.011693
# [2170/5000] Training loss: 0.007386	 Validation loss: 0.007510
# [2175/5000] Training loss: 0.003452	 Validation loss: 0.005257
# [2180/5000] Training loss: 0.001970	 Validation loss: 0.008217
# [2185/5000] Training loss: 0.001605	 Validation loss: 0.004708

# %%
predictions, values = opt.evaluate(test_loader_one, batch_size=1)

preds = np.array(predictions)
vals = np.array(values)

preds = np.reshape(preds, (5, 576, 384))
vals = np.reshape(vals, (5, 576, 384))

print(preds.shape, vals.shape)
# Out:
# (5, 576, 384) (5, 576, 384)

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[0, :, :].transpose() - vals[0, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[1, :, :].transpose() - vals[1, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[2, :, :].transpose() - vals[2, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[3, :, :].transpose() - vals[3, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(preds[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.rcParams['figure.figsize'] = [20, 10]

plt.imshow(vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
plt.imshow(preds[4, :, :].transpose() - vals[4, :, :].transpose(), cmap='viridis', origin='lower')
plt.colorbar()  # Add a colorbar for reference
plt.show()
plt.close()

# %%
torch.save(model.state_dict(), 'Saved models/0SA4+Unet256')

# %%
savfig_p = np.reshape(preds, (5, 576*384))
savfig_t = np.reshape(vals, (5, 576*384))

savfig_p = pd.DataFrame(savfig_p)
savfig_t = pd.DataFrame(savfig_t)

savfig_p.to_csv('CSVs/0SA4+Unet256.csv', index=False)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def calculate_metrics(df1, df2):
    return {'mae' : mean_absolute_error(df1, df2),
            'rmse' : mean_squared_error(df1, df2) ** 0.5,
            'r2' : r2_score(df1, df2)}

# %%
result_metrics = calculate_metrics(savfig_t, savfig_p)
result_metrics
# Out:
# {'mae': 0.011291577, 'rmse': 0.061922115635530656, 'r2': -158.51811677648715}
